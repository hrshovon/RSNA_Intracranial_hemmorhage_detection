# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore", category=UserWarning, module="torch.nn.functional")

# %%
import cv2
import pandas as pd
import pydicom
from fastai.vision import *
from fastai.callbacks import *
from fastai.data_block import _maybe_squeeze
from collections import defaultdict
from torchvision.models import *
import pretrainedmodels
from fastai.vision.models import *

import sys

# %%
import torch
torch.cuda.device(0)

# %%
torch.cuda.get_device_name()
# Out:
# 'GeForce GTX 1070'

# %%
path = Path('/mnt/fst/shaan/rsna-intracranial-hemorrhage-detection')
cmap='jet'

# %%
import os
files = os.listdir("/mnt/fst/shaan/rsna-intracranial-hemorrhage-detection/train224")
test_files = os.listdir("/mnt/fst/shaan/rsna-intracranial-hemorrhage-detection/test224")

# %%
df = pd.read_csv(path/'stage_1_train.csv')
df['fn'] = df.ID.apply(lambda x: '_'.join(x.split('_')[:2]) + '.dcm')
df.columns = ['ID', 'probability', 'fn']
df['label'] = df.ID.apply(lambda x: x.split('_')[-1])
df.drop_duplicates('ID', inplace=True)
pivot = df.pivot(index='fn', columns='label', values='probability')
pivot.reset_index(inplace=True)
d = defaultdict(list)
for fn in df.fn.unique(): 
    d[fn]
for tup in df.itertuples():
    if tup.probability: 
        d[tup.fn].append(tup.label)
        
ks, vs = [], []

for k, v in d.items():
    ks.append(k), vs.append(' '.join(v))
    
df_train = pd.DataFrame(data={'fn': ks, 'labels': vs})
df_train.labels.fillna('', inplace=True)
df_train = df_train[df_train['fn'] != 'ID_6431af929.dcm']
df_train.reset_index(drop=True, inplace=True)

# %%
df_trn = pd.read_feather(path/'df_trn.fth')
df_trn = df_trn[df_trn['SOPInstanceUID'] != 'ID_6431af929']
df_trn
# Out:
#        SOPInstanceUID Modality    PatientID StudyInstanceUID  \
# 0        ID_231d901c1       CT  ID_b81a287f    ID_dd37ba3adb
# 1        ID_994bc0470       CT  ID_400facde    ID_c5277f0c63
# 2        ID_127689cce       CT  ID_42910d3d    ID_db93ade25b
# 3        ID_25457734a       CT  ID_329aafa7    ID_8dd6d32f3b
# 4        ID_81c9aa125       CT  ID_6b544c3c    ID_2685c5d5c0
# ...               ...      ...          ...              ...
# 674253   ID_1b415e1cc       CT  ID_b13dd1c5    ID_a56ee65b9f
# 674254   ID_59ec44ad3       CT  ID_683fd24c    ID_405c292102
# 674255   ID_c6516b047       CT  ID_75f878eb    ID_64406ff4f4
# 674256   ID_2c0ac4759       CT  ID_cf94e855    ID_a8aff1a18e
# 674257   ID_19eede6a5       CT  ID_b1a20252    ID_11dbf143b5
#
#        SeriesInstanceUID StudyID  ImagePositionPatient  \
# 0          ID_15dcd6057a                        -125.0
# 1          ID_4ba12c2161                        -125.0
# 2          ID_c4b4931314                        -125.0
# 3          ID_116558f409                        -114.0
# 4          ID_f56d7bd0f9                        -115.0
# ...                  ...     ...                   ...
# 674253     ID_70961fe25e                        -156.0
# 674254     ID_9c1e421cad                        -120.5
# 674255     ID_87fe0fa9f4                        -109.5
# 674256     ID_fa5855e749                        -106.5
# 674257     ID_39bb965c30                        -125.0
#
#         ImageOrientationPatient  SamplesPerPixel PhotometricInterpretation  \
# 0                           1.0                1               MONOCHROME2
# 1                           1.0                1               MONOCHROME2
# 2                           1.0                1               MONOCHROME2
# 3                           1.0                1               MONOCHROME2
# 4                           1.0                1               MONOCHROME2
# ...                         ...              ...                       ...
# 674253                      1.0                1               MONOCHROME2
# 674254                      1.0                1               MONOCHROME2
# 674255                      1.0                1               MONOCHROME2
# 674256                      1.0                1               MONOCHROME2
# 674257                      1.0                1               MONOCHROME2
#
#         ...  PixelSpacing1  img_min  img_max    img_mean      img_std  \
# 0       ...       0.488281    -1024     3263  171.462490   828.102464
# 1       ...       0.488281        0     2507  430.418091   599.742963
# 2       ...       0.488281    -2000     2810   12.801376  1209.046168
# 3       ...       0.445312        0     2647  566.557011   610.152845
# 4       ...       0.449219        4     1570  178.512295   358.235071
# ...     ...            ...      ...      ...         ...          ...
# 674253  ...       0.609375        4     2612  292.513027   469.929874
# 674254  ...       0.470703        3     2452  559.591610   578.345477
# 674255  ...       0.427734        9     2646  524.992954   567.491898
# 674256  ...       0.416016        0     4000  544.195152   573.152837
# 674257  ...       0.488281    -2000     2687   77.698273  1229.599807
#
#         img_pct_window  MultiWindowCenter  WindowCenter1  MultiWindowWidth  \
# 0             0.164074                NaN            NaN               NaN
# 1             0.198139                1.0           47.0               1.0
# 2             0.250923                NaN            NaN               NaN
# 3             0.298386                1.0           36.0               1.0
# 4             0.006176                1.0           36.0               1.0
# ...                ...                ...            ...               ...
# 674253        0.100445                1.0           36.0               1.0
# 674254        0.171585                1.0           36.0               1.0
# 674255        0.172607                1.0           36.0               1.0
# 674256        0.209194                1.0           36.0               1.0
# 674257        0.171535                NaN            NaN               NaN
#
#         WindowWidth1
# 0                NaN
# 1               80.0
# 2                NaN
# 3               80.0
# 4               80.0
# ...              ...
# 674253          80.0
# 674254          80.0
# 674255          80.0
# 674256          80.0
# 674257           NaN
#
# [674257 rows x 42 columns]

# %%
bad_img = list(df_trn[df_trn.img_pct_window<0.025].SOPInstanceUID)
bad_img = [s + '.dcm' for s in bad_img]
df_train = df_train[~(df_train.fn.isin(bad_img))]
bad_img
# Out:
# ['ID_81c9aa125.dcm',
#  'ID_a31462f2a.dcm',
#  'ID_0acb28b87.dcm',
#  'ID_7ad9ec79d.dcm',
#  'ID_1029cc830.dcm',
#  'ID_78f04b7d1.dcm',
#  'ID_7a0d8a53f.dcm',
#  'ID_ea2568d47.dcm',
#  'ID_c0c3c5e80.dcm',
#  'ID_2f124f224.dcm',
#  'ID_6e922e6c0.dcm',
#  'ID_9db1dd7fb.dcm',
#  'ID_e425db695.dcm',
#  'ID_73d43e137.dcm',
#  'ID_4777fd31b.dcm',
#  'ID_6327b8d38.dcm',
#  'ID_aa241029b.dcm',
#  'ID_eb6ab0790.dcm',
#  'ID_b16095ca8.dcm',
#  'ID_3a626bb70.dcm',
#  'ID_cf4cb07e2.dcm',
#  'ID_ba098b526.dcm',
#  'ID_b58fe3c5b.dcm',
#  'ID_88d25c1bc.dcm',
#  'ID_6939a1303.dcm',
#  'ID_d7cc266e5.dcm',
#  'ID_38e4700ea.dcm',
#  'ID_17a077f2e.dcm',
#  'ID_000ada5fc.dcm',
#  'ID_c4a1a689d.dcm',
#  'ID_8e704bc00.dcm',
#  'ID_fad0346b8.dcm',
#  'ID_d52765ca8.dcm',
#  'ID_0135a2814.dcm',
#  'ID_39065f5de.dcm',
#  'ID_07d914f5f.dcm',
#  'ID_99fbcbf35.dcm',
#  'ID_c3f736a1e.dcm',
#  'ID_76e3b4e0f.dcm',
#  'ID_85372445f.dcm',
#  'ID_3b2232047.dcm',
#  'ID_740be9098.dcm',
#  'ID_3f2848a01.dcm',
#  'ID_14bb5b755.dcm',
#  'ID_d12e704a8.dcm',
#  'ID_b2890a394.dcm',
#  'ID_d37088a1f.dcm',
#  'ID_12ec08137.dcm',
#  'ID_d2a72bf2d.dcm',
#  'ID_5e517b4bb.dcm',
#  'ID_725547ac7.dcm',
#  'ID_658332c96.dcm',
#  'ID_c6eb7e189.dcm',
#  'ID_afe674bef.dcm',
#  'ID_3c6487b43.dcm',
#  'ID_52852b8df.dcm',
#  'ID_b3899f4bb.dcm',
#  'ID_f88494933.dcm',
#  'ID_733bdfc3b.dcm',
#  'ID_a9846beef.dcm',
#  'ID_5310d516b.dcm',
#  'ID_9b169bd4f.dcm',
#  'ID_995f635ef.dcm',
#  'ID_cf5c13a96.dcm',
#  'ID_0ebd4d280.dcm',
#  'ID_24aebfb60.dcm',
#  'ID_615f2f089.dcm',
#  'ID_d213d4de8.dcm',
#  'ID_88e047c37.dcm',
#  'ID_8e5dae42b.dcm',
#  'ID_21d5191cd.dcm',
#  'ID_df79c1e9e.dcm',
#  'ID_9d5124829.dcm',
#  'ID_7a2cbd5e3.dcm',
#  'ID_9420689bf.dcm',
#  'ID_fac6f0f20.dcm',
#  'ID_7f851b405.dcm',
#  'ID_95b9a491c.dcm',
#  'ID_6bef884da.dcm',
#  'ID_eaeeee800.dcm',
#  'ID_10ce3862b.dcm',
#  'ID_85fecd132.dcm',
#  'ID_a92ea9b04.dcm',
#  'ID_0aa17d575.dcm',
#  'ID_832370729.dcm',
#  'ID_d043608fc.dcm',
#  'ID_192a27071.dcm',
#  'ID_b126ec94d.dcm',
#  'ID_2649525d6.dcm',
#  'ID_d5402e024.dcm',
#  'ID_f739fb71b.dcm',
#  'ID_18941be3c.dcm',
#  'ID_82a2b003a.dcm',
#  'ID_c6cc9bb6f.dcm',
#  'ID_fd0c837d8.dcm',
#  'ID_aa90a0f0d.dcm',
#  'ID_dc677a106.dcm',
#  'ID_da6c6ecf7.dcm',
#  'ID_e6413b983.dcm',
#  'ID_d7f652d23.dcm',
#  'ID_2ed045ef8.dcm',
#  'ID_4abe9b63f.dcm',
#  'ID_76396dcb8.dcm',
#  'ID_6270a270b.dcm',
#  'ID_5921618e3.dcm',
#  'ID_7945fded4.dcm',
#  'ID_837435fd6.dcm',
#  'ID_a1ae8cdd3.dcm',
#  'ID_b16b3b6a3.dcm',
#  'ID_cd7cb13e6.dcm',
#  'ID_8cfcfe329.dcm',
#  'ID_67af99bf9.dcm',
#  'ID_9358c7d95.dcm',
#  'ID_79da7843d.dcm',
#  'ID_7cb002bb1.dcm',
#  'ID_81ef45a50.dcm',
#  'ID_7cb45206b.dcm',
#  'ID_a48913b44.dcm',
#  'ID_b60259084.dcm',
#  'ID_a4a20af33.dcm',
#  'ID_43ffada62.dcm',
#  'ID_0929a8bb4.dcm',
#  'ID_1357bbae4.dcm',
#  'ID_38991ff26.dcm',
#  'ID_d4956d4dd.dcm',
#  'ID_107a21536.dcm',
#  'ID_08df59e4a.dcm',
#  'ID_2d3133e04.dcm',
#  'ID_511cd373f.dcm',
#  'ID_993ebf2c9.dcm',
#  'ID_c95f9dbd2.dcm',
#  'ID_1972f05e5.dcm',
#  'ID_db3d2484a.dcm',
#  'ID_48f0ce546.dcm',
#  'ID_ec46d2361.dcm',
#  'ID_e8b9a7e40.dcm',
#  'ID_233e26b36.dcm',
#  'ID_d639263ff.dcm',
#  'ID_68212292b.dcm',
#  'ID_0af240c7a.dcm',
#  'ID_9d791942b.dcm',
#  'ID_7c952e4d4.dcm',
#  'ID_4ddb2f32c.dcm',
#  'ID_d3e5d1009.dcm',
#  'ID_9958bdcc4.dcm',
#  'ID_51a5b3030.dcm',
#  'ID_3ec2ed3bd.dcm',
#  'ID_b26de7218.dcm',
#  'ID_392009dc7.dcm',
#  'ID_1d34f9fa4.dcm',
#  'ID_6e5dd8946.dcm',
#  'ID_b51d78c14.dcm',
#  'ID_97e47ac58.dcm',
#  'ID_943e64aa2.dcm',
#  'ID_428faecf0.dcm',
#  'ID_845812ac1.dcm',
#  'ID_b9755f3f8.dcm',
#  'ID_3a15a0243.dcm',
#  'ID_db9d2f945.dcm',
#  'ID_d837ff6a0.dcm',
#  'ID_0d80d6684.dcm',
#  'ID_991ac2ee8.dcm',
#  'ID_342276196.dcm',
#  'ID_d6d645b63.dcm',
#  'ID_af7d56175.dcm',
#  'ID_52f696646.dcm',
#  'ID_9cb24d97d.dcm',
#  'ID_02bb77af2.dcm',
#  'ID_c83804a45.dcm',
#  'ID_455542d9a.dcm',
#  'ID_a0e234c10.dcm',
#  'ID_17df46afd.dcm',
#  'ID_c1cb038c0.dcm',
#  'ID_49c56d671.dcm',
#  'ID_c2a75c7fb.dcm',
#  'ID_587cf6b7a.dcm',
#  'ID_4e3781372.dcm',
#  'ID_4f7a2e8e4.dcm',
#  'ID_2362d2977.dcm',
#  'ID_00fbf77ca.dcm',
#  'ID_cc925efc2.dcm',
#  'ID_91c1555bc.dcm',
#  'ID_267ed4ea4.dcm',
#  'ID_0c6d94e30.dcm',
#  'ID_20a39fd11.dcm',
#  'ID_b5e8217c3.dcm',
#  'ID_4ddba184f.dcm',
#  'ID_41e9b4a7e.dcm',
#  'ID_d66ad522b.dcm',
#  'ID_fbb23254f.dcm',
#  'ID_23565a7bf.dcm',
#  'ID_03322cff2.dcm',
#  'ID_e28d1efea.dcm',
#  'ID_2c68c5a3b.dcm',
#  'ID_57c27bb56.dcm',
#  'ID_e35209688.dcm',
#  'ID_4b016a3ee.dcm',
#  'ID_484c1f855.dcm',
#  'ID_eb74ea25d.dcm',
#  'ID_ac2c9c8d0.dcm',
#  'ID_9256c2201.dcm',
#  'ID_a2bcf7b57.dcm',
#  'ID_a33d1e362.dcm',
#  'ID_fd4035721.dcm',
#  'ID_01b612d2d.dcm',
#  'ID_bd4a373e0.dcm',
#  'ID_2c97dd555.dcm',
#  'ID_7ad9d4827.dcm',
#  'ID_f556b9f8e.dcm',
#  'ID_c7a9ba9a9.dcm',
#  'ID_9e46bcdee.dcm',
#  'ID_028099493.dcm',
#  'ID_47754adaf.dcm',
#  'ID_9c7816318.dcm',
#  'ID_2f6ce1391.dcm',
#  'ID_134b8fec4.dcm',
#  'ID_738056ada.dcm',
#  'ID_4380390c0.dcm',
#  'ID_da5d79d48.dcm',
#  'ID_479e761a5.dcm',
#  'ID_d6a01fe32.dcm',
#  'ID_22afacb8c.dcm',
#  'ID_fb0591be5.dcm',
#  'ID_e11238f01.dcm',
#  'ID_2b4a73eba.dcm',
#  'ID_8951532dc.dcm',
#  'ID_a85b189cf.dcm',
#  'ID_42b068699.dcm',
#  'ID_c0c9dc6f1.dcm',
#  'ID_4833c117b.dcm',
#  'ID_e3cd26eed.dcm',
#  'ID_69848f96d.dcm',
#  'ID_f6e48f2a5.dcm',
#  'ID_6a822fe2a.dcm',
#  'ID_762e87df7.dcm',
#  'ID_4239095bd.dcm',
#  'ID_dabd52dc4.dcm',
#  'ID_61905cfae.dcm',
#  'ID_5fc3fd8f1.dcm',
#  'ID_98bf56f29.dcm',
#  'ID_92ed3362c.dcm',
#  'ID_55b6d15cd.dcm',
#  'ID_3fd17ef4f.dcm',
#  'ID_c975abaf2.dcm',
#  'ID_679befe78.dcm',
#  'ID_b017fe9aa.dcm',
#  'ID_c49a39a3e.dcm',
#  'ID_f15a4a40b.dcm',
#  'ID_ec65bfa2d.dcm',
#  'ID_ff38afe24.dcm',
#  'ID_b58e95552.dcm',
#  'ID_dd822f39e.dcm',
#  'ID_e07c2e258.dcm',
#  'ID_1a56be3f0.dcm',
#  'ID_26fd876ff.dcm',
#  'ID_de5b439db.dcm',
#  'ID_3f672f61b.dcm',
#  'ID_910ad62ff.dcm',
#  'ID_db4301e55.dcm',
#  'ID_49c5e213e.dcm',
#  'ID_454cacd1e.dcm',
#  'ID_3c6d76255.dcm',
#  'ID_1bdab373c.dcm',
#  'ID_ad3ebc03d.dcm',
#  'ID_2c916e8a8.dcm',
#  'ID_d5d3645a5.dcm',
#  'ID_de08d39f0.dcm',
#  'ID_946b829f7.dcm',
#  'ID_628340c9f.dcm',
#  'ID_4fc1ae821.dcm',
#  'ID_cb13b1674.dcm',
#  'ID_bd442e90a.dcm',
#  'ID_a6bbec0ab.dcm',
#  'ID_cce57265f.dcm',
#  'ID_167db2c88.dcm',
#  'ID_7a6b39478.dcm',
#  'ID_f81164cb0.dcm',
#  'ID_01c23833c.dcm',
#  'ID_0b3299a73.dcm',
#  'ID_92e4165ff.dcm',
#  'ID_eba13fe34.dcm',
#  'ID_6d6d35606.dcm',
#  'ID_00bb816c7.dcm',
#  'ID_3eb90a4f2.dcm',
#  'ID_d2dbef02c.dcm',
#  'ID_7f8b4a98a.dcm',
#  'ID_95a0a240a.dcm',
#  'ID_0db391528.dcm',
#  'ID_45fe0128a.dcm',
#  'ID_f88058bbb.dcm',
#  'ID_c0e34d761.dcm',
#  'ID_6362ef8db.dcm',
#  'ID_71e4033fb.dcm',
#  'ID_16d39f443.dcm',
#  'ID_41ce18976.dcm',
#  'ID_b82fad0d4.dcm',
#  'ID_925207c19.dcm',
#  'ID_f46868e6e.dcm',
#  'ID_dc8bfecf1.dcm',
#  'ID_f8ab24617.dcm',
#  'ID_203095615.dcm',
#  'ID_b57475eb1.dcm',
#  'ID_07fc48135.dcm',
#  'ID_f869c9cf9.dcm',
#  'ID_481d914da.dcm',
#  'ID_061e34294.dcm',
#  'ID_1ad734eee.dcm',
#  'ID_d94e21298.dcm',
#  'ID_c88f115b1.dcm',
#  'ID_ac81a3e35.dcm',
#  'ID_302b020a0.dcm',
#  'ID_4fdde9920.dcm',
#  'ID_7f5a49d28.dcm',
#  'ID_1254452f7.dcm',
#  'ID_81c4ec3ea.dcm',
#  'ID_3ca72c066.dcm',
#  'ID_7abd5ee82.dcm',
#  'ID_f59a25696.dcm',
#  'ID_d32ed3a77.dcm',
#  'ID_b1e6f5702.dcm',
#  'ID_a75c8759c.dcm',
#  'ID_9dec0740e.dcm',
#  'ID_93d0ab9e0.dcm',
#  'ID_117b09d07.dcm',
#  'ID_4c0d2501c.dcm',
#  'ID_a080edb1d.dcm',
#  'ID_a4f0e97d7.dcm',
#  'ID_10b5be557.dcm',
#  'ID_01e9ec989.dcm',
#  'ID_3feff2402.dcm',
#  'ID_a4fb4c65e.dcm',
#  'ID_d4626abce.dcm',
#  'ID_c466cdc3a.dcm',
#  'ID_b99b4b4cf.dcm',
#  'ID_014598a2d.dcm',
#  'ID_41b973f39.dcm',
#  'ID_98fcbfe3b.dcm',
#  'ID_81273608a.dcm',
#  'ID_1635fb404.dcm',
#  'ID_838139023.dcm',
#  'ID_3ff1b9d27.dcm',
#  'ID_586af7ae5.dcm',
#  'ID_5456ec4f8.dcm',
#  'ID_98ac4cd0b.dcm',
#  'ID_7655185bc.dcm',
#  'ID_078b25c8a.dcm',
#  'ID_30ad30f73.dcm',
#  'ID_9e968ac3a.dcm',
#  'ID_ecc60dba9.dcm',
#  'ID_5db182cde.dcm',
#  'ID_b1c008cf7.dcm',
#  'ID_541966737.dcm',
#  'ID_77db470e6.dcm',
#  'ID_28df4635c.dcm',
#  'ID_4a054b3e5.dcm',
#  'ID_37f1a6617.dcm',
#  'ID_2d865595f.dcm',
#  'ID_1bf6cb677.dcm',
#  'ID_b20ba84f2.dcm',
#  'ID_5f8051c32.dcm',
#  'ID_d43ac760a.dcm',
#  'ID_b169959e1.dcm',
#  'ID_ef0096158.dcm',
#  'ID_47667fd22.dcm',
#  'ID_b49a47d15.dcm',
#  'ID_63e9066cf.dcm',
#  'ID_6fc98e0d8.dcm',
#  'ID_a16bd7fd9.dcm',
#  'ID_2a28376c8.dcm',
#  'ID_24601ff3b.dcm',
#  'ID_d872ec055.dcm',
#  'ID_770de1b73.dcm',
#  'ID_1098d55a1.dcm',
#  'ID_17dd1229a.dcm',
#  'ID_466ff3ad2.dcm',
#  'ID_93d67dee2.dcm',
#  'ID_6dd822783.dcm',
#  'ID_605174028.dcm',
#  'ID_f9e07e1ab.dcm',
#  'ID_8587d0a87.dcm',
#  'ID_05574ff36.dcm',
#  'ID_a3bb04aae.dcm',
#  'ID_5a233c87a.dcm',
#  'ID_0dde1faaa.dcm',
#  'ID_45dfaf73a.dcm',
#  'ID_9c169d127.dcm',
#  'ID_5ae8c7cc2.dcm',
#  'ID_4157ec1ae.dcm',
#  'ID_45d9e5f88.dcm',
#  'ID_4a8689509.dcm',
#  'ID_144a8b8dd.dcm',
#  'ID_934fa7dad.dcm',
#  'ID_b481e36cc.dcm',
#  'ID_a43d070f8.dcm',
#  'ID_54ed94e4f.dcm',
#  'ID_a30486527.dcm',
#  'ID_6662c0e06.dcm',
#  'ID_a7d313e48.dcm',
#  'ID_08af3f6fb.dcm',
#  'ID_4b12de9b0.dcm',
#  'ID_6d74caa44.dcm',
#  'ID_d1a263950.dcm',
#  'ID_77b9c3957.dcm',
#  'ID_06188d9d9.dcm',
#  'ID_f4f146492.dcm',
#  'ID_f6bd49722.dcm',
#  'ID_3ce435710.dcm',
#  'ID_832017dbe.dcm',
#  'ID_8f3bed033.dcm',
#  'ID_4957613b6.dcm',
#  'ID_3ad001848.dcm',
#  'ID_fed2d2eb1.dcm',
#  'ID_6dd7e984e.dcm',
#  'ID_b48855bba.dcm',
#  'ID_b6da5759b.dcm',
#  'ID_0eb65a613.dcm',
#  'ID_57eac34f5.dcm',
#  'ID_1e0db5600.dcm',
#  'ID_e5de2ec5f.dcm',
#  'ID_effdfe073.dcm',
#  'ID_d0ee5b2f4.dcm',
#  'ID_88b5abe04.dcm',
#  'ID_e118e9e72.dcm',
#  'ID_4eed3740f.dcm',
#  'ID_91de7adba.dcm',
#  'ID_8280057fd.dcm',
#  'ID_e8ca8b889.dcm',
#  'ID_2326df0d2.dcm',
#  'ID_5dabfefd2.dcm',
#  'ID_6add86ae9.dcm',
#  'ID_a41350547.dcm',
#  'ID_008e000da.dcm',
#  'ID_e04f8ad6f.dcm',
#  'ID_f6a72bc50.dcm',
#  'ID_21360bfec.dcm',
#  'ID_bcd22f2bc.dcm',
#  'ID_79ab6fcfc.dcm',
#  'ID_4fe8761ed.dcm',
#  'ID_7d7b2f409.dcm',
#  'ID_fe3f1935e.dcm',
#  'ID_0234626e3.dcm',
#  'ID_f72672aeb.dcm',
#  'ID_85ad52519.dcm',
#  'ID_ed542cfb3.dcm',
#  'ID_4267fd580.dcm',
#  'ID_ec8cf1eac.dcm',
#  'ID_3c3ae3745.dcm',
#  'ID_cf09a0566.dcm',
#  'ID_a18d3d6a0.dcm',
#  'ID_77c949276.dcm',
#  'ID_dd54a7618.dcm',
#  'ID_13e81513f.dcm',
#  'ID_a2345fbb3.dcm',
#  'ID_3373489d4.dcm',
#  'ID_fe68499d5.dcm',
#  'ID_271595058.dcm',
#  'ID_e1cac9d1f.dcm',
#  'ID_3267a0e06.dcm',
#  'ID_bfb82d89a.dcm',
#  'ID_3a5c89221.dcm',
#  'ID_17dd44edb.dcm',
#  'ID_d4a8cca51.dcm',
#  'ID_8354b7bf2.dcm',
#  'ID_272b7e61a.dcm',
#  'ID_fedafa2b6.dcm',
#  'ID_630f6a22b.dcm',
#  'ID_e4f01d37a.dcm',
#  'ID_f0ed6ae2e.dcm',
#  'ID_458d50462.dcm',
#  'ID_6d2f3efcf.dcm',
#  'ID_76cbc86c8.dcm',
#  'ID_94e1f475c.dcm',
#  'ID_dfe0a736f.dcm',
#  'ID_050f1a4c5.dcm',
#  'ID_9fdb5105a.dcm',
#  'ID_6517c81a3.dcm',
#  'ID_979457304.dcm',
#  'ID_200415034.dcm',
#  'ID_8ddf70c38.dcm',
#  'ID_102e9d995.dcm',
#  'ID_ab313bcd2.dcm',
#  'ID_c61173303.dcm',
#  'ID_2c74bcf51.dcm',
#  'ID_da16c09be.dcm',
#  'ID_dffb0c4e7.dcm',
#  'ID_c5a5a6ccf.dcm',
#  'ID_d5c8dee3b.dcm',
#  'ID_cff25262d.dcm',
#  'ID_4762b04d3.dcm',
#  'ID_7835931d5.dcm',
#  'ID_22a997467.dcm',
#  'ID_1cfd0e74e.dcm',
#  'ID_c89439628.dcm',
#  'ID_0691d53f5.dcm',
#  'ID_b0be9cc18.dcm',
#  'ID_32ce29a0e.dcm',
#  'ID_49c233432.dcm',
#  'ID_a094df2cd.dcm',
#  'ID_ea9920006.dcm',
#  'ID_4d69e27d0.dcm',
#  'ID_5558e5bd7.dcm',
#  'ID_0ca48b3e7.dcm',
#  'ID_687160a34.dcm',
#  'ID_d37d101a5.dcm',
#  'ID_6070fadb2.dcm',
#  'ID_109f2da41.dcm',
#  'ID_196af1fc9.dcm',
#  'ID_3fc56fdd9.dcm',
#  'ID_66477f42d.dcm',
#  'ID_a1618faec.dcm',
#  'ID_dfd766bea.dcm',
#  'ID_55e5854f7.dcm',
#  'ID_e086411c6.dcm',
#  'ID_28efeda9a.dcm',
#  'ID_3077f0bd2.dcm',
#  'ID_892495a4f.dcm',
#  'ID_57c2106f6.dcm',
#  'ID_1157eddd0.dcm',
#  'ID_c8eb0c7a8.dcm',
#  'ID_95966d742.dcm',
#  'ID_9f9944519.dcm',
#  'ID_b48225e17.dcm',
#  'ID_b7763f6ec.dcm',
#  'ID_302fa4316.dcm',
#  'ID_3310ceb05.dcm',
#  'ID_26b83653c.dcm',
#  'ID_4f58f5b6c.dcm',
#  'ID_bd57ed15f.dcm',
#  'ID_79960ac3f.dcm',
#  'ID_1c29537aa.dcm',
#  'ID_67c1475a9.dcm',
#  'ID_109211035.dcm',
#  'ID_5f6cea4c1.dcm',
#  'ID_f1235b1e5.dcm',
#  'ID_4a8d7e2bd.dcm',
#  'ID_8b517bfa5.dcm',
#  'ID_eed2f4f0d.dcm',
#  'ID_cfeb8189c.dcm',
#  'ID_4282d42e7.dcm',
#  'ID_3be48b3ed.dcm',
#  'ID_1c40dbfc7.dcm',
#  'ID_80bffc6c3.dcm',
#  'ID_0289b1b85.dcm',
#  'ID_40a25bab6.dcm',
#  'ID_90483ea45.dcm',
#  'ID_7689d91d0.dcm',
#  'ID_617ee9fe3.dcm',
#  'ID_aa4d750c1.dcm',
#  'ID_ee587913b.dcm',
#  'ID_cfc68de9c.dcm',
#  'ID_63578aed5.dcm',
#  'ID_1dbc110c0.dcm',
#  'ID_dac56567f.dcm',
#  'ID_cdb904f17.dcm',
#  'ID_5d174294f.dcm',
#  'ID_7c1e2b4f5.dcm',
#  'ID_4423964f0.dcm',
#  'ID_f22d559e7.dcm',
#  'ID_d12c045a8.dcm',
#  'ID_db5a87911.dcm',
#  'ID_d18bfed24.dcm',
#  'ID_025564aa2.dcm',
#  'ID_c1c6d51b0.dcm',
#  'ID_ac123362c.dcm',
#  'ID_59178d086.dcm',
#  'ID_b04141c1f.dcm',
#  'ID_bcc8676ef.dcm',
#  'ID_461bc7855.dcm',
#  'ID_3b46b288e.dcm',
#  'ID_59b40a654.dcm',
#  'ID_7310f4447.dcm',
#  'ID_eafbe8234.dcm',
#  'ID_b2480ba22.dcm',
#  'ID_049f4d565.dcm',
#  'ID_b25a4c919.dcm',
#  'ID_db2694f3f.dcm',
#  'ID_6984df224.dcm',
#  'ID_b5c06c51b.dcm',
#  'ID_51b77d240.dcm',
#  'ID_b07c1b53e.dcm',
#  'ID_a890be0c6.dcm',
#  'ID_1d10d0396.dcm',
#  'ID_f2b2259b3.dcm',
#  'ID_fe383483c.dcm',
#  'ID_c1c618522.dcm',
#  'ID_1cbf8469a.dcm',
#  'ID_cce277131.dcm',
#  'ID_76f7f41e9.dcm',
#  'ID_99865be50.dcm',
#  'ID_3d3b8e320.dcm',
#  'ID_21bc10e37.dcm',
#  'ID_0702fd9bc.dcm',
#  'ID_e115f286f.dcm',
#  'ID_1a79f7d56.dcm',
#  'ID_8f302c5ba.dcm',
#  'ID_c51adb043.dcm',
#  'ID_af3ef9c1d.dcm',
#  'ID_e77f5ec6d.dcm',
#  'ID_e1c39fc89.dcm',
#  'ID_5d10991df.dcm',
#  'ID_1dc25e164.dcm',
#  'ID_8f0380d63.dcm',
#  'ID_8c068caa6.dcm',
#  'ID_8dee0baa0.dcm',
#  'ID_4fee374d9.dcm',
#  'ID_f289e0673.dcm',
#  'ID_115861381.dcm',
#  'ID_d340b3f79.dcm',
#  'ID_d1bf41d77.dcm',
#  'ID_75e36e92f.dcm',
#  'ID_47dab30a8.dcm',
#  'ID_a4dff2472.dcm',
#  'ID_4a0008083.dcm',
#  'ID_e86a944b8.dcm',
#  'ID_93ea4a0df.dcm',
#  'ID_9f8d7e0de.dcm',
#  'ID_685ca0f22.dcm',
#  'ID_7cb943cc7.dcm',
#  'ID_5ce7d303d.dcm',
#  'ID_44bdbb6a7.dcm',
#  'ID_772f9ad5f.dcm',
#  'ID_799bb070b.dcm',
#  'ID_0b7ec569e.dcm',
#  'ID_233b98849.dcm',
#  'ID_dca9f6903.dcm',
#  'ID_7b7e36019.dcm',
#  'ID_3a339c946.dcm',
#  'ID_c50ee289b.dcm',
#  'ID_15692be3e.dcm',
#  'ID_99dfe636d.dcm',
#  'ID_8a1693e09.dcm',
#  'ID_183a71ae6.dcm',
#  'ID_0cbcdfea3.dcm',
#  'ID_41efe9777.dcm',
#  'ID_0b0265d0a.dcm',
#  'ID_909ca65c2.dcm',
#  'ID_adf544059.dcm',
#  'ID_4ea19434d.dcm',
#  'ID_aac7398e3.dcm',
#  'ID_dc237482a.dcm',
#  'ID_0f1181883.dcm',
#  'ID_bc7a89e1b.dcm',
#  'ID_c784d2845.dcm',
#  'ID_20d8b570e.dcm',
#  'ID_874d6a875.dcm',
#  'ID_02f7810c8.dcm',
#  'ID_6765a3879.dcm',
#  'ID_a556ffd18.dcm',
#  'ID_cb9040ed1.dcm',
#  'ID_2ea91eeb9.dcm',
#  'ID_78bcde0cd.dcm',
#  'ID_ab8aec932.dcm',
#  'ID_3765116dd.dcm',
#  'ID_1766258bd.dcm',
#  'ID_c98609a39.dcm',
#  'ID_bc43b1a2f.dcm',
#  'ID_d319350d0.dcm',
#  'ID_0cb4421fa.dcm',
#  'ID_46ad768c6.dcm',
#  'ID_28c0eaaf3.dcm',
#  'ID_a963c062e.dcm',
#  'ID_7f4f572f9.dcm',
#  'ID_792493278.dcm',
#  'ID_71f85dd7f.dcm',
#  'ID_48abba346.dcm',
#  'ID_0ad02d666.dcm',
#  'ID_76c58f1e7.dcm',
#  'ID_54e25d118.dcm',
#  'ID_3cb33e908.dcm',
#  'ID_af501a831.dcm',
#  'ID_a6ae984de.dcm',
#  'ID_7b26b1fa1.dcm',
#  'ID_ee8baffa8.dcm',
#  'ID_833a057c5.dcm',
#  'ID_3cf8fd4a4.dcm',
#  'ID_801cfd15c.dcm',
#  'ID_a5a21aced.dcm',
#  'ID_1adf2a2f5.dcm',
#  'ID_1b4e40479.dcm',
#  'ID_ae4e161c5.dcm',
#  'ID_35132f0eb.dcm',
#  'ID_54d5c266f.dcm',
#  'ID_484156b02.dcm',
#  'ID_38ec62164.dcm',
#  'ID_7ee2bfb7a.dcm',
#  'ID_baf819781.dcm',
#  'ID_79e21a959.dcm',
#  'ID_a428e6e86.dcm',
#  'ID_3b7f9014a.dcm',
#  'ID_2570be225.dcm',
#  'ID_af1e81ca9.dcm',
#  'ID_433be80d0.dcm',
#  'ID_9138d9e05.dcm',
#  'ID_d8a6e1b0c.dcm',
#  'ID_88ba7bf9e.dcm',
#  'ID_c1b23f05a.dcm',
#  'ID_7eaf1105c.dcm',
#  'ID_1777c68bf.dcm',
#  'ID_663ce4595.dcm',
#  'ID_1ab81ac9b.dcm',
#  'ID_4aa9d9187.dcm',
#  'ID_80c0ef856.dcm',
#  'ID_62b1106c0.dcm',
#  'ID_f511147a6.dcm',
#  'ID_e1d001185.dcm',
#  'ID_10ed36231.dcm',
#  'ID_a003a12f1.dcm',
#  'ID_1efc42fd7.dcm',
#  'ID_cfb27d806.dcm',
#  'ID_e0192d560.dcm',
#  'ID_6258b9118.dcm',
#  'ID_31e4177bf.dcm',
#  'ID_00d3a9006.dcm',
#  'ID_b5c129cff.dcm',
#  'ID_561786896.dcm',
#  'ID_59d0686c2.dcm',
#  'ID_a1351bd0e.dcm',
#  'ID_f3ed36295.dcm',
#  'ID_be6d3d704.dcm',
#  'ID_edb9bc320.dcm',
#  'ID_385593da7.dcm',
#  'ID_be761d246.dcm',
#  'ID_8eeb69a00.dcm',
#  'ID_34c94c18f.dcm',
#  'ID_03981faca.dcm',
#  'ID_9fd9b04fc.dcm',
#  'ID_8fda7875c.dcm',
#  'ID_a121981db.dcm',
#  'ID_9eee08c14.dcm',
#  'ID_cff1b8970.dcm',
#  'ID_5cb176bf2.dcm',
#  'ID_f38ed07cf.dcm',
#  'ID_9ff0a1f84.dcm',
#  'ID_0d97af2ba.dcm',
#  'ID_7932e7191.dcm',
#  'ID_617e49305.dcm',
#  'ID_c7d8738a3.dcm',
#  'ID_d3f87a2dc.dcm',
#  'ID_75847e845.dcm',
#  'ID_6d16c54fd.dcm',
#  'ID_be2b6e0f2.dcm',
#  'ID_b103df7c0.dcm',
#  'ID_9dd8d7b4c.dcm',
#  'ID_de8ebb06c.dcm',
#  'ID_2db50a194.dcm',
#  'ID_83b2d75a1.dcm',
#  'ID_2666251b1.dcm',
#  'ID_94cc8ec6a.dcm',
#  'ID_8420a6e95.dcm',
#  'ID_a57790b39.dcm',
#  'ID_28f7b6d63.dcm',
#  'ID_dcc6ea3d0.dcm',
#  'ID_da375bd3c.dcm',
#  'ID_794828004.dcm',
#  'ID_33151eae8.dcm',
#  'ID_599d3447e.dcm',
#  'ID_87a15d5f3.dcm',
#  'ID_9ea51d710.dcm',
#  'ID_222bba0c9.dcm',
#  'ID_b747ccfec.dcm',
#  'ID_e48f81aaa.dcm',
#  'ID_34ba7490f.dcm',
#  'ID_ef05f3c6d.dcm',
#  'ID_45bd3da5d.dcm',
#  'ID_823b58f94.dcm',
#  'ID_ba7db1cf4.dcm',
#  'ID_a59187df2.dcm',
#  'ID_773654b1f.dcm',
#  'ID_47a146953.dcm',
#  'ID_83fa9f821.dcm',
#  'ID_faeafdf55.dcm',
#  'ID_e034ff7df.dcm',
#  'ID_f7d0b7590.dcm',
#  'ID_88fb981e2.dcm',
#  'ID_4fde01d24.dcm',
#  'ID_b8b6ad81a.dcm',
#  'ID_976300b95.dcm',
#  'ID_eee05a76b.dcm',
#  'ID_25963b03b.dcm',
#  'ID_2e311a789.dcm',
#  'ID_30642e2a5.dcm',
#  'ID_378404e01.dcm',
#  'ID_33ac50d91.dcm',
#  'ID_1c99fdc16.dcm',
#  'ID_0b704878a.dcm',
#  'ID_37cbef2fe.dcm',
#  'ID_f1fda0d99.dcm',
#  'ID_c1145c6c0.dcm',
#  'ID_74388dca2.dcm',
#  'ID_c056a2e55.dcm',
#  'ID_e525df03f.dcm',
#  'ID_d1ea73306.dcm',
#  'ID_ed72efd8f.dcm',
#  'ID_45d361ee1.dcm',
#  'ID_8d8139c71.dcm',
#  'ID_a9bc481d2.dcm',
#  'ID_dfa9fe3f0.dcm',
#  'ID_92fd0b89c.dcm',
#  'ID_22c07e3eb.dcm',
#  'ID_be3f30e32.dcm',
#  'ID_94f29144d.dcm',
#  'ID_20c322c29.dcm',
#  'ID_75c55cb11.dcm',
#  'ID_5f0166eb3.dcm',
#  'ID_98f4d7c54.dcm',
#  'ID_b61e42d08.dcm',
#  'ID_1c4e212fa.dcm',
#  'ID_d6c413310.dcm',
#  'ID_cddfd4cc6.dcm',
#  'ID_62fdb78a8.dcm',
#  'ID_3cdd550b9.dcm',
#  'ID_f99d9af77.dcm',
#  'ID_90ff2087d.dcm',
#  'ID_03c476e68.dcm',
#  'ID_624d1aa0d.dcm',
#  'ID_438eb5f4c.dcm',
#  'ID_e88d48018.dcm',
#  'ID_4c2b528ec.dcm',
#  'ID_4a5d99cf0.dcm',
#  'ID_10833b6d3.dcm',
#  'ID_f615cf689.dcm',
#  'ID_161ac113e.dcm',
#  'ID_94c3d7c30.dcm',
#  'ID_0d52f1134.dcm',
#  'ID_e8492e11d.dcm',
#  'ID_ea875c2d2.dcm',
#  'ID_fb9a502cc.dcm',
#  'ID_047f87535.dcm',
#  'ID_1949b20e1.dcm',
#  'ID_70cd89b6e.dcm',
#  'ID_296d96358.dcm',
#  'ID_4b5dfe0fd.dcm',
#  'ID_96e106dc1.dcm',
#  'ID_29d7cda92.dcm',
#  'ID_07ec2ff3d.dcm',
#  'ID_ef7df244d.dcm',
#  'ID_1c45cebe8.dcm',
#  'ID_75432a5a3.dcm',
#  'ID_b1dd5aef3.dcm',
#  'ID_fb79971b1.dcm',
#  'ID_eb77b8f49.dcm',
#  'ID_ee409bee6.dcm',
#  'ID_35ca03c08.dcm',
#  'ID_4ecec0f54.dcm',
#  'ID_0632e3d24.dcm',
#  'ID_76e783029.dcm',
#  'ID_b05c6842b.dcm',
#  'ID_cb4ca206c.dcm',
#  'ID_f4d8534b1.dcm',
#  'ID_bccf40ed9.dcm',
#  'ID_4593c4dc4.dcm',
#  'ID_4caf0ab8d.dcm',
#  'ID_85c6b0fe1.dcm',
#  'ID_ff22a4d06.dcm',
#  'ID_14264f0cb.dcm',
#  'ID_5b2c58bc9.dcm',
#  'ID_057524aaf.dcm',
#  'ID_b88d0a324.dcm',
#  'ID_28805a87b.dcm',
#  'ID_010050ce4.dcm',
#  'ID_a9aefd58c.dcm',
#  'ID_3c88012c1.dcm',
#  'ID_c2c1f5bdc.dcm',
#  'ID_35eb0d355.dcm',
#  'ID_330f5b238.dcm',
#  'ID_4347f8a62.dcm',
#  'ID_bda2356dd.dcm',
#  'ID_ed698d7b5.dcm',
#  'ID_9083724db.dcm',
#  'ID_e5951abd0.dcm',
#  'ID_3105f9160.dcm',
#  'ID_4f4b30c07.dcm',
#  'ID_a84afc3f8.dcm',
#  'ID_afa4566c1.dcm',
#  'ID_afb2315d2.dcm',
#  'ID_d04fa52d9.dcm',
#  'ID_940a1d8cc.dcm',
#  'ID_e9a10b5ea.dcm',
#  'ID_e342ae1b7.dcm',
#  'ID_5b606c10f.dcm',
#  'ID_f2184c721.dcm',
#  'ID_69d207c52.dcm',
#  'ID_7555d56ed.dcm',
#  'ID_b8e7b4c28.dcm',
#  'ID_e9c90195b.dcm',
#  'ID_8f7324119.dcm',
#  'ID_589cd9a1c.dcm',
#  'ID_c5080ac80.dcm',
#  'ID_2d7971080.dcm',
#  'ID_7a92d94f7.dcm',
#  'ID_83cf03648.dcm',
#  'ID_963e7abf3.dcm',
#  'ID_0969270fa.dcm',
#  'ID_100e1c64c.dcm',
#  'ID_fe2947313.dcm',
#  'ID_b01f29313.dcm',
#  'ID_f1b11e453.dcm',
#  'ID_79e98c6a4.dcm',
#  'ID_795a57416.dcm',
#  'ID_0429abb5e.dcm',
#  'ID_502a01ee1.dcm',
#  'ID_7b17697d1.dcm',
#  'ID_4fb3c3425.dcm',
#  'ID_099a1dc2f.dcm',
#  'ID_39f914c62.dcm',
#  'ID_bf5053c61.dcm',
#  'ID_a81f1d140.dcm',
#  'ID_bc36ef5e7.dcm',
#  'ID_4605b02dd.dcm',
#  'ID_2f116ca4c.dcm',
#  'ID_e4581cd48.dcm',
#  'ID_b710010bc.dcm',
#  'ID_2a089f8f1.dcm',
#  'ID_02aac33c8.dcm',
#  'ID_5b1a98859.dcm',
#  'ID_1a13b1e77.dcm',
#  'ID_d0777d3b9.dcm',
#  'ID_800e54da1.dcm',
#  'ID_0e7a32ea5.dcm',
#  'ID_4887f20d2.dcm',
#  'ID_f7ad14c7b.dcm',
#  'ID_a08d9ec29.dcm',
#  'ID_a048ecfe0.dcm',
#  'ID_55e294f41.dcm',
#  'ID_c46824fe8.dcm',
#  'ID_2425a807a.dcm',
#  'ID_af8406d1e.dcm',
#  'ID_b49667182.dcm',
#  'ID_16fc6be4a.dcm',
#  'ID_51de04c37.dcm',
#  'ID_a2d9a6113.dcm',
#  'ID_20cd658a9.dcm',
#  'ID_7c9fae3ab.dcm',
#  'ID_7151110de.dcm',
#  'ID_2824603dd.dcm',
#  'ID_4e7bf032e.dcm',
#  'ID_ee941e986.dcm',
#  'ID_760a15af4.dcm',
#  'ID_fae883e10.dcm',
#  'ID_e4f471f7c.dcm',
#  'ID_8ecb26720.dcm',
#  'ID_a1442732d.dcm',
#  'ID_38ff6d9f7.dcm',
#  'ID_3a0e4639f.dcm',
#  'ID_f1d0fddd4.dcm',
#  'ID_119e41bfc.dcm',
#  'ID_97d652517.dcm',
#  'ID_50093d4db.dcm',
#  'ID_a8d635cdf.dcm',
#  'ID_357bd1db9.dcm',
#  'ID_51983acc8.dcm',
#  'ID_c55040c38.dcm',
#  'ID_4052e447c.dcm',
#  'ID_6d4832b72.dcm',
#  'ID_c6a477945.dcm',
#  'ID_96a19375b.dcm',
#  'ID_b70d52add.dcm',
#  'ID_e11a1d077.dcm',
#  'ID_6921277d5.dcm',
#  'ID_d10bc265a.dcm',
#  'ID_de878c2a8.dcm',
#  'ID_57308f327.dcm',
#  'ID_be5eec59c.dcm',
#  'ID_8df287628.dcm',
#  'ID_346c43c12.dcm',
#  'ID_39ae3a15f.dcm',
#  'ID_eab49013e.dcm',
#  'ID_b199adcd6.dcm',
#  'ID_7598e9fe2.dcm',
#  'ID_c6b0996a9.dcm',
#  'ID_5f9b73977.dcm',
#  'ID_faee6c984.dcm',
#  'ID_3a183c0c9.dcm',
#  'ID_485fd90dd.dcm',
#  'ID_8b8b1e941.dcm',
#  'ID_7a13e8746.dcm',
#  'ID_2905f29fe.dcm',
#  'ID_b11d923b5.dcm',
#  'ID_0deb3a700.dcm',
#  'ID_bf73543ae.dcm',
#  'ID_e0cb23ac3.dcm',
#  'ID_f351ae411.dcm',
#  'ID_70621f547.dcm',
#  'ID_ee4825d16.dcm',
#  'ID_911e0d667.dcm',
#  'ID_ff2bca9f6.dcm',
#  'ID_9fea77f6c.dcm',
#  'ID_1c77d2820.dcm',
#  'ID_b99a4f288.dcm',
#  'ID_89e0b0215.dcm',
#  'ID_67adbfd01.dcm',
#  'ID_cb0e199fa.dcm',
#  'ID_b2f928c0a.dcm',
#  'ID_070d3f752.dcm',
#  'ID_f4a7adff5.dcm',
#  'ID_03fabb133.dcm',
#  'ID_95c2c2a36.dcm',
#  'ID_98d87e303.dcm',
#  'ID_8c1d23539.dcm',
#  'ID_e20a83993.dcm',
#  ...]

# %%
a = df_trn.PatientID.value_counts().reset_index()
a.columns = ['PatientID', 'num']

# %%
sub1 = pd.read_csv(path/'stage_1_sample_submission.csv')
sub1['fn'] = sub1.ID.apply(lambda x: '_'.join(x.split('_')[:2]) + '.dcm')
sub1.columns = ['ID', 'probability', 'fn']
sub1['label'] = sub1.ID.apply(lambda x: x.split('_')[-1])
sub1.drop_duplicates('ID', inplace=True)
sub = sub1.pivot(index='fn', columns='label', values='probability')
sub.reset_index(inplace=True)
sub
# Out:
# label                fn  any  epidural  intraparenchymal  intraventricular  \
# 0      ID_000012eaf.dcm  0.5       0.5               0.5               0.5
# 1      ID_0000ca2f6.dcm  0.5       0.5               0.5               0.5
# 2      ID_000259ccf.dcm  0.5       0.5               0.5               0.5
# 3      ID_0002d438a.dcm  0.5       0.5               0.5               0.5
# 4      ID_00032d440.dcm  0.5       0.5               0.5               0.5
# ...                 ...  ...       ...               ...               ...
# 78540  ID_fffe2edb8.dcm  0.5       0.5               0.5               0.5
# 78541  ID_ffff3212e.dcm  0.5       0.5               0.5               0.5
# 78542  ID_ffff59a97.dcm  0.5       0.5               0.5               0.5
# 78543  ID_ffffb670a.dcm  0.5       0.5               0.5               0.5
# 78544  ID_ffffcbff8.dcm  0.5       0.5               0.5               0.5
#
# label  subarachnoid  subdural
# 0               0.5       0.5
# 1               0.5       0.5
# 2               0.5       0.5
# 3               0.5       0.5
# 4               0.5       0.5
# ...             ...       ...
# 78540           0.5       0.5
# 78541           0.5       0.5
# 78542           0.5       0.5
# 78543           0.5       0.5
# 78544           0.5       0.5
#
# [78545 rows x 7 columns]

# %%
val_ID = a.PatientID[3::5].tolist()
val_img = df_trn[df_trn.PatientID.isin(val_ID)].SOPInstanceUID.tolist()
val_img = [s + '.dcm' for s in val_img]
df_train.loc[~(df_train.fn.isin(val_img)), 'is_valid'] = True
df_train.loc[df_train.fn.isin(val_img), 'is_valid'] = False
df_train.reset_index(drop=True, inplace=True)
df_train
# Out:
#                       fn                                      labels is_valid
# 0       ID_63eb1e259.dcm                                                 True
# 1       ID_2669954a7.dcm                                                 True
# 2       ID_52c9913b1.dcm                                                False
# 3       ID_4e6ff6126.dcm                                                 True
# 4       ID_7858edd88.dcm                                                False
# ...                  ...                                         ...      ...
# 591938  ID_6a6cd0773.dcm                                                 True
# 591939  ID_f737f4cc1.dcm                                                 True
# 591940  ID_a9797cb3a.dcm                                                 True
# 591941  ID_9375f67bd.dcm                                                 True
# 591942  ID_5c8b5d701.dcm  intraparenchymal subarachnoid subdural any     True
#
# [591943 rows x 3 columns]

# %%
class DicomImage(Image):
    "DicomImage to support applying transforms to image data in `px`."
    def __init__(self, px:Tensor):
        self._px = px
        self._logit_px=None
        self._flow=None
        self._affine_mat=None
        self.sample_kwargs = {}
    
    def _repr_image_format(self, format_str):
        with BytesIO() as str_buffer:
            plt.imsave(str_buffer, image2np(self.px[0].unsqueeze(0)), # We show only one channel!
                       format=format_str, cmap=cmap)
            return str_buffer.getvalue()
        
    def clone(self):
        "Mimic the behavior of torch.clone for `Image` objects."
        return self.__class__(self.px.clone())

    @property
    def data(self)->TensorImage:
        "Return this images pixels as a tensor."
        return self.px
    
    def show(self, ax:plt.Axes=None, figsize:tuple=(3,3), title:Optional[str]=None, hide_axis:bool=True,
              cmap:str=cmap, y:Any=None, **kwargs):
        "Show image on `ax` with `title`, overlaid with optional `y`"
        ax = show_dicom_image(self, ax=ax, hide_axis=hide_axis, cmap=cmap, figsize=figsize)
        if y is not None: y.show(ax=ax, **kwargs)
        if title is not None: ax.set_title(title)

# %%
def open_dicom_image(fn:PathOrStr, cls:type=DicomImage, 
                     after_open:Callable=None, expand=True,
                     clamp_min=-1024, clamp_max=1024)->Image:
    "Return `Image` object created from image in file `fn`."
    
    def correct_dcm(dcm):
        x = dcm.pixel_array + 1000
        px_mode = 4096
        x[x>=px_mode] = x[x>=px_mode] - px_mode
        dcm.PixelData = x.tobytes()
        dcm.RescaleIntercept = -1000
        
    def window_image(dcm, window_center, window_width):
    
        if (dcm.BitsStored == 12) and (dcm.PixelRepresentation == 0) and (int(dcm.RescaleIntercept) > -100):
            correct_dcm(dcm)

        img = dcm.pixel_array * dcm.RescaleSlope + dcm.RescaleIntercept
        img_min = window_center - window_width // 2
        img_max = window_center + window_width // 2
        img = np.clip(img, img_min, img_max)

        return img

    def bsb_window(dcm):
        brain_img = window_image(dcm, 40, 80)
        subdural_img = window_image(dcm, 80, 200)
        soft_img = window_image(dcm, 40, 380)

        brain_img = (brain_img - 0) / 80
        subdural_img = (subdural_img - (-20)) / 200
        soft_img = (soft_img - (-150)) / 380
        bsb_img = np.array([brain_img, subdural_img, soft_img]).transpose(1,2,0)

        return bsb_img*255
    
    def process_img(img):
        img=img.astype(np.uint8)
        img_grsc=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
        dst = cv2.GaussianBlur(img_grsc,(5,5),cv2.BORDER_DEFAULT)
        ret, thresh = cv2.threshold(dst, 10, 255, 0)
        contours, hierarchy = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
        if len(contours)>0:
            c = max(contours, key = cv2.contourArea)
            mask = np.zeros_like(img_grsc)
            cv2.drawContours(mask, [c], 0, 255, -1)
            out_img=cv2.bitwise_and(img,img,mask=mask)
            x,y,w,h=cv2.boundingRect(c)
            out_img=out_img[y:y+h,x:x+w]
            out_img=cv2.resize(out_img,(512,512))
            return out_img.transpose(2,0,1)
        else:
            return img.transpose(2,0,1)
    
    dcm = pydicom.dcmread(fn) # open dicom image as dicom dataset
    #img = ds.pixel_array # get pixel data as np array
    #if (dcm.BitsStored == 12) and (dcm.PixelRepresentation == 0) and (int(dcm.RescaleIntercept) > -100):
    #    correct_dcm(dcm)
    
    
    # Convert to Hounsfield units (HU) and rescale and set intercept.
    # In this setup we only take a look at the values between -1024 and 1024.
    # Values below will be set to -1024, values above to 1024
    #resc_img = dcm.pixel_array * dcm.RescaleSlope + dcm.RescaleIntercept
    #resc_img[resc_img < -1024] = clamp_min # Clamp to minimum value   
    #resc_img[resc_img > 1024] = clamp_max # Clamp to maximum value
    #resc_img = (resc_img - clamp_min) / (clamp_max - clamp_min) # rescale to range from 0 to 1
    
#     resc_img = bsb_window(dcm)
    resc_img = process_img(bsb_window(dcm))/255
    
    if after_open: resc_img = after_open(resc_img)
    
    #resc_img = torch.from_numpy(resc_img.astype(np.float32, copy=False))
    x = torch.from_numpy(resc_img.astype(np.float32, copy=False))
    #x = resc_img.view(1,*resc_img.shape)
    #x = resc_img.view()
    
    #if expand: x = x.expand(3,*x.shape[-2:])
    # x.shape[-2:] is needed because not everything is of size 512x512!
    # expand is memory efficient: https://stackoverflow.com/questions/44593141/stacking-copies-of-an-array-a-torch-tensor-efficiently
                
    return cls(x)

# %%
def show_dicom_image(img:Image, ax:plt.Axes=None, figsize:tuple=(3,3), hide_axis:bool=True, cmap:str=cmap,
                alpha:float=None, **kwargs)->plt.Axes:
    "Display `DicomImage` in the notebook."
    if ax is None: fig,ax = plt.subplots(figsize=figsize)
    ax.imshow(image2np(img.data.data[0].unsqueeze(0)), # We show only one channel!
              cmap=cmap, alpha=alpha, **kwargs)
    if hide_axis: ax.axis('off')
    return ax

# %%
class DicomImageList(ImageList):
    def __init__(self, *args, after_open:Callable=None, **kwargs):
        super().__init__(*args, **kwargs)
        self.after_open = after_open
        self.c,self.sizes = 1,{}
        
    def open(self, fn):
        "Open image in `fn`, subclass and overwrite for custom behavior."
        return open_dicom_image(fn, after_open=self.after_open)
    
    # based on https://github.com/radekosmulski/rsna-intracranial/blob/master/03_train_basic_model.ipynb
    def label_from_df(self, cols:IntsOrStrs=1, label_cls:Callable=None, **kwargs):
        "Label `self.items` from the values in `cols` in `self.inner_df`."
        self.inner_df.labels.fillna('', inplace=True)
        labels = self.inner_df.iloc[:,df_names_to_idx(cols, self.inner_df)]
        assert labels.isna().sum().sum() == 0, f"You have NaN values in column(s) {cols} of your dataframe, please fix it."
        if is_listy(cols) and len(cols) > 1 and (label_cls is None or label_cls == MultiCategoryList):
            new_kwargs,label_cls = dict(one_hot=True, classes= cols),MultiCategoryList
            kwargs = {**new_kwargs, **kwargs}
        return self._label_from_list(_maybe_squeeze(labels), label_cls=label_cls, **kwargs)
    
    def show_xys(self, xs, ys, imgsize:int=4, figsize:Optional[Tuple[int,int]]=None, **kwargs):
        "Show the `xs` (inputs) and `ys` (targets) on a figure of `figsize`."
        rows = int(np.ceil(math.sqrt(len(xs))))
        axs = subplots(rows, rows, imgsize=imgsize, figsize=figsize)
        for x,y,ax in zip(xs, ys, axs.flatten()): x.show(ax=ax, y=y, **kwargs)
        for ax in axs.flatten()[len(xs):]: ax.axis('off')
        plt.tight_layout()
        
    def reconstruct(self, t): return DicomImage(t)

# %%
sub.loc[898,:]
# Out:
# label
# fn                  ID_03094e955.dcm
# any                              0.5
# epidural                         0.5
# intraparenchymal                 0.5
# intraventricular                 0.5
# subarachnoid                     0.5
# subdural                         0.5
# Name: 898, dtype: object

# %%
fn = '/mnt/fst/shaan/rsna-intracranial-hemorrhage-detection/stage_1_test_images/ID_03094e955.dcm'
fn
# Out:
# '/mnt/fst/shaan/rsna-intracranial-hemorrhage-detection/stage_1_test_images/ID_03094e955.dcm'

# %%
img = open_dicom_image(fn)
img
# Out:
# DicomImage (3, 512, 512)

# %%
img.resize(410)
# Out:
# DicomImage (3, 512, 512)

# %%
tfms = get_transforms(do_flip=True, max_lighting=0.0, max_zoom=1.05, max_warp=0.0)

# %%
np.random.seed(42)
src = (DicomImageList.from_df(df_train, path, folder='stage_1_train_images')
       .split_from_df()
       .label_from_df(cols=-2, label_delim=' '))

# %%
data = (src.transform(tfms, size=512)
        .databunch(bs=8).normalize(imagenet_stats))

# %%
test = DicomImageList.from_df(sub, path=path, folder='stage_1_test_images')
test
# Out:
# DicomImageList (78545 items)
# DicomImage (3, 512, 512),DicomImage (3, 512, 512),DicomImage (3, 512, 512),DicomImage (3, 512, 512),DicomImage (3, 512, 512)
# Path: /mnt/fst/shaan/rsna-intracranial-hemorrhage-detection

# %%
data.add_test(test)

# %%
data
# Out:
# ImageDataBunch;
#
# Train: LabelList (118229 items)
# x: DicomImageList
# DicomImage (3, 512, 512),DicomImage (3, 512, 512),DicomImage (3, 512, 512),DicomImage (3, 512, 512),DicomImage (3, 512, 512)
# y: MultiCategoryList
# ,,,,
# Path: /mnt/fst/shaan/rsna-intracranial-hemorrhage-detection;
#
# Valid: LabelList (473714 items)
# x: DicomImageList
# DicomImage (3, 512, 512),DicomImage (3, 512, 512),DicomImage (3, 512, 512),DicomImage (3, 512, 512),DicomImage (3, 512, 512)
# y: MultiCategoryList
# ,,,,
# Path: /mnt/fst/shaan/rsna-intracranial-hemorrhage-detection;
#
# Test: LabelList (78545 items)
# x: DicomImageList
# DicomImage (3, 512, 512),DicomImage (3, 512, 512),DicomImage (3, 512, 512),DicomImage (3, 512, 512),DicomImage (3, 512, 512)
# y: EmptyLabelList
# ,,,,
# Path: /mnt/fst/shaan/rsna-intracranial-hemorrhage-detection

# %%
data.show_batch()

# %%
def se_resnext50_32x4d(pretrained=False):
    pretrained = 'imagenet' if pretrained else None
    model = pretrainedmodels.se_resnext50_32x4d(pretrained=pretrained)
    return model

# %%
# loss_weights = [2,1,1,1,1,1]
# loss = torch.nn.BCEWithLogitsLoss(pos_weight=torch.tensor(loss_weights).float().cuda())
# def loss_fn(preds, targ): 
#     return loss(preds, targ.float())

# %%
learn = cnn_learner(data, se_resnext50_32x4d, pretrained=True,
                    cut=-2, split_on=lambda m: (m[0][3], m[1]),
                    loss_func=torch.nn.BCEWithLogitsLoss(), metrics=fbeta)
learn.unfreeze()

# %%
learn.load('dicom_se_resnext_validgrouped_image_preprocessed_3')
# Out:
# Learner(data=ImageDataBunch;
#
# Train: LabelList (118229 items)
# x: DicomImageList
# DicomImage (3, 512, 512),DicomImage (3, 512, 512),DicomImage (3, 512, 512),DicomImage (3, 512, 512),DicomImage (3, 512, 512)
# y: MultiCategoryList
# ,,,,
# Path: /mnt/fst/shaan/rsna-intracranial-hemorrhage-detection;
#
# Valid: LabelList (473714 items)
# x: DicomImageList
# DicomImage (3, 512, 512),DicomImage (3, 512, 512),DicomImage (3, 512, 512),DicomImage (3, 512, 512),DicomImage (3, 512, 512)
# y: MultiCategoryList
# ,,,,
# Path: /mnt/fst/shaan/rsna-intracranial-hemorrhage-detection;
#
# Test: LabelList (78545 items)
# x: DicomImageList
# DicomImage (3, 512, 512),DicomImage (3, 512, 512),DicomImage (3, 512, 512),DicomImage (3, 512, 512),DicomImage (3, 512, 512)
# y: EmptyLabelList
# ,,,,
# Path: /mnt/fst/shaan/rsna-intracranial-hemorrhage-detection, model=Sequential(
#   (0): Sequential(
#     (0): Sequential(
#       (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU(inplace=True)
#       (pool): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#     )
#     (1): Sequential(
#       (0): SEResNeXtBottleneck(
#         (conv1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#         (downsample): Sequential(
#           (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): SEResNeXtBottleneck(
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#       )
#       (2): SEResNeXtBottleneck(
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#     (2): Sequential(
#       (0): SEResNeXtBottleneck(
#         (conv1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): SEResNeXtBottleneck(
#         (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#       )
#       (2): SEResNeXtBottleneck(
#         (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#       )
#       (3): SEResNeXtBottleneck(
#         (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#     (3): Sequential(
#       (0): SEResNeXtBottleneck(
#         (conv1): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#         (downsample): Sequential(
#           (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): SEResNeXtBottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#       )
#       (2): SEResNeXtBottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#       )
#       (3): SEResNeXtBottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#       )
#       (4): SEResNeXtBottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#       )
#       (5): SEResNeXtBottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#     (4): Sequential(
#       (0): SEResNeXtBottleneck(
#         (conv1): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(2048, 128, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(128, 2048, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#         (downsample): Sequential(
#           (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): SEResNeXtBottleneck(
#         (conv1): Conv2d(2048, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(2048, 128, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(128, 2048, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#       )
#       (2): SEResNeXtBottleneck(
#         (conv1): Conv2d(2048, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(2048, 128, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(128, 2048, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#   )
#   (1): Sequential(
#     (0): AdaptiveConcatPool2d(
#       (ap): AdaptiveAvgPool2d(output_size=1)
#       (mp): AdaptiveMaxPool2d(output_size=1)
#     )
#     (1): Flatten()
#     (2): BatchNorm1d(4096, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=4096, out_features=512, bias=True)
#     (5): ReLU(inplace=True)
#     (6): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): Dropout(p=0.5, inplace=False)
#     (8): Linear(in_features=512, out_features=6, bias=True)
#   )
# ), opt_func=functools.partial(<class 'torch.optim.adam.Adam'>, betas=(0.9, 0.99)), loss_func=BCEWithLogitsLoss(), metrics=[<function fbeta at 0x7f70bc981620>], true_wd=True, bn_wd=True, wd=0.01, train_bn=True, path=PosixPath('/mnt/fst/shaan/rsna-intracranial-hemorrhage-detection'), model_dir='models', callback_fns=[functools.partial(<class 'fastai.basic_train.Recorder'>, add_time=True, silent=False)], callbacks=[], layer_groups=[Sequential(
#   (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU(inplace=True)
#   (3): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#   (4): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (5): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#   (7): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (8): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (9): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU(inplace=True)
#   (11): AdaptiveAvgPool2d(output_size=1)
#   (12): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1))
#   (13): ReLU(inplace=True)
#   (14): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1))
#   (15): Sigmoid()
#   (16): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (17): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (18): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (19): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (20): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#   (21): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (22): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (23): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (24): ReLU(inplace=True)
#   (25): AdaptiveAvgPool2d(output_size=1)
#   (26): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1))
#   (27): ReLU(inplace=True)
#   (28): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1))
#   (29): Sigmoid()
#   (30): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (31): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (32): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#   (33): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (34): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (35): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (36): ReLU(inplace=True)
#   (37): AdaptiveAvgPool2d(output_size=1)
#   (38): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1))
#   (39): ReLU(inplace=True)
#   (40): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1))
#   (41): Sigmoid()
#   (42): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (43): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (44): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False)
#   (45): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (46): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (47): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (48): ReLU(inplace=True)
#   (49): AdaptiveAvgPool2d(output_size=1)
#   (50): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1))
#   (51): ReLU(inplace=True)
#   (52): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1))
#   (53): Sigmoid()
#   (54): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#   (55): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (56): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (57): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (58): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#   (59): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (60): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (61): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (62): ReLU(inplace=True)
#   (63): AdaptiveAvgPool2d(output_size=1)
#   (64): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1))
#   (65): ReLU(inplace=True)
#   (66): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1))
#   (67): Sigmoid()
#   (68): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (69): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (70): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#   (71): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (72): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (73): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (74): ReLU(inplace=True)
#   (75): AdaptiveAvgPool2d(output_size=1)
#   (76): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1))
#   (77): ReLU(inplace=True)
#   (78): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1))
#   (79): Sigmoid()
#   (80): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (81): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (82): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#   (83): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (84): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (85): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (86): ReLU(inplace=True)
#   (87): AdaptiveAvgPool2d(output_size=1)
#   (88): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1))
#   (89): ReLU(inplace=True)
#   (90): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1))
#   (91): Sigmoid()
# ), Sequential(
#   (0): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False)
#   (3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (4): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (5): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU(inplace=True)
#   (7): AdaptiveAvgPool2d(output_size=1)
#   (8): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#   (9): ReLU(inplace=True)
#   (10): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#   (11): Sigmoid()
#   (12): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#   (13): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (14): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (15): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (16): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#   (17): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (18): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (19): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (20): ReLU(inplace=True)
#   (21): AdaptiveAvgPool2d(output_size=1)
#   (22): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#   (23): ReLU(inplace=True)
#   (24): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#   (25): Sigmoid()
#   (26): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (27): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#   (29): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (30): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (31): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (32): ReLU(inplace=True)
#   (33): AdaptiveAvgPool2d(output_size=1)
#   (34): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#   (35): ReLU(inplace=True)
#   (36): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#   (37): Sigmoid()
#   (38): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (39): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (40): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#   (41): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (42): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (43): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (44): ReLU(inplace=True)
#   (45): AdaptiveAvgPool2d(output_size=1)
#   (46): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#   (47): ReLU(inplace=True)
#   (48): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#   (49): Sigmoid()
#   (50): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (51): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (52): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#   (53): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (54): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (55): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (56): ReLU(inplace=True)
#   (57): AdaptiveAvgPool2d(output_size=1)
#   (58): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#   (59): ReLU(inplace=True)
#   (60): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#   (61): Sigmoid()
#   (62): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (63): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (64): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#   (65): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (66): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (67): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (68): ReLU(inplace=True)
#   (69): AdaptiveAvgPool2d(output_size=1)
#   (70): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#   (71): ReLU(inplace=True)
#   (72): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#   (73): Sigmoid()
#   (74): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (75): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (76): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False)
#   (77): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (78): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (79): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (80): ReLU(inplace=True)
#   (81): AdaptiveAvgPool2d(output_size=1)
#   (82): Conv2d(2048, 128, kernel_size=(1, 1), stride=(1, 1))
#   (83): ReLU(inplace=True)
#   (84): Conv2d(128, 2048, kernel_size=(1, 1), stride=(1, 1))
#   (85): Sigmoid()
#   (86): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#   (87): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (88): Conv2d(2048, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (89): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (90): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#   (91): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (92): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (93): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (94): ReLU(inplace=True)
#   (95): AdaptiveAvgPool2d(output_size=1)
#   (96): Conv2d(2048, 128, kernel_size=(1, 1), stride=(1, 1))
#   (97): ReLU(inplace=True)
#   (98): Conv2d(128, 2048, kernel_size=(1, 1), stride=(1, 1))
#   (99): Sigmoid()
#   (100): Conv2d(2048, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (101): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (102): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#   (103): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (104): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (105): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (106): ReLU(inplace=True)
#   (107): AdaptiveAvgPool2d(output_size=1)
#   (108): Conv2d(2048, 128, kernel_size=(1, 1), stride=(1, 1))
#   (109): ReLU(inplace=True)
#   (110): Conv2d(128, 2048, kernel_size=(1, 1), stride=(1, 1))
#   (111): Sigmoid()
# ), Sequential(
#   (0): AdaptiveAvgPool2d(output_size=1)
#   (1): AdaptiveMaxPool2d(output_size=1)
#   (2): Flatten()
#   (3): BatchNorm1d(4096, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (4): Dropout(p=0.25, inplace=False)
#   (5): Linear(in_features=4096, out_features=512, bias=True)
#   (6): ReLU(inplace=True)
#   (7): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (8): Dropout(p=0.5, inplace=False)
#   (9): Linear(in_features=512, out_features=6, bias=True)
# )], add_time=True, silent=False)

# %%
learn.summary()
# Out:
# Sequential
# ======================================================================
# Layer (type)         Output Shape         Param #    Trainable
# ======================================================================
# Conv2d               [64, 256, 256]       9,408      True
# ______________________________________________________________________
# BatchNorm2d          [64, 256, 256]       128        True
# ______________________________________________________________________
# ReLU                 [64, 256, 256]       0          False
# ______________________________________________________________________
# MaxPool2d            [64, 128, 128]       0          False
# ______________________________________________________________________
# Conv2d               [128, 128, 128]      8,192      True
# ______________________________________________________________________
# BatchNorm2d          [128, 128, 128]      256        True
# ______________________________________________________________________
# Conv2d               [128, 128, 128]      4,608      True
# ______________________________________________________________________
# BatchNorm2d          [128, 128, 128]      256        True
# ______________________________________________________________________
# Conv2d               [256, 128, 128]      32,768     True
# ______________________________________________________________________
# BatchNorm2d          [256, 128, 128]      512        True
# ______________________________________________________________________
# ReLU                 [256, 128, 128]      0          False
# ______________________________________________________________________
# AdaptiveAvgPool2d    [256, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [16, 1, 1]           4,112      True
# ______________________________________________________________________
# ReLU                 [16, 1, 1]           0          False
# ______________________________________________________________________
# Conv2d               [256, 1, 1]          4,352      True
# ______________________________________________________________________
# Sigmoid              [256, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [256, 128, 128]      16,384     True
# ______________________________________________________________________
# BatchNorm2d          [256, 128, 128]      512        True
# ______________________________________________________________________
# Conv2d               [128, 128, 128]      32,768     True
# ______________________________________________________________________
# BatchNorm2d          [128, 128, 128]      256        True
# ______________________________________________________________________
# Conv2d               [128, 128, 128]      4,608      True
# ______________________________________________________________________
# BatchNorm2d          [128, 128, 128]      256        True
# ______________________________________________________________________
# Conv2d               [256, 128, 128]      32,768     True
# ______________________________________________________________________
# BatchNorm2d          [256, 128, 128]      512        True
# ______________________________________________________________________
# ReLU                 [256, 128, 128]      0          False
# ______________________________________________________________________
# AdaptiveAvgPool2d    [256, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [16, 1, 1]           4,112      True
# ______________________________________________________________________
# ReLU                 [16, 1, 1]           0          False
# ______________________________________________________________________
# Conv2d               [256, 1, 1]          4,352      True
# ______________________________________________________________________
# Sigmoid              [256, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [128, 128, 128]      32,768     True
# ______________________________________________________________________
# BatchNorm2d          [128, 128, 128]      256        True
# ______________________________________________________________________
# Conv2d               [128, 128, 128]      4,608      True
# ______________________________________________________________________
# BatchNorm2d          [128, 128, 128]      256        True
# ______________________________________________________________________
# Conv2d               [256, 128, 128]      32,768     True
# ______________________________________________________________________
# BatchNorm2d          [256, 128, 128]      512        True
# ______________________________________________________________________
# ReLU                 [256, 128, 128]      0          False
# ______________________________________________________________________
# AdaptiveAvgPool2d    [256, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [16, 1, 1]           4,112      True
# ______________________________________________________________________
# ReLU                 [16, 1, 1]           0          False
# ______________________________________________________________________
# Conv2d               [256, 1, 1]          4,352      True
# ______________________________________________________________________
# Sigmoid              [256, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [256, 128, 128]      65,536     True
# ______________________________________________________________________
# BatchNorm2d          [256, 128, 128]      512        True
# ______________________________________________________________________
# Conv2d               [256, 64, 64]        18,432     True
# ______________________________________________________________________
# BatchNorm2d          [256, 64, 64]        512        True
# ______________________________________________________________________
# Conv2d               [512, 64, 64]        131,072    True
# ______________________________________________________________________
# BatchNorm2d          [512, 64, 64]        1,024      True
# ______________________________________________________________________
# ReLU                 [512, 64, 64]        0          False
# ______________________________________________________________________
# AdaptiveAvgPool2d    [512, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [32, 1, 1]           16,416     True
# ______________________________________________________________________
# ReLU                 [32, 1, 1]           0          False
# ______________________________________________________________________
# Conv2d               [512, 1, 1]          16,896     True
# ______________________________________________________________________
# Sigmoid              [512, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [512, 64, 64]        131,072    True
# ______________________________________________________________________
# BatchNorm2d          [512, 64, 64]        1,024      True
# ______________________________________________________________________
# Conv2d               [256, 64, 64]        131,072    True
# ______________________________________________________________________
# BatchNorm2d          [256, 64, 64]        512        True
# ______________________________________________________________________
# Conv2d               [256, 64, 64]        18,432     True
# ______________________________________________________________________
# BatchNorm2d          [256, 64, 64]        512        True
# ______________________________________________________________________
# Conv2d               [512, 64, 64]        131,072    True
# ______________________________________________________________________
# BatchNorm2d          [512, 64, 64]        1,024      True
# ______________________________________________________________________
# ReLU                 [512, 64, 64]        0          False
# ______________________________________________________________________
# AdaptiveAvgPool2d    [512, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [32, 1, 1]           16,416     True
# ______________________________________________________________________
# ReLU                 [32, 1, 1]           0          False
# ______________________________________________________________________
# Conv2d               [512, 1, 1]          16,896     True
# ______________________________________________________________________
# Sigmoid              [512, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [256, 64, 64]        131,072    True
# ______________________________________________________________________
# BatchNorm2d          [256, 64, 64]        512        True
# ______________________________________________________________________
# Conv2d               [256, 64, 64]        18,432     True
# ______________________________________________________________________
# BatchNorm2d          [256, 64, 64]        512        True
# ______________________________________________________________________
# Conv2d               [512, 64, 64]        131,072    True
# ______________________________________________________________________
# BatchNorm2d          [512, 64, 64]        1,024      True
# ______________________________________________________________________
# ReLU                 [512, 64, 64]        0          False
# ______________________________________________________________________
# AdaptiveAvgPool2d    [512, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [32, 1, 1]           16,416     True
# ______________________________________________________________________
# ReLU                 [32, 1, 1]           0          False
# ______________________________________________________________________
# Conv2d               [512, 1, 1]          16,896     True
# ______________________________________________________________________
# Sigmoid              [512, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [256, 64, 64]        131,072    True
# ______________________________________________________________________
# BatchNorm2d          [256, 64, 64]        512        True
# ______________________________________________________________________
# Conv2d               [256, 64, 64]        18,432     True
# ______________________________________________________________________
# BatchNorm2d          [256, 64, 64]        512        True
# ______________________________________________________________________
# Conv2d               [512, 64, 64]        131,072    True
# ______________________________________________________________________
# BatchNorm2d          [512, 64, 64]        1,024      True
# ______________________________________________________________________
# ReLU                 [512, 64, 64]        0          False
# ______________________________________________________________________
# AdaptiveAvgPool2d    [512, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [32, 1, 1]           16,416     True
# ______________________________________________________________________
# ReLU                 [32, 1, 1]           0          False
# ______________________________________________________________________
# Conv2d               [512, 1, 1]          16,896     True
# ______________________________________________________________________
# Sigmoid              [512, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [512, 64, 64]        262,144    True
# ______________________________________________________________________
# BatchNorm2d          [512, 64, 64]        1,024      True
# ______________________________________________________________________
# Conv2d               [512, 32, 32]        73,728     True
# ______________________________________________________________________
# BatchNorm2d          [512, 32, 32]        1,024      True
# ______________________________________________________________________
# Conv2d               [1024, 32, 32]       524,288    True
# ______________________________________________________________________
# BatchNorm2d          [1024, 32, 32]       2,048      True
# ______________________________________________________________________
# ReLU                 [1024, 32, 32]       0          False
# ______________________________________________________________________
# AdaptiveAvgPool2d    [1024, 1, 1]         0          False
# ______________________________________________________________________
# Conv2d               [64, 1, 1]           65,600     True
# ______________________________________________________________________
# ReLU                 [64, 1, 1]           0          False
# ______________________________________________________________________
# Conv2d               [1024, 1, 1]         66,560     True
# ______________________________________________________________________
# Sigmoid              [1024, 1, 1]         0          False
# ______________________________________________________________________
# Conv2d               [1024, 32, 32]       524,288    True
# ______________________________________________________________________
# BatchNorm2d          [1024, 32, 32]       2,048      True
# ______________________________________________________________________
# Conv2d               [512, 32, 32]        524,288    True
# ______________________________________________________________________
# BatchNorm2d          [512, 32, 32]        1,024      True
# ______________________________________________________________________
# Conv2d               [512, 32, 32]        73,728     True
# ______________________________________________________________________
# BatchNorm2d          [512, 32, 32]        1,024      True
# ______________________________________________________________________
# Conv2d               [1024, 32, 32]       524,288    True
# ______________________________________________________________________
# BatchNorm2d          [1024, 32, 32]       2,048      True
# ______________________________________________________________________
# ReLU                 [1024, 32, 32]       0          False
# ______________________________________________________________________
# AdaptiveAvgPool2d    [1024, 1, 1]         0          False
# ______________________________________________________________________
# Conv2d               [64, 1, 1]           65,600     True
# ______________________________________________________________________
# ReLU                 [64, 1, 1]           0          False
# ______________________________________________________________________
# Conv2d               [1024, 1, 1]         66,560     True
# ______________________________________________________________________
# Sigmoid              [1024, 1, 1]         0          False
# ______________________________________________________________________
# Conv2d               [512, 32, 32]        524,288    True
# ______________________________________________________________________
# BatchNorm2d          [512, 32, 32]        1,024      True
# ______________________________________________________________________
# Conv2d               [512, 32, 32]        73,728     True
# ______________________________________________________________________
# BatchNorm2d          [512, 32, 32]        1,024      True
# ______________________________________________________________________
# Conv2d               [1024, 32, 32]       524,288    True
# ______________________________________________________________________
# BatchNorm2d          [1024, 32, 32]       2,048      True
# ______________________________________________________________________
# ReLU                 [1024, 32, 32]       0          False
# ______________________________________________________________________
# AdaptiveAvgPool2d    [1024, 1, 1]         0          False
# ______________________________________________________________________
# Conv2d               [64, 1, 1]           65,600     True
# ______________________________________________________________________
# ReLU                 [64, 1, 1]           0          False
# ______________________________________________________________________
# Conv2d               [1024, 1, 1]         66,560     True
# ______________________________________________________________________
# Sigmoid              [1024, 1, 1]         0          False
# ______________________________________________________________________
# Conv2d               [512, 32, 32]        524,288    True
# ______________________________________________________________________
# BatchNorm2d          [512, 32, 32]        1,024      True
# ______________________________________________________________________
# Conv2d               [512, 32, 32]        73,728     True
# ______________________________________________________________________
# BatchNorm2d          [512, 32, 32]        1,024      True
# ______________________________________________________________________
# Conv2d               [1024, 32, 32]       524,288    True
# ______________________________________________________________________
# BatchNorm2d          [1024, 32, 32]       2,048      True
# ______________________________________________________________________
# ReLU                 [1024, 32, 32]       0          False
# ______________________________________________________________________
# AdaptiveAvgPool2d    [1024, 1, 1]         0          False
# ______________________________________________________________________
# Conv2d               [64, 1, 1]           65,600     True
# ______________________________________________________________________
# ReLU                 [64, 1, 1]           0          False
# ______________________________________________________________________
# Conv2d               [1024, 1, 1]         66,560     True
# ______________________________________________________________________
# Sigmoid              [1024, 1, 1]         0          False
# ______________________________________________________________________
# Conv2d               [512, 32, 32]        524,288    True
# ______________________________________________________________________
# BatchNorm2d          [512, 32, 32]        1,024      True
# ______________________________________________________________________
# Conv2d               [512, 32, 32]        73,728     True
# ______________________________________________________________________
# BatchNorm2d          [512, 32, 32]        1,024      True
# ______________________________________________________________________
# Conv2d               [1024, 32, 32]       524,288    True
# ______________________________________________________________________
# BatchNorm2d          [1024, 32, 32]       2,048      True
# ______________________________________________________________________
# ReLU                 [1024, 32, 32]       0          False
# ______________________________________________________________________
# AdaptiveAvgPool2d    [1024, 1, 1]         0          False
# ______________________________________________________________________
# Conv2d               [64, 1, 1]           65,600     True
# ______________________________________________________________________
# ReLU                 [64, 1, 1]           0          False
# ______________________________________________________________________
# Conv2d               [1024, 1, 1]         66,560     True
# ______________________________________________________________________
# Sigmoid              [1024, 1, 1]         0          False
# ______________________________________________________________________
# Conv2d               [512, 32, 32]        524,288    True
# ______________________________________________________________________
# BatchNorm2d          [512, 32, 32]        1,024      True
# ______________________________________________________________________
# Conv2d               [512, 32, 32]        73,728     True
# ______________________________________________________________________
# BatchNorm2d          [512, 32, 32]        1,024      True
# ______________________________________________________________________
# Conv2d               [1024, 32, 32]       524,288    True
# ______________________________________________________________________
# BatchNorm2d          [1024, 32, 32]       2,048      True
# ______________________________________________________________________
# ReLU                 [1024, 32, 32]       0          False
# ______________________________________________________________________
# AdaptiveAvgPool2d    [1024, 1, 1]         0          False
# ______________________________________________________________________
# Conv2d               [64, 1, 1]           65,600     True
# ______________________________________________________________________
# ReLU                 [64, 1, 1]           0          False
# ______________________________________________________________________
# Conv2d               [1024, 1, 1]         66,560     True
# ______________________________________________________________________
# Sigmoid              [1024, 1, 1]         0          False
# ______________________________________________________________________
# Conv2d               [1024, 32, 32]       1,048,576  True
# ______________________________________________________________________
# BatchNorm2d          [1024, 32, 32]       2,048      True
# ______________________________________________________________________
# Conv2d               [1024, 16, 16]       294,912    True
# ______________________________________________________________________
# BatchNorm2d          [1024, 16, 16]       2,048      True
# ______________________________________________________________________
# Conv2d               [2048, 16, 16]       2,097,152  True
# ______________________________________________________________________
# BatchNorm2d          [2048, 16, 16]       4,096      True
# ______________________________________________________________________
# ReLU                 [2048, 16, 16]       0          False
# ______________________________________________________________________
# AdaptiveAvgPool2d    [2048, 1, 1]         0          False
# ______________________________________________________________________
# Conv2d               [128, 1, 1]          262,272    True
# ______________________________________________________________________
# ReLU                 [128, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [2048, 1, 1]         264,192    True
# ______________________________________________________________________
# Sigmoid              [2048, 1, 1]         0          False
# ______________________________________________________________________
# Conv2d               [2048, 16, 16]       2,097,152  True
# ______________________________________________________________________
# BatchNorm2d          [2048, 16, 16]       4,096      True
# ______________________________________________________________________
# Conv2d               [1024, 16, 16]       2,097,152  True
# ______________________________________________________________________
# BatchNorm2d          [1024, 16, 16]       2,048      True
# ______________________________________________________________________
# Conv2d               [1024, 16, 16]       294,912    True
# ______________________________________________________________________
# BatchNorm2d          [1024, 16, 16]       2,048      True
# ______________________________________________________________________
# Conv2d               [2048, 16, 16]       2,097,152  True
# ______________________________________________________________________
# BatchNorm2d          [2048, 16, 16]       4,096      True
# ______________________________________________________________________
# ReLU                 [2048, 16, 16]       0          False
# ______________________________________________________________________
# AdaptiveAvgPool2d    [2048, 1, 1]         0          False
# ______________________________________________________________________
# Conv2d               [128, 1, 1]          262,272    True
# ______________________________________________________________________
# ReLU                 [128, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [2048, 1, 1]         264,192    True
# ______________________________________________________________________
# Sigmoid              [2048, 1, 1]         0          False
# ______________________________________________________________________
# Conv2d               [1024, 16, 16]       2,097,152  True
# ______________________________________________________________________
# BatchNorm2d          [1024, 16, 16]       2,048      True
# ______________________________________________________________________
# Conv2d               [1024, 16, 16]       294,912    True
# ______________________________________________________________________
# BatchNorm2d          [1024, 16, 16]       2,048      True
# ______________________________________________________________________
# Conv2d               [2048, 16, 16]       2,097,152  True
# ______________________________________________________________________
# BatchNorm2d          [2048, 16, 16]       4,096      True
# ______________________________________________________________________
# ReLU                 [2048, 16, 16]       0          False
# ______________________________________________________________________
# AdaptiveAvgPool2d    [2048, 1, 1]         0          False
# ______________________________________________________________________
# Conv2d               [128, 1, 1]          262,272    True
# ______________________________________________________________________
# ReLU                 [128, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [2048, 1, 1]         264,192    True
# ______________________________________________________________________
# Sigmoid              [2048, 1, 1]         0          False
# ______________________________________________________________________
# AdaptiveAvgPool2d    [2048, 1, 1]         0          False
# ______________________________________________________________________
# AdaptiveMaxPool2d    [2048, 1, 1]         0          False
# ______________________________________________________________________
# Flatten              [4096]               0          False
# ______________________________________________________________________
# BatchNorm1d          [4096]               8,192      True
# ______________________________________________________________________
# Dropout              [4096]               0          False
# ______________________________________________________________________
# Linear               [512]                2,097,664  True
# ______________________________________________________________________
# ReLU                 [512]                0          False
# ______________________________________________________________________
# BatchNorm1d          [512]                1,024      True
# ______________________________________________________________________
# Dropout              [512]                0          False
# ______________________________________________________________________
# Linear               [6]                  3,078      True
# ______________________________________________________________________
#
# Total params: 27,620,854
# Total trainable params: 27,620,854
# Total non-trainable params: 0
# Optimized with 'torch.optim.adam.Adam', betas=(0.9, 0.99)
# Using true weight decay as discussed in https://www.fast.ai/2018/07/02/adam-weight-decay/
# Loss function : BCEWithLogitsLoss
# ======================================================================
# Callbacks functions applied

# %%
learn.lr_find()
learn.recorder.plot(suggestion=True)
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 1.10E-06
# Min loss divided by 10: 1.32E-07

# %%
lr = 1e-8
learn.fit_one_cycle(1, lr, 
                    callbacks=[SaveModelCallback(learn, every='improvement', monitor='valid_loss', name='dicom_se_resnext_validgrouped_image_preprocessed_4')])
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>fbeta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='602' class='' max='14778', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       4.07% [602/14778 06:11<2:25:56 0.1309]
#     </div>

# %%
learn.save('rsna-dicom-se_resnext-validgrouped-image-preprocessed-stage4')

# %%
preds, _ = learn.get_preds(ds_type=DatasetType.Test)

# %%
preds

# %%
datasetIndex = []
num = len(learn.data.test_ds)

for i in range(num):
    datasetIndex.append(str(learn.data.test_ds.items[i]).split('/')[-1])

# %%
datasetIndex

# %%
classes = (pivot.columns.tolist()[1:])
classes

# %%
ids = []
labels = []

for path, pred in zip(sorted(test_files), preds):
    for i, label in enumerate(classes):
        ids.append(f"{path.split('.')[0]}_{label}")
        predicted_probability = '{0:1.10f}'.format(pred[i].item())
        labels.append(predicted_probability)

# %%
sub_df = pd.DataFrame({'ID': ids, 'Label': labels})
sub_df

# %%
sub_df.to_csv('fastai-effb2-410-3channel-dicom-0.025delete-validgrouped-image-preprocessed.csv', index=False)

# %%
preds_tta, _ = learn.TTA(ds_type=DatasetType.Test)

# %%
preds_tta

# %%
ids = []
labels_tta = []

for path, pred in zip(sorted(test_files), preds_tta):
    for i, label in enumerate(classes):
        ids.append(f"{path.split('.')[0]}_{label}")
        predicted_probability = '{0:1.10f}'.format(pred[i].item())
        labels_tta.append(predicted_probability)

# %%
sub_df_tta = pd.DataFrame({'ID': ids, 'Label': labels_tta})
sub_df_tta

# %%
sub_df_tta.to_csv('fastai-effb2-410-3channel-dicom-0.025delete-validgrouped-tta-stage1.csv', index=False)

# %%
# png = os.listdir('/mnt/fst/shaan/rsna-intracranial-hemorrhage-detection/png-rashid')
# png

# %%
# import matplotlib.image as mpimg
# img = mpimg.imread('/mnt/fst/shaan/rsna-intracranial-hemorrhage-detection/png-rashid/'+png[0])
# plt.imshow(img, cmap=cmap)
