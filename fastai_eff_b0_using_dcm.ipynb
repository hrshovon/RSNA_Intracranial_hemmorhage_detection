# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore", category=UserWarning, module="torch.nn.functional")

# %%
import pandas as pd
import pydicom
from fastai.vision import *
from fastai.callbacks import *
from fastai.data_block import _maybe_squeeze
from collections import defaultdict

# %%
import torch
torch.cuda.device(0)

# %%
torch.cuda.get_device_name()
# Out:
# 'GeForce GTX 1070'

# %%
path = Path('/mnt/fst/shaan/rsna-intracranial-hemorrhage-detection')
cmap='jet'

# %%
import os
files = os.listdir("/mnt/fst/shaan/rsna-intracranial-hemorrhage-detection/train224")
test_files = os.listdir("/mnt/fst/shaan/rsna-intracranial-hemorrhage-detection/test224")

# %%
df = pd.read_csv(path/'stage_1_train.csv')
df['fn'] = df.ID.apply(lambda x: '_'.join(x.split('_')[:2]) + '.dcm')
df.columns = ['ID', 'probability', 'fn']
df['label'] = df.ID.apply(lambda x: x.split('_')[-1])
df.drop_duplicates('ID', inplace=True)
pivot = df.pivot(index='fn', columns='label', values='probability')
pivot.reset_index(inplace=True)
d = defaultdict(list)
for fn in df.fn.unique(): 
    d[fn]
for tup in df.itertuples():
    if tup.probability: 
        d[tup.fn].append(tup.label)
        
ks, vs = [], []

for k, v in d.items():
    ks.append(k), vs.append(' '.join(v))
    
df_train = pd.DataFrame(data={'fn': ks, 'labels': vs})
df_train.labels.fillna('', inplace=True)
df_train = df_train[df_train['fn'] != 'ID_6431af929.dcm']
df_train.reset_index(drop=True, inplace=True)

# %%
df_trn = pd.read_feather(path/'df_trn.fth')
df_trn = df_trn[df_trn['SOPInstanceUID'] != 'ID_6431af929']
df_trn
# Out:
#        SOPInstanceUID Modality    PatientID StudyInstanceUID  \
# 0        ID_231d901c1       CT  ID_b81a287f    ID_dd37ba3adb
# 1        ID_994bc0470       CT  ID_400facde    ID_c5277f0c63
# 2        ID_127689cce       CT  ID_42910d3d    ID_db93ade25b
# 3        ID_25457734a       CT  ID_329aafa7    ID_8dd6d32f3b
# 4        ID_81c9aa125       CT  ID_6b544c3c    ID_2685c5d5c0
# ...               ...      ...          ...              ...
# 674253   ID_1b415e1cc       CT  ID_b13dd1c5    ID_a56ee65b9f
# 674254   ID_59ec44ad3       CT  ID_683fd24c    ID_405c292102
# 674255   ID_c6516b047       CT  ID_75f878eb    ID_64406ff4f4
# 674256   ID_2c0ac4759       CT  ID_cf94e855    ID_a8aff1a18e
# 674257   ID_19eede6a5       CT  ID_b1a20252    ID_11dbf143b5
#
#        SeriesInstanceUID StudyID  ImagePositionPatient  \
# 0          ID_15dcd6057a                        -125.0
# 1          ID_4ba12c2161                        -125.0
# 2          ID_c4b4931314                        -125.0
# 3          ID_116558f409                        -114.0
# 4          ID_f56d7bd0f9                        -115.0
# ...                  ...     ...                   ...
# 674253     ID_70961fe25e                        -156.0
# 674254     ID_9c1e421cad                        -120.5
# 674255     ID_87fe0fa9f4                        -109.5
# 674256     ID_fa5855e749                        -106.5
# 674257     ID_39bb965c30                        -125.0
#
#         ImageOrientationPatient  SamplesPerPixel PhotometricInterpretation  \
# 0                           1.0                1               MONOCHROME2
# 1                           1.0                1               MONOCHROME2
# 2                           1.0                1               MONOCHROME2
# 3                           1.0                1               MONOCHROME2
# 4                           1.0                1               MONOCHROME2
# ...                         ...              ...                       ...
# 674253                      1.0                1               MONOCHROME2
# 674254                      1.0                1               MONOCHROME2
# 674255                      1.0                1               MONOCHROME2
# 674256                      1.0                1               MONOCHROME2
# 674257                      1.0                1               MONOCHROME2
#
#         ...  PixelSpacing1  img_min  img_max    img_mean      img_std  \
# 0       ...       0.488281    -1024     3263  171.462490   828.102464
# 1       ...       0.488281        0     2507  430.418091   599.742963
# 2       ...       0.488281    -2000     2810   12.801376  1209.046168
# 3       ...       0.445312        0     2647  566.557011   610.152845
# 4       ...       0.449219        4     1570  178.512295   358.235071
# ...     ...            ...      ...      ...         ...          ...
# 674253  ...       0.609375        4     2612  292.513027   469.929874
# 674254  ...       0.470703        3     2452  559.591610   578.345477
# 674255  ...       0.427734        9     2646  524.992954   567.491898
# 674256  ...       0.416016        0     4000  544.195152   573.152837
# 674257  ...       0.488281    -2000     2687   77.698273  1229.599807
#
#         img_pct_window  MultiWindowCenter  WindowCenter1  MultiWindowWidth  \
# 0             0.164074                NaN            NaN               NaN
# 1             0.198139                1.0           47.0               1.0
# 2             0.250923                NaN            NaN               NaN
# 3             0.298386                1.0           36.0               1.0
# 4             0.006176                1.0           36.0               1.0
# ...                ...                ...            ...               ...
# 674253        0.100445                1.0           36.0               1.0
# 674254        0.171585                1.0           36.0               1.0
# 674255        0.172607                1.0           36.0               1.0
# 674256        0.209194                1.0           36.0               1.0
# 674257        0.171535                NaN            NaN               NaN
#
#         WindowWidth1
# 0                NaN
# 1               80.0
# 2                NaN
# 3               80.0
# 4               80.0
# ...              ...
# 674253          80.0
# 674254          80.0
# 674255          80.0
# 674256          80.0
# 674257           NaN
#
# [674257 rows x 42 columns]

# %%
bad_img = list(df_trn[df_trn.img_pct_window<0.025].SOPInstanceUID)
bad_img = [s + '.dcm' for s in bad_img]
bad_img
# Out:
# ['ID_81c9aa125.dcm',
#  'ID_a31462f2a.dcm',
#  'ID_0acb28b87.dcm',
#  'ID_7ad9ec79d.dcm',
#  'ID_1029cc830.dcm',
#  'ID_78f04b7d1.dcm',
#  'ID_7a0d8a53f.dcm',
#  'ID_ea2568d47.dcm',
#  'ID_c0c3c5e80.dcm',
#  'ID_2f124f224.dcm',
#  'ID_6e922e6c0.dcm',
#  'ID_9db1dd7fb.dcm',
#  'ID_e425db695.dcm',
#  'ID_73d43e137.dcm',
#  'ID_4777fd31b.dcm',
#  'ID_6327b8d38.dcm',
#  'ID_aa241029b.dcm',
#  'ID_eb6ab0790.dcm',
#  'ID_b16095ca8.dcm',
#  'ID_3a626bb70.dcm',
#  'ID_cf4cb07e2.dcm',
#  'ID_ba098b526.dcm',
#  'ID_b58fe3c5b.dcm',
#  'ID_88d25c1bc.dcm',
#  'ID_6939a1303.dcm',
#  'ID_d7cc266e5.dcm',
#  'ID_38e4700ea.dcm',
#  'ID_17a077f2e.dcm',
#  'ID_000ada5fc.dcm',
#  'ID_c4a1a689d.dcm',
#  'ID_8e704bc00.dcm',
#  'ID_fad0346b8.dcm',
#  'ID_d52765ca8.dcm',
#  'ID_0135a2814.dcm',
#  'ID_39065f5de.dcm',
#  'ID_07d914f5f.dcm',
#  'ID_99fbcbf35.dcm',
#  'ID_c3f736a1e.dcm',
#  'ID_76e3b4e0f.dcm',
#  'ID_85372445f.dcm',
#  'ID_3b2232047.dcm',
#  'ID_740be9098.dcm',
#  'ID_3f2848a01.dcm',
#  'ID_14bb5b755.dcm',
#  'ID_d12e704a8.dcm',
#  'ID_b2890a394.dcm',
#  'ID_d37088a1f.dcm',
#  'ID_12ec08137.dcm',
#  'ID_d2a72bf2d.dcm',
#  'ID_5e517b4bb.dcm',
#  'ID_725547ac7.dcm',
#  'ID_658332c96.dcm',
#  'ID_c6eb7e189.dcm',
#  'ID_afe674bef.dcm',
#  'ID_3c6487b43.dcm',
#  'ID_52852b8df.dcm',
#  'ID_b3899f4bb.dcm',
#  'ID_f88494933.dcm',
#  'ID_733bdfc3b.dcm',
#  'ID_a9846beef.dcm',
#  'ID_5310d516b.dcm',
#  'ID_9b169bd4f.dcm',
#  'ID_995f635ef.dcm',
#  'ID_cf5c13a96.dcm',
#  'ID_0ebd4d280.dcm',
#  'ID_24aebfb60.dcm',
#  'ID_615f2f089.dcm',
#  'ID_d213d4de8.dcm',
#  'ID_88e047c37.dcm',
#  'ID_8e5dae42b.dcm',
#  'ID_21d5191cd.dcm',
#  'ID_df79c1e9e.dcm',
#  'ID_9d5124829.dcm',
#  'ID_7a2cbd5e3.dcm',
#  'ID_9420689bf.dcm',
#  'ID_fac6f0f20.dcm',
#  'ID_7f851b405.dcm',
#  'ID_95b9a491c.dcm',
#  'ID_6bef884da.dcm',
#  'ID_eaeeee800.dcm',
#  'ID_10ce3862b.dcm',
#  'ID_85fecd132.dcm',
#  'ID_a92ea9b04.dcm',
#  'ID_0aa17d575.dcm',
#  'ID_832370729.dcm',
#  'ID_d043608fc.dcm',
#  'ID_192a27071.dcm',
#  'ID_b126ec94d.dcm',
#  'ID_2649525d6.dcm',
#  'ID_d5402e024.dcm',
#  'ID_f739fb71b.dcm',
#  'ID_18941be3c.dcm',
#  'ID_82a2b003a.dcm',
#  'ID_c6cc9bb6f.dcm',
#  'ID_fd0c837d8.dcm',
#  'ID_aa90a0f0d.dcm',
#  'ID_dc677a106.dcm',
#  'ID_da6c6ecf7.dcm',
#  'ID_e6413b983.dcm',
#  'ID_d7f652d23.dcm',
#  'ID_2ed045ef8.dcm',
#  'ID_4abe9b63f.dcm',
#  'ID_76396dcb8.dcm',
#  'ID_6270a270b.dcm',
#  'ID_5921618e3.dcm',
#  'ID_7945fded4.dcm',
#  'ID_837435fd6.dcm',
#  'ID_a1ae8cdd3.dcm',
#  'ID_b16b3b6a3.dcm',
#  'ID_cd7cb13e6.dcm',
#  'ID_8cfcfe329.dcm',
#  'ID_67af99bf9.dcm',
#  'ID_9358c7d95.dcm',
#  'ID_79da7843d.dcm',
#  'ID_7cb002bb1.dcm',
#  'ID_81ef45a50.dcm',
#  'ID_7cb45206b.dcm',
#  'ID_a48913b44.dcm',
#  'ID_b60259084.dcm',
#  'ID_a4a20af33.dcm',
#  'ID_43ffada62.dcm',
#  'ID_0929a8bb4.dcm',
#  'ID_1357bbae4.dcm',
#  'ID_38991ff26.dcm',
#  'ID_d4956d4dd.dcm',
#  'ID_107a21536.dcm',
#  'ID_08df59e4a.dcm',
#  'ID_2d3133e04.dcm',
#  'ID_511cd373f.dcm',
#  'ID_993ebf2c9.dcm',
#  'ID_c95f9dbd2.dcm',
#  'ID_1972f05e5.dcm',
#  'ID_db3d2484a.dcm',
#  'ID_48f0ce546.dcm',
#  'ID_ec46d2361.dcm',
#  'ID_e8b9a7e40.dcm',
#  'ID_233e26b36.dcm',
#  'ID_d639263ff.dcm',
#  'ID_68212292b.dcm',
#  'ID_0af240c7a.dcm',
#  'ID_9d791942b.dcm',
#  'ID_7c952e4d4.dcm',
#  'ID_4ddb2f32c.dcm',
#  'ID_d3e5d1009.dcm',
#  'ID_9958bdcc4.dcm',
#  'ID_51a5b3030.dcm',
#  'ID_3ec2ed3bd.dcm',
#  'ID_b26de7218.dcm',
#  'ID_392009dc7.dcm',
#  'ID_1d34f9fa4.dcm',
#  'ID_6e5dd8946.dcm',
#  'ID_b51d78c14.dcm',
#  'ID_97e47ac58.dcm',
#  'ID_943e64aa2.dcm',
#  'ID_428faecf0.dcm',
#  'ID_845812ac1.dcm',
#  'ID_b9755f3f8.dcm',
#  'ID_3a15a0243.dcm',
#  'ID_db9d2f945.dcm',
#  'ID_d837ff6a0.dcm',
#  'ID_0d80d6684.dcm',
#  'ID_991ac2ee8.dcm',
#  'ID_342276196.dcm',
#  'ID_d6d645b63.dcm',
#  'ID_af7d56175.dcm',
#  'ID_52f696646.dcm',
#  'ID_9cb24d97d.dcm',
#  'ID_02bb77af2.dcm',
#  'ID_c83804a45.dcm',
#  'ID_455542d9a.dcm',
#  'ID_a0e234c10.dcm',
#  'ID_17df46afd.dcm',
#  'ID_c1cb038c0.dcm',
#  'ID_49c56d671.dcm',
#  'ID_c2a75c7fb.dcm',
#  'ID_587cf6b7a.dcm',
#  'ID_4e3781372.dcm',
#  'ID_4f7a2e8e4.dcm',
#  'ID_2362d2977.dcm',
#  'ID_00fbf77ca.dcm',
#  'ID_cc925efc2.dcm',
#  'ID_91c1555bc.dcm',
#  'ID_267ed4ea4.dcm',
#  'ID_0c6d94e30.dcm',
#  'ID_20a39fd11.dcm',
#  'ID_b5e8217c3.dcm',
#  'ID_4ddba184f.dcm',
#  'ID_41e9b4a7e.dcm',
#  'ID_d66ad522b.dcm',
#  'ID_fbb23254f.dcm',
#  'ID_23565a7bf.dcm',
#  'ID_03322cff2.dcm',
#  'ID_e28d1efea.dcm',
#  'ID_2c68c5a3b.dcm',
#  'ID_57c27bb56.dcm',
#  'ID_e35209688.dcm',
#  'ID_4b016a3ee.dcm',
#  'ID_484c1f855.dcm',
#  'ID_eb74ea25d.dcm',
#  'ID_ac2c9c8d0.dcm',
#  'ID_9256c2201.dcm',
#  'ID_a2bcf7b57.dcm',
#  'ID_a33d1e362.dcm',
#  'ID_fd4035721.dcm',
#  'ID_01b612d2d.dcm',
#  'ID_bd4a373e0.dcm',
#  'ID_2c97dd555.dcm',
#  'ID_7ad9d4827.dcm',
#  'ID_f556b9f8e.dcm',
#  'ID_c7a9ba9a9.dcm',
#  'ID_9e46bcdee.dcm',
#  'ID_028099493.dcm',
#  'ID_47754adaf.dcm',
#  'ID_9c7816318.dcm',
#  'ID_2f6ce1391.dcm',
#  'ID_134b8fec4.dcm',
#  'ID_738056ada.dcm',
#  'ID_4380390c0.dcm',
#  'ID_da5d79d48.dcm',
#  'ID_479e761a5.dcm',
#  'ID_d6a01fe32.dcm',
#  'ID_22afacb8c.dcm',
#  'ID_fb0591be5.dcm',
#  'ID_e11238f01.dcm',
#  'ID_2b4a73eba.dcm',
#  'ID_8951532dc.dcm',
#  'ID_a85b189cf.dcm',
#  'ID_42b068699.dcm',
#  'ID_c0c9dc6f1.dcm',
#  'ID_4833c117b.dcm',
#  'ID_e3cd26eed.dcm',
#  'ID_69848f96d.dcm',
#  'ID_f6e48f2a5.dcm',
#  'ID_6a822fe2a.dcm',
#  'ID_762e87df7.dcm',
#  'ID_4239095bd.dcm',
#  'ID_dabd52dc4.dcm',
#  'ID_61905cfae.dcm',
#  'ID_5fc3fd8f1.dcm',
#  'ID_98bf56f29.dcm',
#  'ID_92ed3362c.dcm',
#  'ID_55b6d15cd.dcm',
#  'ID_3fd17ef4f.dcm',
#  'ID_c975abaf2.dcm',
#  'ID_679befe78.dcm',
#  'ID_b017fe9aa.dcm',
#  'ID_c49a39a3e.dcm',
#  'ID_f15a4a40b.dcm',
#  'ID_ec65bfa2d.dcm',
#  'ID_ff38afe24.dcm',
#  'ID_b58e95552.dcm',
#  'ID_dd822f39e.dcm',
#  'ID_e07c2e258.dcm',
#  'ID_1a56be3f0.dcm',
#  'ID_26fd876ff.dcm',
#  'ID_de5b439db.dcm',
#  'ID_3f672f61b.dcm',
#  'ID_910ad62ff.dcm',
#  'ID_db4301e55.dcm',
#  'ID_49c5e213e.dcm',
#  'ID_454cacd1e.dcm',
#  'ID_3c6d76255.dcm',
#  'ID_1bdab373c.dcm',
#  'ID_ad3ebc03d.dcm',
#  'ID_2c916e8a8.dcm',
#  'ID_d5d3645a5.dcm',
#  'ID_de08d39f0.dcm',
#  'ID_946b829f7.dcm',
#  'ID_628340c9f.dcm',
#  'ID_4fc1ae821.dcm',
#  'ID_cb13b1674.dcm',
#  'ID_bd442e90a.dcm',
#  'ID_a6bbec0ab.dcm',
#  'ID_cce57265f.dcm',
#  'ID_167db2c88.dcm',
#  'ID_7a6b39478.dcm',
#  'ID_f81164cb0.dcm',
#  'ID_01c23833c.dcm',
#  'ID_0b3299a73.dcm',
#  'ID_92e4165ff.dcm',
#  'ID_eba13fe34.dcm',
#  'ID_6d6d35606.dcm',
#  'ID_00bb816c7.dcm',
#  'ID_3eb90a4f2.dcm',
#  'ID_d2dbef02c.dcm',
#  'ID_7f8b4a98a.dcm',
#  'ID_95a0a240a.dcm',
#  'ID_0db391528.dcm',
#  'ID_45fe0128a.dcm',
#  'ID_f88058bbb.dcm',
#  'ID_c0e34d761.dcm',
#  'ID_6362ef8db.dcm',
#  'ID_71e4033fb.dcm',
#  'ID_16d39f443.dcm',
#  'ID_41ce18976.dcm',
#  'ID_b82fad0d4.dcm',
#  'ID_925207c19.dcm',
#  'ID_f46868e6e.dcm',
#  'ID_dc8bfecf1.dcm',
#  'ID_f8ab24617.dcm',
#  'ID_203095615.dcm',
#  'ID_b57475eb1.dcm',
#  'ID_07fc48135.dcm',
#  'ID_f869c9cf9.dcm',
#  'ID_481d914da.dcm',
#  'ID_061e34294.dcm',
#  'ID_1ad734eee.dcm',
#  'ID_d94e21298.dcm',
#  'ID_c88f115b1.dcm',
#  'ID_ac81a3e35.dcm',
#  'ID_302b020a0.dcm',
#  'ID_4fdde9920.dcm',
#  'ID_7f5a49d28.dcm',
#  'ID_1254452f7.dcm',
#  'ID_81c4ec3ea.dcm',
#  'ID_3ca72c066.dcm',
#  'ID_7abd5ee82.dcm',
#  'ID_f59a25696.dcm',
#  'ID_d32ed3a77.dcm',
#  'ID_b1e6f5702.dcm',
#  'ID_a75c8759c.dcm',
#  'ID_9dec0740e.dcm',
#  'ID_93d0ab9e0.dcm',
#  'ID_117b09d07.dcm',
#  'ID_4c0d2501c.dcm',
#  'ID_a080edb1d.dcm',
#  'ID_a4f0e97d7.dcm',
#  'ID_10b5be557.dcm',
#  'ID_01e9ec989.dcm',
#  'ID_3feff2402.dcm',
#  'ID_a4fb4c65e.dcm',
#  'ID_d4626abce.dcm',
#  'ID_c466cdc3a.dcm',
#  'ID_b99b4b4cf.dcm',
#  'ID_014598a2d.dcm',
#  'ID_41b973f39.dcm',
#  'ID_98fcbfe3b.dcm',
#  'ID_81273608a.dcm',
#  'ID_1635fb404.dcm',
#  'ID_838139023.dcm',
#  'ID_3ff1b9d27.dcm',
#  'ID_586af7ae5.dcm',
#  'ID_5456ec4f8.dcm',
#  'ID_98ac4cd0b.dcm',
#  'ID_7655185bc.dcm',
#  'ID_078b25c8a.dcm',
#  'ID_30ad30f73.dcm',
#  'ID_9e968ac3a.dcm',
#  'ID_ecc60dba9.dcm',
#  'ID_5db182cde.dcm',
#  'ID_b1c008cf7.dcm',
#  'ID_541966737.dcm',
#  'ID_77db470e6.dcm',
#  'ID_28df4635c.dcm',
#  'ID_4a054b3e5.dcm',
#  'ID_37f1a6617.dcm',
#  'ID_2d865595f.dcm',
#  'ID_1bf6cb677.dcm',
#  'ID_b20ba84f2.dcm',
#  'ID_5f8051c32.dcm',
#  'ID_d43ac760a.dcm',
#  'ID_b169959e1.dcm',
#  'ID_ef0096158.dcm',
#  'ID_47667fd22.dcm',
#  'ID_b49a47d15.dcm',
#  'ID_63e9066cf.dcm',
#  'ID_6fc98e0d8.dcm',
#  'ID_a16bd7fd9.dcm',
#  'ID_2a28376c8.dcm',
#  'ID_24601ff3b.dcm',
#  'ID_d872ec055.dcm',
#  'ID_770de1b73.dcm',
#  'ID_1098d55a1.dcm',
#  'ID_17dd1229a.dcm',
#  'ID_466ff3ad2.dcm',
#  'ID_93d67dee2.dcm',
#  'ID_6dd822783.dcm',
#  'ID_605174028.dcm',
#  'ID_f9e07e1ab.dcm',
#  'ID_8587d0a87.dcm',
#  'ID_05574ff36.dcm',
#  'ID_a3bb04aae.dcm',
#  'ID_5a233c87a.dcm',
#  'ID_0dde1faaa.dcm',
#  'ID_45dfaf73a.dcm',
#  'ID_9c169d127.dcm',
#  'ID_5ae8c7cc2.dcm',
#  'ID_4157ec1ae.dcm',
#  'ID_45d9e5f88.dcm',
#  'ID_4a8689509.dcm',
#  'ID_144a8b8dd.dcm',
#  'ID_934fa7dad.dcm',
#  'ID_b481e36cc.dcm',
#  'ID_a43d070f8.dcm',
#  'ID_54ed94e4f.dcm',
#  'ID_a30486527.dcm',
#  'ID_6662c0e06.dcm',
#  'ID_a7d313e48.dcm',
#  'ID_08af3f6fb.dcm',
#  'ID_4b12de9b0.dcm',
#  'ID_6d74caa44.dcm',
#  'ID_d1a263950.dcm',
#  'ID_77b9c3957.dcm',
#  'ID_06188d9d9.dcm',
#  'ID_f4f146492.dcm',
#  'ID_f6bd49722.dcm',
#  'ID_3ce435710.dcm',
#  'ID_832017dbe.dcm',
#  'ID_8f3bed033.dcm',
#  'ID_4957613b6.dcm',
#  'ID_3ad001848.dcm',
#  'ID_fed2d2eb1.dcm',
#  'ID_6dd7e984e.dcm',
#  'ID_b48855bba.dcm',
#  'ID_b6da5759b.dcm',
#  'ID_0eb65a613.dcm',
#  'ID_57eac34f5.dcm',
#  'ID_1e0db5600.dcm',
#  'ID_e5de2ec5f.dcm',
#  'ID_effdfe073.dcm',
#  'ID_d0ee5b2f4.dcm',
#  'ID_88b5abe04.dcm',
#  'ID_e118e9e72.dcm',
#  'ID_4eed3740f.dcm',
#  'ID_91de7adba.dcm',
#  'ID_8280057fd.dcm',
#  'ID_e8ca8b889.dcm',
#  'ID_2326df0d2.dcm',
#  'ID_5dabfefd2.dcm',
#  'ID_6add86ae9.dcm',
#  'ID_a41350547.dcm',
#  'ID_008e000da.dcm',
#  'ID_e04f8ad6f.dcm',
#  'ID_f6a72bc50.dcm',
#  'ID_21360bfec.dcm',
#  'ID_bcd22f2bc.dcm',
#  'ID_79ab6fcfc.dcm',
#  'ID_4fe8761ed.dcm',
#  'ID_7d7b2f409.dcm',
#  'ID_fe3f1935e.dcm',
#  'ID_0234626e3.dcm',
#  'ID_f72672aeb.dcm',
#  'ID_85ad52519.dcm',
#  'ID_ed542cfb3.dcm',
#  'ID_4267fd580.dcm',
#  'ID_ec8cf1eac.dcm',
#  'ID_3c3ae3745.dcm',
#  'ID_cf09a0566.dcm',
#  'ID_a18d3d6a0.dcm',
#  'ID_77c949276.dcm',
#  'ID_dd54a7618.dcm',
#  'ID_13e81513f.dcm',
#  'ID_a2345fbb3.dcm',
#  'ID_3373489d4.dcm',
#  'ID_fe68499d5.dcm',
#  'ID_271595058.dcm',
#  'ID_e1cac9d1f.dcm',
#  'ID_3267a0e06.dcm',
#  'ID_bfb82d89a.dcm',
#  'ID_3a5c89221.dcm',
#  'ID_17dd44edb.dcm',
#  'ID_d4a8cca51.dcm',
#  'ID_8354b7bf2.dcm',
#  'ID_272b7e61a.dcm',
#  'ID_fedafa2b6.dcm',
#  'ID_630f6a22b.dcm',
#  'ID_e4f01d37a.dcm',
#  'ID_f0ed6ae2e.dcm',
#  'ID_458d50462.dcm',
#  'ID_6d2f3efcf.dcm',
#  'ID_76cbc86c8.dcm',
#  'ID_94e1f475c.dcm',
#  'ID_dfe0a736f.dcm',
#  'ID_050f1a4c5.dcm',
#  'ID_9fdb5105a.dcm',
#  'ID_6517c81a3.dcm',
#  'ID_979457304.dcm',
#  'ID_200415034.dcm',
#  'ID_8ddf70c38.dcm',
#  'ID_102e9d995.dcm',
#  'ID_ab313bcd2.dcm',
#  'ID_c61173303.dcm',
#  'ID_2c74bcf51.dcm',
#  'ID_da16c09be.dcm',
#  'ID_dffb0c4e7.dcm',
#  'ID_c5a5a6ccf.dcm',
#  'ID_d5c8dee3b.dcm',
#  'ID_cff25262d.dcm',
#  'ID_4762b04d3.dcm',
#  'ID_7835931d5.dcm',
#  'ID_22a997467.dcm',
#  'ID_1cfd0e74e.dcm',
#  'ID_c89439628.dcm',
#  'ID_0691d53f5.dcm',
#  'ID_b0be9cc18.dcm',
#  'ID_32ce29a0e.dcm',
#  'ID_49c233432.dcm',
#  'ID_a094df2cd.dcm',
#  'ID_ea9920006.dcm',
#  'ID_4d69e27d0.dcm',
#  'ID_5558e5bd7.dcm',
#  'ID_0ca48b3e7.dcm',
#  'ID_687160a34.dcm',
#  'ID_d37d101a5.dcm',
#  'ID_6070fadb2.dcm',
#  'ID_109f2da41.dcm',
#  'ID_196af1fc9.dcm',
#  'ID_3fc56fdd9.dcm',
#  'ID_66477f42d.dcm',
#  'ID_a1618faec.dcm',
#  'ID_dfd766bea.dcm',
#  'ID_55e5854f7.dcm',
#  'ID_e086411c6.dcm',
#  'ID_28efeda9a.dcm',
#  'ID_3077f0bd2.dcm',
#  'ID_892495a4f.dcm',
#  'ID_57c2106f6.dcm',
#  'ID_1157eddd0.dcm',
#  'ID_c8eb0c7a8.dcm',
#  'ID_95966d742.dcm',
#  'ID_9f9944519.dcm',
#  'ID_b48225e17.dcm',
#  'ID_b7763f6ec.dcm',
#  'ID_302fa4316.dcm',
#  'ID_3310ceb05.dcm',
#  'ID_26b83653c.dcm',
#  'ID_4f58f5b6c.dcm',
#  'ID_bd57ed15f.dcm',
#  'ID_79960ac3f.dcm',
#  'ID_1c29537aa.dcm',
#  'ID_67c1475a9.dcm',
#  'ID_109211035.dcm',
#  'ID_5f6cea4c1.dcm',
#  'ID_f1235b1e5.dcm',
#  'ID_4a8d7e2bd.dcm',
#  'ID_8b517bfa5.dcm',
#  'ID_eed2f4f0d.dcm',
#  'ID_cfeb8189c.dcm',
#  'ID_4282d42e7.dcm',
#  'ID_3be48b3ed.dcm',
#  'ID_1c40dbfc7.dcm',
#  'ID_80bffc6c3.dcm',
#  'ID_0289b1b85.dcm',
#  'ID_40a25bab6.dcm',
#  'ID_90483ea45.dcm',
#  'ID_7689d91d0.dcm',
#  'ID_617ee9fe3.dcm',
#  'ID_aa4d750c1.dcm',
#  'ID_ee587913b.dcm',
#  'ID_cfc68de9c.dcm',
#  'ID_63578aed5.dcm',
#  'ID_1dbc110c0.dcm',
#  'ID_dac56567f.dcm',
#  'ID_cdb904f17.dcm',
#  'ID_5d174294f.dcm',
#  'ID_7c1e2b4f5.dcm',
#  'ID_4423964f0.dcm',
#  'ID_f22d559e7.dcm',
#  'ID_d12c045a8.dcm',
#  'ID_db5a87911.dcm',
#  'ID_d18bfed24.dcm',
#  'ID_025564aa2.dcm',
#  'ID_c1c6d51b0.dcm',
#  'ID_ac123362c.dcm',
#  'ID_59178d086.dcm',
#  'ID_b04141c1f.dcm',
#  'ID_bcc8676ef.dcm',
#  'ID_461bc7855.dcm',
#  'ID_3b46b288e.dcm',
#  'ID_59b40a654.dcm',
#  'ID_7310f4447.dcm',
#  'ID_eafbe8234.dcm',
#  'ID_b2480ba22.dcm',
#  'ID_049f4d565.dcm',
#  'ID_b25a4c919.dcm',
#  'ID_db2694f3f.dcm',
#  'ID_6984df224.dcm',
#  'ID_b5c06c51b.dcm',
#  'ID_51b77d240.dcm',
#  'ID_b07c1b53e.dcm',
#  'ID_a890be0c6.dcm',
#  'ID_1d10d0396.dcm',
#  'ID_f2b2259b3.dcm',
#  'ID_fe383483c.dcm',
#  'ID_c1c618522.dcm',
#  'ID_1cbf8469a.dcm',
#  'ID_cce277131.dcm',
#  'ID_76f7f41e9.dcm',
#  'ID_99865be50.dcm',
#  'ID_3d3b8e320.dcm',
#  'ID_21bc10e37.dcm',
#  'ID_0702fd9bc.dcm',
#  'ID_e115f286f.dcm',
#  'ID_1a79f7d56.dcm',
#  'ID_8f302c5ba.dcm',
#  'ID_c51adb043.dcm',
#  'ID_af3ef9c1d.dcm',
#  'ID_e77f5ec6d.dcm',
#  'ID_e1c39fc89.dcm',
#  'ID_5d10991df.dcm',
#  'ID_1dc25e164.dcm',
#  'ID_8f0380d63.dcm',
#  'ID_8c068caa6.dcm',
#  'ID_8dee0baa0.dcm',
#  'ID_4fee374d9.dcm',
#  'ID_f289e0673.dcm',
#  'ID_115861381.dcm',
#  'ID_d340b3f79.dcm',
#  'ID_d1bf41d77.dcm',
#  'ID_75e36e92f.dcm',
#  'ID_47dab30a8.dcm',
#  'ID_a4dff2472.dcm',
#  'ID_4a0008083.dcm',
#  'ID_e86a944b8.dcm',
#  'ID_93ea4a0df.dcm',
#  'ID_9f8d7e0de.dcm',
#  'ID_685ca0f22.dcm',
#  'ID_7cb943cc7.dcm',
#  'ID_5ce7d303d.dcm',
#  'ID_44bdbb6a7.dcm',
#  'ID_772f9ad5f.dcm',
#  'ID_799bb070b.dcm',
#  'ID_0b7ec569e.dcm',
#  'ID_233b98849.dcm',
#  'ID_dca9f6903.dcm',
#  'ID_7b7e36019.dcm',
#  'ID_3a339c946.dcm',
#  'ID_c50ee289b.dcm',
#  'ID_15692be3e.dcm',
#  'ID_99dfe636d.dcm',
#  'ID_8a1693e09.dcm',
#  'ID_183a71ae6.dcm',
#  'ID_0cbcdfea3.dcm',
#  'ID_41efe9777.dcm',
#  'ID_0b0265d0a.dcm',
#  'ID_909ca65c2.dcm',
#  'ID_adf544059.dcm',
#  'ID_4ea19434d.dcm',
#  'ID_aac7398e3.dcm',
#  'ID_dc237482a.dcm',
#  'ID_0f1181883.dcm',
#  'ID_bc7a89e1b.dcm',
#  'ID_c784d2845.dcm',
#  'ID_20d8b570e.dcm',
#  'ID_874d6a875.dcm',
#  'ID_02f7810c8.dcm',
#  'ID_6765a3879.dcm',
#  'ID_a556ffd18.dcm',
#  'ID_cb9040ed1.dcm',
#  'ID_2ea91eeb9.dcm',
#  'ID_78bcde0cd.dcm',
#  'ID_ab8aec932.dcm',
#  'ID_3765116dd.dcm',
#  'ID_1766258bd.dcm',
#  'ID_c98609a39.dcm',
#  'ID_bc43b1a2f.dcm',
#  'ID_d319350d0.dcm',
#  'ID_0cb4421fa.dcm',
#  'ID_46ad768c6.dcm',
#  'ID_28c0eaaf3.dcm',
#  'ID_a963c062e.dcm',
#  'ID_7f4f572f9.dcm',
#  'ID_792493278.dcm',
#  'ID_71f85dd7f.dcm',
#  'ID_48abba346.dcm',
#  'ID_0ad02d666.dcm',
#  'ID_76c58f1e7.dcm',
#  'ID_54e25d118.dcm',
#  'ID_3cb33e908.dcm',
#  'ID_af501a831.dcm',
#  'ID_a6ae984de.dcm',
#  'ID_7b26b1fa1.dcm',
#  'ID_ee8baffa8.dcm',
#  'ID_833a057c5.dcm',
#  'ID_3cf8fd4a4.dcm',
#  'ID_801cfd15c.dcm',
#  'ID_a5a21aced.dcm',
#  'ID_1adf2a2f5.dcm',
#  'ID_1b4e40479.dcm',
#  'ID_ae4e161c5.dcm',
#  'ID_35132f0eb.dcm',
#  'ID_54d5c266f.dcm',
#  'ID_484156b02.dcm',
#  'ID_38ec62164.dcm',
#  'ID_7ee2bfb7a.dcm',
#  'ID_baf819781.dcm',
#  'ID_79e21a959.dcm',
#  'ID_a428e6e86.dcm',
#  'ID_3b7f9014a.dcm',
#  'ID_2570be225.dcm',
#  'ID_af1e81ca9.dcm',
#  'ID_433be80d0.dcm',
#  'ID_9138d9e05.dcm',
#  'ID_d8a6e1b0c.dcm',
#  'ID_88ba7bf9e.dcm',
#  'ID_c1b23f05a.dcm',
#  'ID_7eaf1105c.dcm',
#  'ID_1777c68bf.dcm',
#  'ID_663ce4595.dcm',
#  'ID_1ab81ac9b.dcm',
#  'ID_4aa9d9187.dcm',
#  'ID_80c0ef856.dcm',
#  'ID_62b1106c0.dcm',
#  'ID_f511147a6.dcm',
#  'ID_e1d001185.dcm',
#  'ID_10ed36231.dcm',
#  'ID_a003a12f1.dcm',
#  'ID_1efc42fd7.dcm',
#  'ID_cfb27d806.dcm',
#  'ID_e0192d560.dcm',
#  'ID_6258b9118.dcm',
#  'ID_31e4177bf.dcm',
#  'ID_00d3a9006.dcm',
#  'ID_b5c129cff.dcm',
#  'ID_561786896.dcm',
#  'ID_59d0686c2.dcm',
#  'ID_a1351bd0e.dcm',
#  'ID_f3ed36295.dcm',
#  'ID_be6d3d704.dcm',
#  'ID_edb9bc320.dcm',
#  'ID_385593da7.dcm',
#  'ID_be761d246.dcm',
#  'ID_8eeb69a00.dcm',
#  'ID_34c94c18f.dcm',
#  'ID_03981faca.dcm',
#  'ID_9fd9b04fc.dcm',
#  'ID_8fda7875c.dcm',
#  'ID_a121981db.dcm',
#  'ID_9eee08c14.dcm',
#  'ID_cff1b8970.dcm',
#  'ID_5cb176bf2.dcm',
#  'ID_f38ed07cf.dcm',
#  'ID_9ff0a1f84.dcm',
#  'ID_0d97af2ba.dcm',
#  'ID_7932e7191.dcm',
#  'ID_617e49305.dcm',
#  'ID_c7d8738a3.dcm',
#  'ID_d3f87a2dc.dcm',
#  'ID_75847e845.dcm',
#  'ID_6d16c54fd.dcm',
#  'ID_be2b6e0f2.dcm',
#  'ID_b103df7c0.dcm',
#  'ID_9dd8d7b4c.dcm',
#  'ID_de8ebb06c.dcm',
#  'ID_2db50a194.dcm',
#  'ID_83b2d75a1.dcm',
#  'ID_2666251b1.dcm',
#  'ID_94cc8ec6a.dcm',
#  'ID_8420a6e95.dcm',
#  'ID_a57790b39.dcm',
#  'ID_28f7b6d63.dcm',
#  'ID_dcc6ea3d0.dcm',
#  'ID_da375bd3c.dcm',
#  'ID_794828004.dcm',
#  'ID_33151eae8.dcm',
#  'ID_599d3447e.dcm',
#  'ID_87a15d5f3.dcm',
#  'ID_9ea51d710.dcm',
#  'ID_222bba0c9.dcm',
#  'ID_b747ccfec.dcm',
#  'ID_e48f81aaa.dcm',
#  'ID_34ba7490f.dcm',
#  'ID_ef05f3c6d.dcm',
#  'ID_45bd3da5d.dcm',
#  'ID_823b58f94.dcm',
#  'ID_ba7db1cf4.dcm',
#  'ID_a59187df2.dcm',
#  'ID_773654b1f.dcm',
#  'ID_47a146953.dcm',
#  'ID_83fa9f821.dcm',
#  'ID_faeafdf55.dcm',
#  'ID_e034ff7df.dcm',
#  'ID_f7d0b7590.dcm',
#  'ID_88fb981e2.dcm',
#  'ID_4fde01d24.dcm',
#  'ID_b8b6ad81a.dcm',
#  'ID_976300b95.dcm',
#  'ID_eee05a76b.dcm',
#  'ID_25963b03b.dcm',
#  'ID_2e311a789.dcm',
#  'ID_30642e2a5.dcm',
#  'ID_378404e01.dcm',
#  'ID_33ac50d91.dcm',
#  'ID_1c99fdc16.dcm',
#  'ID_0b704878a.dcm',
#  'ID_37cbef2fe.dcm',
#  'ID_f1fda0d99.dcm',
#  'ID_c1145c6c0.dcm',
#  'ID_74388dca2.dcm',
#  'ID_c056a2e55.dcm',
#  'ID_e525df03f.dcm',
#  'ID_d1ea73306.dcm',
#  'ID_ed72efd8f.dcm',
#  'ID_45d361ee1.dcm',
#  'ID_8d8139c71.dcm',
#  'ID_a9bc481d2.dcm',
#  'ID_dfa9fe3f0.dcm',
#  'ID_92fd0b89c.dcm',
#  'ID_22c07e3eb.dcm',
#  'ID_be3f30e32.dcm',
#  'ID_94f29144d.dcm',
#  'ID_20c322c29.dcm',
#  'ID_75c55cb11.dcm',
#  'ID_5f0166eb3.dcm',
#  'ID_98f4d7c54.dcm',
#  'ID_b61e42d08.dcm',
#  'ID_1c4e212fa.dcm',
#  'ID_d6c413310.dcm',
#  'ID_cddfd4cc6.dcm',
#  'ID_62fdb78a8.dcm',
#  'ID_3cdd550b9.dcm',
#  'ID_f99d9af77.dcm',
#  'ID_90ff2087d.dcm',
#  'ID_03c476e68.dcm',
#  'ID_624d1aa0d.dcm',
#  'ID_438eb5f4c.dcm',
#  'ID_e88d48018.dcm',
#  'ID_4c2b528ec.dcm',
#  'ID_4a5d99cf0.dcm',
#  'ID_10833b6d3.dcm',
#  'ID_f615cf689.dcm',
#  'ID_161ac113e.dcm',
#  'ID_94c3d7c30.dcm',
#  'ID_0d52f1134.dcm',
#  'ID_e8492e11d.dcm',
#  'ID_ea875c2d2.dcm',
#  'ID_fb9a502cc.dcm',
#  'ID_047f87535.dcm',
#  'ID_1949b20e1.dcm',
#  'ID_70cd89b6e.dcm',
#  'ID_296d96358.dcm',
#  'ID_4b5dfe0fd.dcm',
#  'ID_96e106dc1.dcm',
#  'ID_29d7cda92.dcm',
#  'ID_07ec2ff3d.dcm',
#  'ID_ef7df244d.dcm',
#  'ID_1c45cebe8.dcm',
#  'ID_75432a5a3.dcm',
#  'ID_b1dd5aef3.dcm',
#  'ID_fb79971b1.dcm',
#  'ID_eb77b8f49.dcm',
#  'ID_ee409bee6.dcm',
#  'ID_35ca03c08.dcm',
#  'ID_4ecec0f54.dcm',
#  'ID_0632e3d24.dcm',
#  'ID_76e783029.dcm',
#  'ID_b05c6842b.dcm',
#  'ID_cb4ca206c.dcm',
#  'ID_f4d8534b1.dcm',
#  'ID_bccf40ed9.dcm',
#  'ID_4593c4dc4.dcm',
#  'ID_4caf0ab8d.dcm',
#  'ID_85c6b0fe1.dcm',
#  'ID_ff22a4d06.dcm',
#  'ID_14264f0cb.dcm',
#  'ID_5b2c58bc9.dcm',
#  'ID_057524aaf.dcm',
#  'ID_b88d0a324.dcm',
#  'ID_28805a87b.dcm',
#  'ID_010050ce4.dcm',
#  'ID_a9aefd58c.dcm',
#  'ID_3c88012c1.dcm',
#  'ID_c2c1f5bdc.dcm',
#  'ID_35eb0d355.dcm',
#  'ID_330f5b238.dcm',
#  'ID_4347f8a62.dcm',
#  'ID_bda2356dd.dcm',
#  'ID_ed698d7b5.dcm',
#  'ID_9083724db.dcm',
#  'ID_e5951abd0.dcm',
#  'ID_3105f9160.dcm',
#  'ID_4f4b30c07.dcm',
#  'ID_a84afc3f8.dcm',
#  'ID_afa4566c1.dcm',
#  'ID_afb2315d2.dcm',
#  'ID_d04fa52d9.dcm',
#  'ID_940a1d8cc.dcm',
#  'ID_e9a10b5ea.dcm',
#  'ID_e342ae1b7.dcm',
#  'ID_5b606c10f.dcm',
#  'ID_f2184c721.dcm',
#  'ID_69d207c52.dcm',
#  'ID_7555d56ed.dcm',
#  'ID_b8e7b4c28.dcm',
#  'ID_e9c90195b.dcm',
#  'ID_8f7324119.dcm',
#  'ID_589cd9a1c.dcm',
#  'ID_c5080ac80.dcm',
#  'ID_2d7971080.dcm',
#  'ID_7a92d94f7.dcm',
#  'ID_83cf03648.dcm',
#  'ID_963e7abf3.dcm',
#  'ID_0969270fa.dcm',
#  'ID_100e1c64c.dcm',
#  'ID_fe2947313.dcm',
#  'ID_b01f29313.dcm',
#  'ID_f1b11e453.dcm',
#  'ID_79e98c6a4.dcm',
#  'ID_795a57416.dcm',
#  'ID_0429abb5e.dcm',
#  'ID_502a01ee1.dcm',
#  'ID_7b17697d1.dcm',
#  'ID_4fb3c3425.dcm',
#  'ID_099a1dc2f.dcm',
#  'ID_39f914c62.dcm',
#  'ID_bf5053c61.dcm',
#  'ID_a81f1d140.dcm',
#  'ID_bc36ef5e7.dcm',
#  'ID_4605b02dd.dcm',
#  'ID_2f116ca4c.dcm',
#  'ID_e4581cd48.dcm',
#  'ID_b710010bc.dcm',
#  'ID_2a089f8f1.dcm',
#  'ID_02aac33c8.dcm',
#  'ID_5b1a98859.dcm',
#  'ID_1a13b1e77.dcm',
#  'ID_d0777d3b9.dcm',
#  'ID_800e54da1.dcm',
#  'ID_0e7a32ea5.dcm',
#  'ID_4887f20d2.dcm',
#  'ID_f7ad14c7b.dcm',
#  'ID_a08d9ec29.dcm',
#  'ID_a048ecfe0.dcm',
#  'ID_55e294f41.dcm',
#  'ID_c46824fe8.dcm',
#  'ID_2425a807a.dcm',
#  'ID_af8406d1e.dcm',
#  'ID_b49667182.dcm',
#  'ID_16fc6be4a.dcm',
#  'ID_51de04c37.dcm',
#  'ID_a2d9a6113.dcm',
#  'ID_20cd658a9.dcm',
#  'ID_7c9fae3ab.dcm',
#  'ID_7151110de.dcm',
#  'ID_2824603dd.dcm',
#  'ID_4e7bf032e.dcm',
#  'ID_ee941e986.dcm',
#  'ID_760a15af4.dcm',
#  'ID_fae883e10.dcm',
#  'ID_e4f471f7c.dcm',
#  'ID_8ecb26720.dcm',
#  'ID_a1442732d.dcm',
#  'ID_38ff6d9f7.dcm',
#  'ID_3a0e4639f.dcm',
#  'ID_f1d0fddd4.dcm',
#  'ID_119e41bfc.dcm',
#  'ID_97d652517.dcm',
#  'ID_50093d4db.dcm',
#  'ID_a8d635cdf.dcm',
#  'ID_357bd1db9.dcm',
#  'ID_51983acc8.dcm',
#  'ID_c55040c38.dcm',
#  'ID_4052e447c.dcm',
#  'ID_6d4832b72.dcm',
#  'ID_c6a477945.dcm',
#  'ID_96a19375b.dcm',
#  'ID_b70d52add.dcm',
#  'ID_e11a1d077.dcm',
#  'ID_6921277d5.dcm',
#  'ID_d10bc265a.dcm',
#  'ID_de878c2a8.dcm',
#  'ID_57308f327.dcm',
#  'ID_be5eec59c.dcm',
#  'ID_8df287628.dcm',
#  'ID_346c43c12.dcm',
#  'ID_39ae3a15f.dcm',
#  'ID_eab49013e.dcm',
#  'ID_b199adcd6.dcm',
#  'ID_7598e9fe2.dcm',
#  'ID_c6b0996a9.dcm',
#  'ID_5f9b73977.dcm',
#  'ID_faee6c984.dcm',
#  'ID_3a183c0c9.dcm',
#  'ID_485fd90dd.dcm',
#  'ID_8b8b1e941.dcm',
#  'ID_7a13e8746.dcm',
#  'ID_2905f29fe.dcm',
#  'ID_b11d923b5.dcm',
#  'ID_0deb3a700.dcm',
#  'ID_bf73543ae.dcm',
#  'ID_e0cb23ac3.dcm',
#  'ID_f351ae411.dcm',
#  'ID_70621f547.dcm',
#  'ID_ee4825d16.dcm',
#  'ID_911e0d667.dcm',
#  'ID_ff2bca9f6.dcm',
#  'ID_9fea77f6c.dcm',
#  'ID_1c77d2820.dcm',
#  'ID_b99a4f288.dcm',
#  'ID_89e0b0215.dcm',
#  'ID_67adbfd01.dcm',
#  'ID_cb0e199fa.dcm',
#  'ID_b2f928c0a.dcm',
#  'ID_070d3f752.dcm',
#  'ID_f4a7adff5.dcm',
#  'ID_03fabb133.dcm',
#  'ID_95c2c2a36.dcm',
#  'ID_98d87e303.dcm',
#  'ID_8c1d23539.dcm',
#  'ID_e20a83993.dcm',
#  ...]

# %%
df_trn = df_trn[~(df_trn.img_pct_window<0.025)]
a = df_trn.PatientID.value_counts().reset_index()
a.columns = ['PatientID', 'num']
val_ID = a.PatientID[4::5].tolist()
val_img = df_trn[df_trn.PatientID.isin(val_ID)].SOPInstanceUID.tolist()
val_img = [s + '.dcm' for s in val_img]

# %%
df_train = df_train[~(df_train.fn.isin(bad_img))]
df_train.loc[~(df_train.fn.isin(val_img)), 'is_valid'] = False
df_train.loc[df_train.fn.isin(val_img), 'is_valid'] = True
# df_train = df_train[:50000].copy()
df_train.reset_index(drop=True, inplace=True)
df_train
# Out:
#                       fn                                      labels is_valid
# 0       ID_63eb1e259.dcm                                                False
# 1       ID_2669954a7.dcm                                                False
# 2       ID_52c9913b1.dcm                                                False
# 3       ID_4e6ff6126.dcm                                                False
# 4       ID_7858edd88.dcm                                                False
# ...                  ...                                         ...      ...
# 591938  ID_6a6cd0773.dcm                                                 True
# 591939  ID_f737f4cc1.dcm                                                False
# 591940  ID_a9797cb3a.dcm                                                False
# 591941  ID_9375f67bd.dcm                                                 True
# 591942  ID_5c8b5d701.dcm  intraparenchymal subarachnoid subdural any    False
#
# [591943 rows x 3 columns]

# %%
sub1 = pd.read_csv(path/'stage_1_sample_submission.csv')
sub1['fn'] = sub1.ID.apply(lambda x: '_'.join(x.split('_')[:2]) + '.dcm')
sub1.columns = ['ID', 'probability', 'fn']
sub1['label'] = sub1.ID.apply(lambda x: x.split('_')[-1])
sub1.drop_duplicates('ID', inplace=True)
sub = sub1.pivot(index='fn', columns='label', values='probability')
sub.reset_index(inplace=True)
sub
# Out:
# label                fn  any  epidural  intraparenchymal  intraventricular  \
# 0      ID_000012eaf.dcm  0.5       0.5               0.5               0.5
# 1      ID_0000ca2f6.dcm  0.5       0.5               0.5               0.5
# 2      ID_000259ccf.dcm  0.5       0.5               0.5               0.5
# 3      ID_0002d438a.dcm  0.5       0.5               0.5               0.5
# 4      ID_00032d440.dcm  0.5       0.5               0.5               0.5
# ...                 ...  ...       ...               ...               ...
# 78540  ID_fffe2edb8.dcm  0.5       0.5               0.5               0.5
# 78541  ID_ffff3212e.dcm  0.5       0.5               0.5               0.5
# 78542  ID_ffff59a97.dcm  0.5       0.5               0.5               0.5
# 78543  ID_ffffb670a.dcm  0.5       0.5               0.5               0.5
# 78544  ID_ffffcbff8.dcm  0.5       0.5               0.5               0.5
#
# label  subarachnoid  subdural
# 0               0.5       0.5
# 1               0.5       0.5
# 2               0.5       0.5
# 3               0.5       0.5
# 4               0.5       0.5
# ...             ...       ...
# 78540           0.5       0.5
# 78541           0.5       0.5
# 78542           0.5       0.5
# 78543           0.5       0.5
# 78544           0.5       0.5
#
# [78545 rows x 7 columns]

# %%
class DicomImage(Image):
    "DicomImage to support applying transforms to image data in `px`."
    def __init__(self, px:Tensor):
        self._px = px
        self._logit_px=None
        self._flow=None
        self._affine_mat=None
        self.sample_kwargs = {}
    
    def _repr_image_format(self, format_str):
        with BytesIO() as str_buffer:
            plt.imsave(str_buffer, image2np(self.px[0].unsqueeze(0)), # We show only one channel!
                       format=format_str, cmap=cmap)
            return str_buffer.getvalue()
        
    def clone(self):
        "Mimic the behavior of torch.clone for `Image` objects."
        return self.__class__(self.px.clone())

    @property
    def data(self)->TensorImage:
        "Return this images pixels as a tensor."
        return self.px
    
    def show(self, ax:plt.Axes=None, figsize:tuple=(3,3), title:Optional[str]=None, hide_axis:bool=True,
              cmap:str=cmap, y:Any=None, **kwargs):
        "Show image on `ax` with `title`, overlaid with optional `y`"
        ax = show_dicom_image(self, ax=ax, hide_axis=hide_axis, cmap=cmap, figsize=figsize)
        if y is not None: y.show(ax=ax, **kwargs)
        if title is not None: ax.set_title(title)

# %%
def open_dicom_image(fn:PathOrStr, cls:type=DicomImage, 
                     after_open:Callable=None, expand=True,
                     clamp_min=-1024, clamp_max=1024)->Image:
    "Return `Image` object created from image in file `fn`."
    
    def correct_dcm(dcm):
        x = dcm.pixel_array + 1000
        px_mode = 4096
        x[x>=px_mode] = x[x>=px_mode] - px_mode
        dcm.PixelData = x.tobytes()
        dcm.RescaleIntercept = -1000
        
    def window_image(dcm, window_center, window_width):
    
        if (dcm.BitsStored == 12) and (dcm.PixelRepresentation == 0) and (int(dcm.RescaleIntercept) > -100):
            correct_dcm(dcm)

        img = dcm.pixel_array * dcm.RescaleSlope + dcm.RescaleIntercept
        img_min = window_center - window_width // 2
        img_max = window_center + window_width // 2
        img = np.clip(img, img_min, img_max)

        return img

    def bsb_window(dcm):
        brain_img = window_image(dcm, 40, 80)
        subdural_img = window_image(dcm, 80, 200)
        soft_img = window_image(dcm, 40, 380)

        brain_img = (brain_img - 0) / 80
        subdural_img = (subdural_img - (-20)) / 200
        soft_img = (soft_img - (-150)) / 380
        bsb_img = np.array([brain_img, subdural_img, soft_img])

        return bsb_img
    
    dcm = pydicom.dcmread(fn) # open dicom image as dicom dataset
    #img = ds.pixel_array # get pixel data as np array
    #if (dcm.BitsStored == 12) and (dcm.PixelRepresentation == 0) and (int(dcm.RescaleIntercept) > -100):
    #    correct_dcm(dcm)
    
    
    # Convert to Hounsfield units (HU) and rescale and set intercept.
    # In this setup we only take a look at the values between -1024 and 1024.
    # Values below will be set to -1024, values above to 1024
    #resc_img = dcm.pixel_array * dcm.RescaleSlope + dcm.RescaleIntercept
    #resc_img[resc_img < -1024] = clamp_min # Clamp to minimum value   
    #resc_img[resc_img > 1024] = clamp_max # Clamp to maximum value
    #resc_img = (resc_img - clamp_min) / (clamp_max - clamp_min) # rescale to range from 0 to 1
    
    resc_img = bsb_window(dcm)
    
    if after_open: resc_img = after_open(resc_img)
    
    #resc_img = torch.from_numpy(resc_img.astype(np.float32, copy=False))
    x = torch.from_numpy(resc_img.astype(np.float32, copy=False))
    #x = resc_img.view(1,*resc_img.shape)
    #x = resc_img.view()
    
    #if expand: x = x.expand(3,*x.shape[-2:])
    # x.shape[-2:] is needed because not everything is of size 512x512!
    # expand is memory efficient: https://stackoverflow.com/questions/44593141/stacking-copies-of-an-array-a-torch-tensor-efficiently
                
    return cls(x)

# %%
def show_dicom_image(img:Image, ax:plt.Axes=None, figsize:tuple=(3,3), hide_axis:bool=True, cmap:str=cmap,
                alpha:float=None, **kwargs)->plt.Axes:
    "Display `DicomImage` in the notebook."
    if ax is None: fig,ax = plt.subplots(figsize=figsize)
    ax.imshow(image2np(img.data.data[0].unsqueeze(0)), # We show only one channel!
              cmap=cmap, alpha=alpha, **kwargs)
    if hide_axis: ax.axis('off')
    return ax

# %%
class DicomImageList(ImageList):
    def __init__(self, *args, after_open:Callable=None, **kwargs):
        super().__init__(*args, **kwargs)
        self.after_open = after_open
        self.c,self.sizes = 1,{}
        
    def open(self, fn):
        "Open image in `fn`, subclass and overwrite for custom behavior."
        return open_dicom_image(fn, after_open=self.after_open)
    
    # based on https://github.com/radekosmulski/rsna-intracranial/blob/master/03_train_basic_model.ipynb
    def label_from_df(self, cols:IntsOrStrs=1, label_cls:Callable=None, **kwargs):
        "Label `self.items` from the values in `cols` in `self.inner_df`."
        self.inner_df.labels.fillna('', inplace=True)
        labels = self.inner_df.iloc[:,df_names_to_idx(cols, self.inner_df)]
        assert labels.isna().sum().sum() == 0, f"You have NaN values in column(s) {cols} of your dataframe, please fix it."
        if is_listy(cols) and len(cols) > 1 and (label_cls is None or label_cls == MultiCategoryList):
            new_kwargs,label_cls = dict(one_hot=True, classes= cols),MultiCategoryList
            kwargs = {**new_kwargs, **kwargs}
        return self._label_from_list(_maybe_squeeze(labels), label_cls=label_cls, **kwargs)
    
    def show_xys(self, xs, ys, imgsize:int=4, figsize:Optional[Tuple[int,int]]=None, **kwargs):
        "Show the `xs` (inputs) and `ys` (targets) on a figure of `figsize`."
        rows = int(np.ceil(math.sqrt(len(xs))))
        axs = subplots(rows, rows, imgsize=imgsize, figsize=figsize)
        for x,y,ax in zip(xs, ys, axs.flatten()): x.show(ax=ax, y=y, **kwargs)
        for ax in axs.flatten()[len(xs):]: ax.axis('off')
        plt.tight_layout()
        
    def reconstruct(self, t): return DicomImage(t)

# %%
fn = '/mnt/fst/shaan/rsna-intracranial-hemorrhage-detection/stage_1_train_images/ID_52c9913b1.dcm'
fn
# Out:
# '/mnt/fst/shaan/rsna-intracranial-hemorrhage-detection/stage_1_train_images/ID_52c9913b1.dcm'

# %%
img = open_dicom_image(fn)
img
# Out:
# DicomImage (3, 512, 512)

# %%
img.resize(410)
# Out:
# DicomImage (3, 512, 512)

# %%
tfms = get_transforms(do_flip=True, max_lighting=0.1, max_zoom=1.05, max_warp=0.)

# %%
np.random.seed(42)
src = (DicomImageList.from_df(df_train, path, folder='stage_1_train_images')
       .split_from_df()
       .label_from_df(cols=-2, label_delim=' '))

# %%
data = (src.transform(tfms, size=410)
        .databunch(bs=16).normalize(imagenet_stats))

# %%
test = DicomImageList.from_df(sub, path=path, folder='stage_1_test_images')
test
# Out:
# DicomImageList (78545 items)
# DicomImage (3, 512, 512),DicomImage (3, 512, 512),DicomImage (3, 512, 512),DicomImage (3, 512, 512),DicomImage (3, 512, 512)
# Path: /mnt/fst/shaan/rsna-intracranial-hemorrhage-detection

# %%
data.add_test(test)

# %%
data
# Out:
# ImageDataBunch;
#
# Train: LabelList (473732 items)
# x: DicomImageList
# DicomImage (3, 410, 410),DicomImage (3, 410, 410),DicomImage (3, 410, 410),DicomImage (3, 410, 410),DicomImage (3, 410, 410)
# y: MultiCategoryList
# ,,,,
# Path: /mnt/fst/shaan/rsna-intracranial-hemorrhage-detection;
#
# Valid: LabelList (118211 items)
# x: DicomImageList
# DicomImage (3, 410, 410),DicomImage (3, 410, 410),DicomImage (3, 410, 410),DicomImage (3, 410, 410),DicomImage (3, 410, 410)
# y: MultiCategoryList
# ,,,,
# Path: /mnt/fst/shaan/rsna-intracranial-hemorrhage-detection;
#
# Test: LabelList (78545 items)
# x: DicomImageList
# DicomImage (3, 410, 410),DicomImage (3, 410, 410),DicomImage (3, 410, 410),DicomImage (3, 410, 410),DicomImage (3, 410, 410)
# y: EmptyLabelList
# ,,,,
# Path: /mnt/fst/shaan/rsna-intracranial-hemorrhage-detection

# %%
data.show_batch()

# %%
from efficientnet_pytorch import EfficientNet

model = EfficientNet.from_pretrained('efficientnet-b2', num_classes=data.c)
# Out:
# Loaded pretrained weights for efficientnet-b2

# %%
# loss_weights = [2,1,1,1,1,1]
# loss = torch.nn.BCEWithLogitsLoss(pos_weight=torch.tensor(loss_weights).float().cuda())
# def loss_fn(preds, targ): 
#     return loss(preds, targ.float())

# %%
learn = Learner(data, model, loss_func=torch.nn.BCEWithLogitsLoss(), metrics=fbeta)

# %%
learn
# Out:
# Learner(data=ImageDataBunch;
#
# Train: LabelList (473732 items)
# x: DicomImageList
# DicomImage (3, 410, 410),DicomImage (3, 410, 410),DicomImage (3, 410, 410),DicomImage (3, 410, 410),DicomImage (3, 410, 410)
# y: MultiCategoryList
# ,,,,
# Path: /mnt/fst/shaan/rsna-intracranial-hemorrhage-detection;
#
# Valid: LabelList (118211 items)
# x: DicomImageList
# DicomImage (3, 410, 410),DicomImage (3, 410, 410),DicomImage (3, 410, 410),DicomImage (3, 410, 410),DicomImage (3, 410, 410)
# y: MultiCategoryList
# ,,,,
# Path: /mnt/fst/shaan/rsna-intracranial-hemorrhage-detection;
#
# Test: LabelList (78545 items)
# x: DicomImageList
# DicomImage (3, 410, 410),DicomImage (3, 410, 410),DicomImage (3, 410, 410),DicomImage (3, 410, 410),DicomImage (3, 410, 410)
# y: EmptyLabelList
# ,,,,
# Path: /mnt/fst/shaan/rsna-intracranial-hemorrhage-detection, model=EfficientNet(
#   (_conv_stem): Conv2dStaticSamePadding(
#     3, 32, kernel_size=(3, 3), stride=(2, 2), bias=False
#     (static_padding): ZeroPad2d(padding=(0, 1, 0, 1), value=0.0)
#   )
#   (_bn0): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (_blocks): ModuleList(
#     (0): MBConvBlock(
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         32, 32, kernel_size=(3, 3), stride=[1, 1], groups=32, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         32, 8, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         8, 32, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(16, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (1): MBConvBlock(
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         16, 16, kernel_size=(3, 3), stride=(1, 1), groups=16, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(16, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         16, 4, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         4, 16, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(16, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (2): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(96, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         96, 96, kernel_size=(3, 3), stride=[2, 2], groups=96, bias=False
#         (static_padding): ZeroPad2d(padding=(0, 1, 0, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(96, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         96, 4, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         4, 96, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(24, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (3): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         144, 144, kernel_size=(3, 3), stride=(1, 1), groups=144, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         144, 6, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         6, 144, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(24, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (4): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         144, 144, kernel_size=(3, 3), stride=(1, 1), groups=144, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         144, 6, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         6, 144, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(24, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (5): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         144, 144, kernel_size=(5, 5), stride=[2, 2], groups=144, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 2, 1, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         144, 6, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         6, 144, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         144, 48, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(48, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (6): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(288, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         288, 288, kernel_size=(5, 5), stride=(1, 1), groups=288, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(288, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         288, 12, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         12, 288, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(48, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (7): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(288, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         288, 288, kernel_size=(5, 5), stride=(1, 1), groups=288, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(288, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         288, 12, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         12, 288, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(48, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (8): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(288, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         288, 288, kernel_size=(3, 3), stride=[2, 2], groups=288, bias=False
#         (static_padding): ZeroPad2d(padding=(0, 1, 0, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(288, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         288, 12, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         12, 288, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         288, 88, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(88, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (9): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         88, 528, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(528, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         528, 528, kernel_size=(3, 3), stride=(1, 1), groups=528, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(528, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         528, 22, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         22, 528, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         528, 88, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(88, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (10): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         88, 528, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(528, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         528, 528, kernel_size=(3, 3), stride=(1, 1), groups=528, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(528, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         528, 22, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         22, 528, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         528, 88, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(88, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (11): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         88, 528, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(528, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         528, 528, kernel_size=(3, 3), stride=(1, 1), groups=528, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(528, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         528, 22, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         22, 528, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         528, 88, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(88, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (12): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         88, 528, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(528, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         528, 528, kernel_size=(5, 5), stride=[1, 1], groups=528, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(528, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         528, 22, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         22, 528, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         528, 120, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(120, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (13): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         120, 720, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(720, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         720, 720, kernel_size=(5, 5), stride=(1, 1), groups=720, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(720, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         720, 30, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         30, 720, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         720, 120, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(120, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (14): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         120, 720, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(720, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         720, 720, kernel_size=(5, 5), stride=(1, 1), groups=720, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(720, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         720, 30, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         30, 720, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         720, 120, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(120, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (15): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         120, 720, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(720, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         720, 720, kernel_size=(5, 5), stride=(1, 1), groups=720, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(720, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         720, 30, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         30, 720, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         720, 120, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(120, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (16): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         120, 720, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(720, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         720, 720, kernel_size=(5, 5), stride=[2, 2], groups=720, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 2, 1, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(720, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         720, 30, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         30, 720, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         720, 208, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(208, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (17): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         208, 1248, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1248, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1248, 1248, kernel_size=(5, 5), stride=(1, 1), groups=1248, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(1248, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1248, 52, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         52, 1248, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1248, 208, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(208, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (18): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         208, 1248, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1248, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1248, 1248, kernel_size=(5, 5), stride=(1, 1), groups=1248, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(1248, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1248, 52, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         52, 1248, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1248, 208, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(208, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (19): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         208, 1248, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1248, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1248, 1248, kernel_size=(5, 5), stride=(1, 1), groups=1248, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(1248, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1248, 52, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         52, 1248, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1248, 208, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(208, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (20): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         208, 1248, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1248, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1248, 1248, kernel_size=(5, 5), stride=(1, 1), groups=1248, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(1248, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1248, 52, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         52, 1248, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1248, 208, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(208, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (21): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         208, 1248, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1248, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1248, 1248, kernel_size=(3, 3), stride=[1, 1], groups=1248, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(1248, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1248, 52, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         52, 1248, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1248, 352, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(352, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (22): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         352, 2112, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(2112, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         2112, 2112, kernel_size=(3, 3), stride=(1, 1), groups=2112, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(2112, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         2112, 88, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         88, 2112, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         2112, 352, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(352, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#   )
#   (_conv_head): Conv2dStaticSamePadding(
#     352, 1408, kernel_size=(1, 1), stride=(1, 1), bias=False
#     (static_padding): Identity()
#   )
#   (_bn1): BatchNorm2d(1408, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (_avg_pooling): AdaptiveAvgPool2d(output_size=1)
#   (_dropout): Dropout(p=0.3, inplace=False)
#   (_fc): Linear(in_features=1408, out_features=6, bias=True)
#   (_swish): MemoryEfficientSwish()
# ), opt_func=functools.partial(<class 'torch.optim.adam.Adam'>, betas=(0.9, 0.99)), loss_func=BCEWithLogitsLoss(), metrics=[<function fbeta at 0x7fc907dfc510>], true_wd=True, bn_wd=True, wd=0.01, train_bn=True, path=PosixPath('/mnt/fst/shaan/rsna-intracranial-hemorrhage-detection'), model_dir='models', callback_fns=[functools.partial(<class 'fastai.basic_train.Recorder'>, add_time=True, silent=False)], callbacks=[], layer_groups=[Sequential(
#   (0): ZeroPad2d(padding=(0, 1, 0, 1), value=0.0)
#   (1): ParameterModule()
#   (2): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (3): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#   (4): ParameterModule()
#   (5): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (6): Identity()
#   (7): ParameterModule()
#   (8): ParameterModule()
#   (9): Identity()
#   (10): ParameterModule()
#   (11): ParameterModule()
#   (12): Identity()
#   (13): ParameterModule()
#   (14): BatchNorm2d(16, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (15): MemoryEfficientSwish()
#   (16): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#   (17): ParameterModule()
#   (18): BatchNorm2d(16, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (19): Identity()
#   (20): ParameterModule()
#   (21): ParameterModule()
#   (22): Identity()
#   (23): ParameterModule()
#   (24): ParameterModule()
#   (25): Identity()
#   (26): ParameterModule()
#   (27): BatchNorm2d(16, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (28): MemoryEfficientSwish()
#   (29): Identity()
#   (30): ParameterModule()
#   (31): BatchNorm2d(96, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (32): ZeroPad2d(padding=(0, 1, 0, 1), value=0.0)
#   (33): ParameterModule()
#   (34): BatchNorm2d(96, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (35): Identity()
#   (36): ParameterModule()
#   (37): ParameterModule()
#   (38): Identity()
#   (39): ParameterModule()
#   (40): ParameterModule()
#   (41): Identity()
#   (42): ParameterModule()
#   (43): BatchNorm2d(24, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (44): MemoryEfficientSwish()
#   (45): Identity()
#   (46): ParameterModule()
#   (47): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (48): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#   (49): ParameterModule()
#   (50): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (51): Identity()
#   (52): ParameterModule()
#   (53): ParameterModule()
#   (54): Identity()
#   (55): ParameterModule()
#   (56): ParameterModule()
#   (57): Identity()
#   (58): ParameterModule()
#   (59): BatchNorm2d(24, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (60): MemoryEfficientSwish()
#   (61): Identity()
#   (62): ParameterModule()
#   (63): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (64): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#   (65): ParameterModule()
#   (66): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (67): Identity()
#   (68): ParameterModule()
#   (69): ParameterModule()
#   (70): Identity()
#   (71): ParameterModule()
#   (72): ParameterModule()
#   (73): Identity()
#   (74): ParameterModule()
#   (75): BatchNorm2d(24, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (76): MemoryEfficientSwish()
#   (77): Identity()
#   (78): ParameterModule()
#   (79): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (80): ZeroPad2d(padding=(1, 2, 1, 2), value=0.0)
#   (81): ParameterModule()
#   (82): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (83): Identity()
#   (84): ParameterModule()
#   (85): ParameterModule()
#   (86): Identity()
#   (87): ParameterModule()
#   (88): ParameterModule()
#   (89): Identity()
#   (90): ParameterModule()
#   (91): BatchNorm2d(48, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (92): MemoryEfficientSwish()
#   (93): Identity()
#   (94): ParameterModule()
#   (95): BatchNorm2d(288, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (96): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (97): ParameterModule()
#   (98): BatchNorm2d(288, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (99): Identity()
#   (100): ParameterModule()
#   (101): ParameterModule()
#   (102): Identity()
#   (103): ParameterModule()
#   (104): ParameterModule()
#   (105): Identity()
#   (106): ParameterModule()
#   (107): BatchNorm2d(48, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (108): MemoryEfficientSwish()
#   (109): Identity()
#   (110): ParameterModule()
#   (111): BatchNorm2d(288, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (112): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (113): ParameterModule()
#   (114): BatchNorm2d(288, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (115): Identity()
#   (116): ParameterModule()
#   (117): ParameterModule()
#   (118): Identity()
#   (119): ParameterModule()
#   (120): ParameterModule()
#   (121): Identity()
#   (122): ParameterModule()
#   (123): BatchNorm2d(48, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (124): MemoryEfficientSwish()
#   (125): Identity()
#   (126): ParameterModule()
#   (127): BatchNorm2d(288, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (128): ZeroPad2d(padding=(0, 1, 0, 1), value=0.0)
#   (129): ParameterModule()
#   (130): BatchNorm2d(288, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (131): Identity()
#   (132): ParameterModule()
#   (133): ParameterModule()
#   (134): Identity()
#   (135): ParameterModule()
#   (136): ParameterModule()
#   (137): Identity()
#   (138): ParameterModule()
#   (139): BatchNorm2d(88, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (140): MemoryEfficientSwish()
#   (141): Identity()
#   (142): ParameterModule()
#   (143): BatchNorm2d(528, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (144): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#   (145): ParameterModule()
#   (146): BatchNorm2d(528, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (147): Identity()
#   (148): ParameterModule()
#   (149): ParameterModule()
#   (150): Identity()
#   (151): ParameterModule()
#   (152): ParameterModule()
#   (153): Identity()
#   (154): ParameterModule()
#   (155): BatchNorm2d(88, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (156): MemoryEfficientSwish()
#   (157): Identity()
#   (158): ParameterModule()
#   (159): BatchNorm2d(528, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (160): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#   (161): ParameterModule()
#   (162): BatchNorm2d(528, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (163): Identity()
#   (164): ParameterModule()
#   (165): ParameterModule()
#   (166): Identity()
#   (167): ParameterModule()
#   (168): ParameterModule()
#   (169): Identity()
#   (170): ParameterModule()
#   (171): BatchNorm2d(88, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (172): MemoryEfficientSwish()
#   (173): Identity()
#   (174): ParameterModule()
#   (175): BatchNorm2d(528, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (176): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#   (177): ParameterModule()
#   (178): BatchNorm2d(528, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (179): Identity()
#   (180): ParameterModule()
#   (181): ParameterModule()
#   (182): Identity()
#   (183): ParameterModule()
#   (184): ParameterModule()
#   (185): Identity()
#   (186): ParameterModule()
#   (187): BatchNorm2d(88, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (188): MemoryEfficientSwish()
#   (189): Identity()
#   (190): ParameterModule()
#   (191): BatchNorm2d(528, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (192): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (193): ParameterModule()
#   (194): BatchNorm2d(528, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (195): Identity()
#   (196): ParameterModule()
#   (197): ParameterModule()
#   (198): Identity()
#   (199): ParameterModule()
#   (200): ParameterModule()
#   (201): Identity()
#   (202): ParameterModule()
#   (203): BatchNorm2d(120, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (204): MemoryEfficientSwish()
#   (205): Identity()
#   (206): ParameterModule()
#   (207): BatchNorm2d(720, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (208): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (209): ParameterModule()
#   (210): BatchNorm2d(720, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (211): Identity()
#   (212): ParameterModule()
#   (213): ParameterModule()
#   (214): Identity()
#   (215): ParameterModule()
#   (216): ParameterModule()
#   (217): Identity()
#   (218): ParameterModule()
#   (219): BatchNorm2d(120, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (220): MemoryEfficientSwish()
#   (221): Identity()
#   (222): ParameterModule()
#   (223): BatchNorm2d(720, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (224): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (225): ParameterModule()
#   (226): BatchNorm2d(720, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (227): Identity()
#   (228): ParameterModule()
#   (229): ParameterModule()
#   (230): Identity()
#   (231): ParameterModule()
#   (232): ParameterModule()
#   (233): Identity()
#   (234): ParameterModule()
#   (235): BatchNorm2d(120, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (236): MemoryEfficientSwish()
#   (237): Identity()
#   (238): ParameterModule()
#   (239): BatchNorm2d(720, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (240): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (241): ParameterModule()
#   (242): BatchNorm2d(720, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (243): Identity()
#   (244): ParameterModule()
#   (245): ParameterModule()
#   (246): Identity()
#   (247): ParameterModule()
#   (248): ParameterModule()
#   (249): Identity()
#   (250): ParameterModule()
#   (251): BatchNorm2d(120, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (252): MemoryEfficientSwish()
#   (253): Identity()
#   (254): ParameterModule()
#   (255): BatchNorm2d(720, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (256): ZeroPad2d(padding=(1, 2, 1, 2), value=0.0)
#   (257): ParameterModule()
#   (258): BatchNorm2d(720, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (259): Identity()
#   (260): ParameterModule()
#   (261): ParameterModule()
#   (262): Identity()
#   (263): ParameterModule()
#   (264): ParameterModule()
#   (265): Identity()
#   (266): ParameterModule()
#   (267): BatchNorm2d(208, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (268): MemoryEfficientSwish()
#   (269): Identity()
#   (270): ParameterModule()
#   (271): BatchNorm2d(1248, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (272): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (273): ParameterModule()
#   (274): BatchNorm2d(1248, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (275): Identity()
#   (276): ParameterModule()
#   (277): ParameterModule()
#   (278): Identity()
#   (279): ParameterModule()
#   (280): ParameterModule()
#   (281): Identity()
#   (282): ParameterModule()
#   (283): BatchNorm2d(208, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (284): MemoryEfficientSwish()
#   (285): Identity()
#   (286): ParameterModule()
#   (287): BatchNorm2d(1248, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (288): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (289): ParameterModule()
#   (290): BatchNorm2d(1248, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (291): Identity()
#   (292): ParameterModule()
#   (293): ParameterModule()
#   (294): Identity()
#   (295): ParameterModule()
#   (296): ParameterModule()
#   (297): Identity()
#   (298): ParameterModule()
#   (299): BatchNorm2d(208, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (300): MemoryEfficientSwish()
#   (301): Identity()
#   (302): ParameterModule()
#   (303): BatchNorm2d(1248, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (304): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (305): ParameterModule()
#   (306): BatchNorm2d(1248, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (307): Identity()
#   (308): ParameterModule()
#   (309): ParameterModule()
#   (310): Identity()
#   (311): ParameterModule()
#   (312): ParameterModule()
#   (313): Identity()
#   (314): ParameterModule()
#   (315): BatchNorm2d(208, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (316): MemoryEfficientSwish()
#   (317): Identity()
#   (318): ParameterModule()
#   (319): BatchNorm2d(1248, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (320): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (321): ParameterModule()
#   (322): BatchNorm2d(1248, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (323): Identity()
#   (324): ParameterModule()
#   (325): ParameterModule()
#   (326): Identity()
#   (327): ParameterModule()
#   (328): ParameterModule()
#   (329): Identity()
#   (330): ParameterModule()
#   (331): BatchNorm2d(208, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (332): MemoryEfficientSwish()
#   (333): Identity()
#   (334): ParameterModule()
#   (335): BatchNorm2d(1248, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (336): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#   (337): ParameterModule()
#   (338): BatchNorm2d(1248, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (339): Identity()
#   (340): ParameterModule()
#   (341): ParameterModule()
#   (342): Identity()
#   (343): ParameterModule()
#   (344): ParameterModule()
#   (345): Identity()
#   (346): ParameterModule()
#   (347): BatchNorm2d(352, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (348): MemoryEfficientSwish()
#   (349): Identity()
#   (350): ParameterModule()
#   (351): BatchNorm2d(2112, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (352): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#   (353): ParameterModule()
#   (354): BatchNorm2d(2112, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (355): Identity()
#   (356): ParameterModule()
#   (357): ParameterModule()
#   (358): Identity()
#   (359): ParameterModule()
#   (360): ParameterModule()
#   (361): Identity()
#   (362): ParameterModule()
#   (363): BatchNorm2d(352, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (364): MemoryEfficientSwish()
#   (365): Identity()
#   (366): ParameterModule()
#   (367): BatchNorm2d(1408, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (368): AdaptiveAvgPool2d(output_size=1)
#   (369): Dropout(p=0.3, inplace=False)
#   (370): Linear(in_features=1408, out_features=6, bias=True)
#   (371): MemoryEfficientSwish()
# )], add_time=True, silent=False)

# %%
learn.lr_find()
learn.recorder.plot(suggestion=True)
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 1.00E-03
# Min loss divided by 10: 6.92E-03

# %%
lr = 7e-3
learn.fit_one_cycle(5, lr, 
                    callbacks=[SaveModelCallback(learn, every='improvement', monitor='valid_loss', name='dicom_best_410_validgrouped')])
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>fbeta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.124578</td>
#       <td>0.183465</td>
#       <td>0.114934</td>
#       <td>5:47:57</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.116979</td>
#       <td>0.126079</td>
#       <td>0.093869</td>
#       <td>5:48:14</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.103361</td>
#       <td>0.119512</td>
#       <td>0.112620</td>
#       <td>5:48:26</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.087433</td>
#       <td>0.086337</td>
#       <td>0.125493</td>
#       <td>5:48:26</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.074923</td>
#       <td>0.075367</td>
#       <td>0.134415</td>
#       <td>5:48:28</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.18346494436264038.
# Better model found at epoch 1 with valid_loss value: 0.12607908248901367.
# Better model found at epoch 2 with valid_loss value: 0.11951187998056412.
# Better model found at epoch 3 with valid_loss value: 0.08633670210838318.
# Better model found at epoch 4 with valid_loss value: 0.07536658644676208.

# %%
learn.save('rsna-dicom-effb2-410-validgrouped-stage1')

# %%
learn.unfreeze()

# %%
learn.lr_find()
learn.recorder.plot(suggestion=True)
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Failed to compute the gradients, there might not be enough points.

# %%
learn.load('dicom_best_410_validgrouped')
learn.fit_one_cycle(5, slice(4e-5), 
                    callbacks=[SaveModelCallback(learn, every='improvement', monitor='valid_loss', 
                                                 name='dicom_best_410_validgrouped')])

# %%
learn.save('rsna-dicom-effb2-410-validgrouped-stage2')

# %%
learn.load('dicom_best_410_validgrouped')

# %%
#learn.load('rsna-dicom-effb0-224-validgrouped-stage1')

# %%
preds, _ = learn.get_preds(ds_type=DatasetType.Test)

# %%
preds
# Out:
# tensor([[4.9611e-02, 1.4991e-03, 1.2591e-02, 6.2288e-03, 4.1652e-03, 3.3422e-02],
#         [1.1886e-04, 2.9112e-06, 2.3566e-05, 2.9380e-06, 2.0148e-05, 1.1667e-04],
#         [6.6078e-06, 3.2957e-08, 2.2134e-07, 7.5040e-09, 1.2608e-06, 1.0499e-05],
#         ...,
#         [4.6472e-06, 5.2592e-08, 1.6465e-08, 9.6657e-09, 2.4023e-07, 4.1683e-06],
#         [6.4004e-03, 3.5431e-05, 2.4195e-04, 4.9707e-04, 2.9950e-03, 2.4523e-03],
#         [5.8645e-03, 2.6385e-04, 1.0276e-03, 2.8215e-04, 1.6106e-03, 4.4956e-03]])

# %%
datasetIndex = []
num = len(learn.data.test_ds)

for i in range(num):
    datasetIndex.append(str(learn.data.test_ds.items[i]).split('/')[-1])

# %%
datasetIndex
# Out:
# ['ID_000012eaf.dcm',
#  'ID_0000ca2f6.dcm',
#  'ID_000259ccf.dcm',
#  'ID_0002d438a.dcm',
#  'ID_00032d440.dcm',
#  'ID_00044a417.dcm',
#  'ID_0004cd66f.dcm',
#  'ID_0005b2d86.dcm',
#  'ID_0005db660.dcm',
#  'ID_000624786.dcm',
#  'ID_0006441d0.dcm',
#  'ID_00067e05e.dcm',
#  'ID_000716c43.dcm',
#  'ID_0007c5cb8.dcm',
#  'ID_00086a66f.dcm',
#  'ID_0008f134d.dcm',
#  'ID_000920cd1.dcm',
#  'ID_0009c4591.dcm',
#  'ID_000b8242c.dcm',
#  'ID_000dcad55.dcm',
#  'ID_000dfc63c.dcm',
#  'ID_000e918cb.dcm',
#  'ID_000edbf38.dcm',
#  'ID_000ef9a73.dcm',
#  'ID_000f4b376.dcm',
#  'ID_000ff2f62.dcm',
#  'ID_0010c2cba.dcm',
#  'ID_001397ee7.dcm',
#  'ID_0013ac1b1.dcm',
#  'ID_001423669.dcm',
#  'ID_0014fa8d6.dcm',
#  'ID_0015ed96c.dcm',
#  'ID_00168a161.dcm',
#  'ID_0016fa1ac.dcm',
#  'ID_0017dbe86.dcm',
#  'ID_0017f3209.dcm',
#  'ID_00180d0bf.dcm',
#  'ID_0018abbe1.dcm',
#  'ID_001af9a11.dcm',
#  'ID_001b5d5db.dcm',
#  'ID_001c4f769.dcm',
#  'ID_001c66334.dcm',
#  'ID_001c828ec.dcm',
#  'ID_001d0012a.dcm',
#  'ID_001f46a1c.dcm',
#  'ID_00216d818.dcm',
#  'ID_002185add.dcm',
#  'ID_002287eb9.dcm',
#  'ID_002444960.dcm',
#  'ID_002493a7c.dcm',
#  'ID_0026769fd.dcm',
#  'ID_0027cbc5d.dcm',
#  'ID_0027cd18b.dcm',
#  'ID_0028242b1.dcm',
#  'ID_002a52a2f.dcm',
#  'ID_002ac3f83.dcm',
#  'ID_002b21601.dcm',
#  'ID_002b9e809.dcm',
#  'ID_002bba5e9.dcm',
#  'ID_002c1ab67.dcm',
#  'ID_002d09d1a.dcm',
#  'ID_002d6bbff.dcm',
#  'ID_002e294aa.dcm',
#  'ID_002e319c9.dcm',
#  'ID_002faf07d.dcm',
#  'ID_002fbec31.dcm',
#  'ID_0030b7850.dcm',
#  'ID_0030bd8ee.dcm',
#  'ID_0031c0ba9.dcm',
#  'ID_003277954.dcm',
#  'ID_00345662c.dcm',
#  'ID_003775fbf.dcm',
#  'ID_003794066.dcm',
#  'ID_0037a7902.dcm',
#  'ID_00388f66b.dcm',
#  'ID_0039a7097.dcm',
#  'ID_0039ff145.dcm',
#  'ID_003a4af0e.dcm',
#  'ID_003ba9f7b.dcm',
#  'ID_003d8861a.dcm',
#  'ID_003dc6afb.dcm',
#  'ID_00414f24c.dcm',
#  'ID_0043f8fc4.dcm',
#  'ID_0045ca0d5.dcm',
#  'ID_00462dc9a.dcm',
#  'ID_00466709b.dcm',
#  'ID_00469a24b.dcm',
#  'ID_00470b86e.dcm',
#  'ID_004757ce7.dcm',
#  'ID_00479f3ef.dcm',
#  'ID_0048277bf.dcm',
#  'ID_004874d36.dcm',
#  'ID_0048af5eb.dcm',
#  'ID_0049020bd.dcm',
#  'ID_0049272d2.dcm',
#  'ID_004966d37.dcm',
#  'ID_004a76189.dcm',
#  'ID_004b59c06.dcm',
#  'ID_004c05696.dcm',
#  'ID_004c5f6f7.dcm',
#  'ID_004c926e3.dcm',
#  'ID_004dac33f.dcm',
#  'ID_004db0d70.dcm',
#  'ID_00506a1de.dcm',
#  'ID_0050b9e64.dcm',
#  'ID_0051918d6.dcm',
#  'ID_0051a188d.dcm',
#  'ID_0051ff0b1.dcm',
#  'ID_005362755.dcm',
#  'ID_00556e194.dcm',
#  'ID_0055d1ec5.dcm',
#  'ID_005625c0f.dcm',
#  'ID_005883003.dcm',
#  'ID_0059b9f3d.dcm',
#  'ID_0059ea5a0.dcm',
#  'ID_005a05616.dcm',
#  'ID_005a27301.dcm',
#  'ID_005a93928.dcm',
#  'ID_005b9681c.dcm',
#  'ID_005d2e378.dcm',
#  'ID_005da00b4.dcm',
#  'ID_005dd7a68.dcm',
#  'ID_005e6ce1e.dcm',
#  'ID_005ed82f7.dcm',
#  'ID_005f428d2.dcm',
#  'ID_005fab6c7.dcm',
#  'ID_005fc8902.dcm',
#  'ID_005ff1a7f.dcm',
#  'ID_006035056.dcm',
#  'ID_0062727ba.dcm',
#  'ID_0062f2e34.dcm',
#  'ID_006357b4b.dcm',
#  'ID_00642e48f.dcm',
#  'ID_00645f5a5.dcm',
#  'ID_0065304ee.dcm',
#  'ID_0066a047b.dcm',
#  'ID_0066cf28b.dcm',
#  'ID_0066da35b.dcm',
#  'ID_006835157.dcm',
#  'ID_00689b9c5.dcm',
#  'ID_006947877.dcm',
#  'ID_006c34feb.dcm',
#  'ID_006c508c8.dcm',
#  'ID_006d0c282.dcm',
#  'ID_006d4baf4.dcm',
#  'ID_006d7b96f.dcm',
#  'ID_006e10fb0.dcm',
#  'ID_006e281a1.dcm',
#  'ID_006e3b6cb.dcm',
#  'ID_006e59ac5.dcm',
#  'ID_007371272.dcm',
#  'ID_0073f63f6.dcm',
#  'ID_0073fa6d7.dcm',
#  'ID_00745067d.dcm',
#  'ID_00745db55.dcm',
#  'ID_007603167.dcm',
#  'ID_0076265e1.dcm',
#  'ID_0076fbb6e.dcm',
#  'ID_0077aa014.dcm',
#  'ID_0078d8e23.dcm',
#  'ID_0078e8351.dcm',
#  'ID_007a0f089.dcm',
#  'ID_007b29975.dcm',
#  'ID_007c776fb.dcm',
#  'ID_007d12c15.dcm',
#  'ID_007d4d577.dcm',
#  'ID_007ded5a7.dcm',
#  'ID_007e5cc1f.dcm',
#  'ID_007e9bc90.dcm',
#  'ID_008018e8a.dcm',
#  'ID_008204384.dcm',
#  'ID_0084728ee.dcm',
#  'ID_00862d77d.dcm',
#  'ID_0086de33b.dcm',
#  'ID_0087d6d1e.dcm',
#  'ID_008987e7e.dcm',
#  'ID_008a7f9f4.dcm',
#  'ID_008b58aa4.dcm',
#  'ID_008bb4fab.dcm',
#  'ID_008c5ee32.dcm',
#  'ID_008c8e831.dcm',
#  'ID_008ce33f8.dcm',
#  'ID_008df70bd.dcm',
#  'ID_008e4023a.dcm',
#  'ID_009128ac5.dcm',
#  'ID_0091a6335.dcm',
#  'ID_0092299b8.dcm',
#  'ID_009233928.dcm',
#  'ID_00923f10c.dcm',
#  'ID_0092d5830.dcm',
#  'ID_00937d8b0.dcm',
#  'ID_0093c3a19.dcm',
#  'ID_00942831d.dcm',
#  'ID_0094492ae.dcm',
#  'ID_0095407bf.dcm',
#  'ID_0095492cd.dcm',
#  'ID_00958000a.dcm',
#  'ID_0097a3fe6.dcm',
#  'ID_00981df26.dcm',
#  'ID_00982474b.dcm',
#  'ID_0099f7aee.dcm',
#  'ID_009b26321.dcm',
#  'ID_009b4dc86.dcm',
#  'ID_009b7ef6b.dcm',
#  'ID_009b8a3ad.dcm',
#  'ID_009c4db37.dcm',
#  'ID_009f4747a.dcm',
#  'ID_00a170e01.dcm',
#  'ID_00a2daf58.dcm',
#  'ID_00a3ee613.dcm',
#  'ID_00a4dded5.dcm',
#  'ID_00a5394f3.dcm',
#  'ID_00a5e2b8f.dcm',
#  'ID_00a5f063e.dcm',
#  'ID_00a69c3b3.dcm',
#  'ID_00a6b03a7.dcm',
#  'ID_00a8e4e56.dcm',
#  'ID_00ab5b0c4.dcm',
#  'ID_00ab9d6b4.dcm',
#  'ID_00abaea4a.dcm',
#  'ID_00abed414.dcm',
#  'ID_00ac47c24.dcm',
#  'ID_00ac6c8c2.dcm',
#  'ID_00aceef99.dcm',
#  'ID_00ae13cb9.dcm',
#  'ID_00b08c323.dcm',
#  'ID_00b1884f3.dcm',
#  'ID_00b1f9ec1.dcm',
#  'ID_00b23a890.dcm',
#  'ID_00b2510c8.dcm',
#  'ID_00b3dc9fd.dcm',
#  'ID_00b41bf08.dcm',
#  'ID_00b55eb35.dcm',
#  'ID_00b5c63af.dcm',
#  'ID_00b67234b.dcm',
#  'ID_00b69b3c3.dcm',
#  'ID_00b6eb2ff.dcm',
#  'ID_00b84bf19.dcm',
#  'ID_00b8dca3f.dcm',
#  'ID_00b954024.dcm',
#  'ID_00ba1f77f.dcm',
#  'ID_00bb10795.dcm',
#  'ID_00bcc61f7.dcm',
#  'ID_00be0d980.dcm',
#  'ID_00be8b95c.dcm',
#  'ID_00bec2766.dcm',
#  'ID_00bf3f5f5.dcm',
#  'ID_00c01bbdc.dcm',
#  'ID_00c0b3796.dcm',
#  'ID_00c12192f.dcm',
#  'ID_00c2a390e.dcm',
#  'ID_00c3946ac.dcm',
#  'ID_00c4735fa.dcm',
#  'ID_00c4938c5.dcm',
#  'ID_00c6f3ae3.dcm',
#  'ID_00c8004ef.dcm',
#  'ID_00c847f1c.dcm',
#  'ID_00c88ed45.dcm',
#  'ID_00c89e3a6.dcm',
#  'ID_00ca1dad8.dcm',
#  'ID_00cada62a.dcm',
#  'ID_00cb18c74.dcm',
#  'ID_00cbc466a.dcm',
#  'ID_00cbcb168.dcm',
#  'ID_00cee9241.dcm',
#  'ID_00cf04f7f.dcm',
#  'ID_00cf3c617.dcm',
#  'ID_00d03cd4f.dcm',
#  'ID_00d10f258.dcm',
#  'ID_00d1c7298.dcm',
#  'ID_00d1e2d08.dcm',
#  'ID_00d298762.dcm',
#  'ID_00d2cdca9.dcm',
#  'ID_00d2ed46b.dcm',
#  'ID_00d2f892d.dcm',
#  'ID_00d351261.dcm',
#  'ID_00d4a3042.dcm',
#  'ID_00d4eefc2.dcm',
#  'ID_00d5b0131.dcm',
#  'ID_00d9850da.dcm',
#  'ID_00d9ca7e4.dcm',
#  'ID_00db0adaa.dcm',
#  'ID_00dbefd9b.dcm',
#  'ID_00dc14745.dcm',
#  'ID_00dcac736.dcm',
#  'ID_00dd798b7.dcm',
#  'ID_00ddf3fd3.dcm',
#  'ID_00de4a5be.dcm',
#  'ID_00de91564.dcm',
#  'ID_00df0ddb5.dcm',
#  'ID_00e20f097.dcm',
#  'ID_00e2c5f6a.dcm',
#  'ID_00e350b34.dcm',
#  'ID_00e4f6fab.dcm',
#  'ID_00e69de2f.dcm',
#  'ID_00e6c95f0.dcm',
#  'ID_00e88314e.dcm',
#  'ID_00e908c1b.dcm',
#  'ID_00e968117.dcm',
#  'ID_00ec6bac5.dcm',
#  'ID_00ec7ba4f.dcm',
#  'ID_00edc547d.dcm',
#  'ID_00ede92f2.dcm',
#  'ID_00ef0e636.dcm',
#  'ID_00ef3a45d.dcm',
#  'ID_00ef55a73.dcm',
#  'ID_00ef8fda8.dcm',
#  'ID_00f447a0b.dcm',
#  'ID_00f475071.dcm',
#  'ID_00f496dae.dcm',
#  'ID_00f4d45c7.dcm',
#  'ID_00f525d92.dcm',
#  'ID_00f5691bb.dcm',
#  'ID_00f5def87.dcm',
#  'ID_00f6916d9.dcm',
#  'ID_00f79bfe5.dcm',
#  'ID_00f85084d.dcm',
#  'ID_00f852a88.dcm',
#  'ID_00fa2f6cc.dcm',
#  'ID_00fbd6348.dcm',
#  'ID_00fd15c28.dcm',
#  'ID_00fde2865.dcm',
#  'ID_00feb44f3.dcm',
#  'ID_00ff2567d.dcm',
#  'ID_010385f22.dcm',
#  'ID_0103a6053.dcm',
#  'ID_0108b7900.dcm',
#  'ID_010a44ecf.dcm',
#  'ID_010aafc7f.dcm',
#  'ID_010ab17e6.dcm',
#  'ID_010ad3dee.dcm',
#  'ID_010b1e7e1.dcm',
#  'ID_010b9b2e8.dcm',
#  'ID_010d14272.dcm',
#  'ID_010e94a34.dcm',
#  'ID_010ffdb9f.dcm',
#  'ID_01108184a.dcm',
#  'ID_01119d3d0.dcm',
#  'ID_0112a4021.dcm',
#  'ID_0112dd409.dcm',
#  'ID_01136b516.dcm',
#  'ID_01136e64d.dcm',
#  'ID_011608294.dcm',
#  'ID_0116f7d66.dcm',
#  'ID_0117aa276.dcm',
#  'ID_0118acf31.dcm',
#  'ID_0118d4df5.dcm',
#  'ID_01196901f.dcm',
#  'ID_01196dfb0.dcm',
#  'ID_011b7d479.dcm',
#  'ID_011c67597.dcm',
#  'ID_011d09f78.dcm',
#  'ID_011e8f05d.dcm',
#  'ID_0120ddf70.dcm',
#  'ID_01212d227.dcm',
#  'ID_0122e4160.dcm',
#  'ID_01231b25b.dcm',
#  'ID_01232a675.dcm',
#  'ID_0123a0c74.dcm',
#  'ID_0123e453e.dcm',
#  'ID_0124245bb.dcm',
#  'ID_012427f37.dcm',
#  'ID_012444a4f.dcm',
#  'ID_01254ab99.dcm',
#  'ID_012762e60.dcm',
#  'ID_0129f9dfe.dcm',
#  'ID_012ac50b8.dcm',
#  'ID_012c01409.dcm',
#  'ID_01317365d.dcm',
#  'ID_0133636ee.dcm',
#  'ID_01342c6d0.dcm',
#  'ID_01344e5c4.dcm',
#  'ID_01354f585.dcm',
#  'ID_013652bec.dcm',
#  'ID_0137e72aa.dcm',
#  'ID_0137e7740.dcm',
#  'ID_01395ddd9.dcm',
#  'ID_013d1dc10.dcm',
#  'ID_013ef8003.dcm',
#  'ID_013f09ca0.dcm',
#  'ID_013f23c46.dcm',
#  'ID_01401c4fb.dcm',
#  'ID_01407f669.dcm',
#  'ID_0141038f7.dcm',
#  'ID_01416ab96.dcm',
#  'ID_0141ed528.dcm',
#  'ID_0143775dd.dcm',
#  'ID_01443f558.dcm',
#  'ID_014750028.dcm',
#  'ID_01484c9f0.dcm',
#  'ID_0148a0617.dcm',
#  'ID_0148f9443.dcm',
#  'ID_014a5dc17.dcm',
#  'ID_014af61fb.dcm',
#  'ID_014c56ad9.dcm',
#  'ID_014d2b10e.dcm',
#  'ID_014d972d5.dcm',
#  'ID_014e3c7ca.dcm',
#  'ID_014eabe2d.dcm',
#  'ID_014ef3f82.dcm',
#  'ID_014f8bf98.dcm',
#  'ID_014faf4d9.dcm',
#  'ID_01508edbb.dcm',
#  'ID_01520f511.dcm',
#  'ID_0153cecef.dcm',
#  'ID_01562cbc8.dcm',
#  'ID_0157bcf11.dcm',
#  'ID_0157f86c8.dcm',
#  'ID_01589f3c8.dcm',
#  'ID_0158f4a3a.dcm',
#  'ID_015a0fe31.dcm',
#  'ID_015ad1862.dcm',
#  'ID_015b2e530.dcm',
#  'ID_015b8e18c.dcm',
#  'ID_015ba6b3c.dcm',
#  'ID_015dc323d.dcm',
#  'ID_015ed434e.dcm',
#  'ID_015edf100.dcm',
#  'ID_015f93792.dcm',
#  'ID_015fc137a.dcm',
#  'ID_0160404fe.dcm',
#  'ID_01608c795.dcm',
#  'ID_01614e08c.dcm',
#  'ID_0162c69f0.dcm',
#  'ID_016356ad3.dcm',
#  'ID_01636b51b.dcm',
#  'ID_01649d92c.dcm',
#  'ID_0165b6acb.dcm',
#  'ID_016710f58.dcm',
#  'ID_01676688e.dcm',
#  'ID_0167ac0d7.dcm',
#  'ID_01682b171.dcm',
#  'ID_01688f9d7.dcm',
#  'ID_0168c13de.dcm',
#  'ID_016a2d3f0.dcm',
#  'ID_016b433db.dcm',
#  'ID_016c27ba3.dcm',
#  'ID_016d71b15.dcm',
#  'ID_016e273c2.dcm',
#  'ID_016e5beec.dcm',
#  'ID_016f1d2a3.dcm',
#  'ID_0170d6740.dcm',
#  'ID_01725551f.dcm',
#  'ID_017354028.dcm',
#  'ID_0173c7516.dcm',
#  'ID_01752169b.dcm',
#  'ID_017635f1c.dcm',
#  'ID_0176360b8.dcm',
#  'ID_0176f1d4b.dcm',
#  'ID_01777faff.dcm',
#  'ID_0179e9289.dcm',
#  'ID_017a61482.dcm',
#  'ID_017a6c5f9.dcm',
#  'ID_017a76d8f.dcm',
#  'ID_017af91db.dcm',
#  'ID_017bd27e1.dcm',
#  'ID_017c57bda.dcm',
#  'ID_017d70f34.dcm',
#  'ID_017e5c607.dcm',
#  'ID_017e5fabe.dcm',
#  'ID_01810c89e.dcm',
#  'ID_018189cd6.dcm',
#  'ID_0182516d7.dcm',
#  'ID_01830fb22.dcm',
#  'ID_01833f39d.dcm',
#  'ID_0183fafdf.dcm',
#  'ID_0185aa367.dcm',
#  'ID_0185b6d9e.dcm',
#  'ID_0185fa664.dcm',
#  'ID_0187b38a3.dcm',
#  'ID_018936a6b.dcm',
#  'ID_0189a2abc.dcm',
#  'ID_018a1ae0a.dcm',
#  'ID_018d94da9.dcm',
#  'ID_018dfe32f.dcm',
#  'ID_018eb30ba.dcm',
#  'ID_018fed04a.dcm',
#  'ID_0190fc5e0.dcm',
#  'ID_019542400.dcm',
#  'ID_01991286f.dcm',
#  'ID_019a1ee29.dcm',
#  'ID_019b14f47.dcm',
#  'ID_019ec91f3.dcm',
#  'ID_019efd5b0.dcm',
#  'ID_019f3e87b.dcm',
#  'ID_019f3e9fc.dcm',
#  'ID_019f7ed85.dcm',
#  'ID_01a02d2c1.dcm',
#  'ID_01a4d1e0c.dcm',
#  'ID_01a80edd8.dcm',
#  'ID_01a8d7f75.dcm',
#  'ID_01a929096.dcm',
#  'ID_01a9361c5.dcm',
#  'ID_01aa8743e.dcm',
#  'ID_01ac6dd74.dcm',
#  'ID_01ae97feb.dcm',
#  'ID_01aef037c.dcm',
#  'ID_01afb3cf2.dcm',
#  'ID_01b03eb4b.dcm',
#  'ID_01b0c123c.dcm',
#  'ID_01b1e36ac.dcm',
#  'ID_01b22e09e.dcm',
#  'ID_01b40dffe.dcm',
#  'ID_01b4ea9b2.dcm',
#  'ID_01b4f6e4e.dcm',
#  'ID_01b5ad0e9.dcm',
#  'ID_01b63e8b4.dcm',
#  'ID_01b66795c.dcm',
#  'ID_01b6c467c.dcm',
#  'ID_01b70bd56.dcm',
#  'ID_01b7ce870.dcm',
#  'ID_01b84b2e2.dcm',
#  'ID_01b8b577e.dcm',
#  'ID_01b945970.dcm',
#  'ID_01b9e867c.dcm',
#  'ID_01bab5738.dcm',
#  'ID_01bb2c3ce.dcm',
#  'ID_01bb9af49.dcm',
#  'ID_01bd125bb.dcm',
#  'ID_01be0e92a.dcm',
#  'ID_01be24500.dcm',
#  'ID_01be96605.dcm',
#  'ID_01bf2f203.dcm',
#  'ID_01c063f9c.dcm',
#  'ID_01c0af567.dcm',
#  'ID_01c0f0dfa.dcm',
#  'ID_01c10ead2.dcm',
#  'ID_01c1e45ec.dcm',
#  'ID_01c7e0cf2.dcm',
#  'ID_01c807914.dcm',
#  'ID_01ca5d9ac.dcm',
#  'ID_01ca64230.dcm',
#  'ID_01ca8fc59.dcm',
#  'ID_01cce69cd.dcm',
#  'ID_01ce1f645.dcm',
#  'ID_01ce8ba4c.dcm',
#  'ID_01cf3e07c.dcm',
#  'ID_01d0201f0.dcm',
#  'ID_01d0f230d.dcm',
#  'ID_01d16625b.dcm',
#  'ID_01d23c680.dcm',
#  'ID_01d2b3506.dcm',
#  'ID_01d48e8f7.dcm',
#  'ID_01d51cd7e.dcm',
#  'ID_01d63411b.dcm',
#  'ID_01d67179b.dcm',
#  'ID_01d68dc70.dcm',
#  'ID_01d6fb13a.dcm',
#  'ID_01d8ae3b5.dcm',
#  'ID_01d94447d.dcm',
#  'ID_01d954c5a.dcm',
#  'ID_01dac1eb6.dcm',
#  'ID_01db868f9.dcm',
#  'ID_01dc861dc.dcm',
#  'ID_01dcb29c3.dcm',
#  'ID_01de605c5.dcm',
#  'ID_01df7e3e5.dcm',
#  'ID_01dfb3621.dcm',
#  'ID_01e21b5a5.dcm',
#  'ID_01e26f2bf.dcm',
#  'ID_01e3f5739.dcm',
#  'ID_01e40becc.dcm',
#  'ID_01e482ae6.dcm',
#  'ID_01e499500.dcm',
#  'ID_01e512f8f.dcm',
#  'ID_01e6cfc52.dcm',
#  'ID_01e6e67c2.dcm',
#  'ID_01e82dd8e.dcm',
#  'ID_01e84b842.dcm',
#  'ID_01e8d73a6.dcm',
#  'ID_01ea3176a.dcm',
#  'ID_01ea59f04.dcm',
#  'ID_01eadbcee.dcm',
#  'ID_01eafcf9d.dcm',
#  'ID_01eb4fd8b.dcm',
#  'ID_01eb73cce.dcm',
#  'ID_01ece1e57.dcm',
#  'ID_01ee7490e.dcm',
#  'ID_01f05e2f7.dcm',
#  'ID_01f0ea171.dcm',
#  'ID_01f172d83.dcm',
#  'ID_01f29bc52.dcm',
#  'ID_01f471e21.dcm',
#  'ID_01f4c3e4b.dcm',
#  'ID_01f602bb8.dcm',
#  'ID_01f68696e.dcm',
#  'ID_01f6d2a2f.dcm',
#  'ID_01f8047b5.dcm',
#  'ID_01fbeba5f.dcm',
#  'ID_01fc78f0a.dcm',
#  'ID_01fcf3f26.dcm',
#  'ID_01fd109f6.dcm',
#  'ID_01fe05d3a.dcm',
#  'ID_01fe1bf3d.dcm',
#  'ID_01ff44207.dcm',
#  'ID_0200af6e9.dcm',
#  'ID_020279337.dcm',
#  'ID_0202f9a92.dcm',
#  'ID_02046f52e.dcm',
#  'ID_020498ea7.dcm',
#  'ID_0205dced9.dcm',
#  'ID_020814632.dcm',
#  'ID_020836139.dcm',
#  'ID_020937c2b.dcm',
#  'ID_0209e3d4d.dcm',
#  'ID_020a72b1b.dcm',
#  'ID_020ae5e81.dcm',
#  'ID_020ba45f7.dcm',
#  'ID_020bc824f.dcm',
#  'ID_020c26a25.dcm',
#  'ID_020e77054.dcm',
#  'ID_021069182.dcm',
#  'ID_0211876e0.dcm',
#  'ID_0212b7de6.dcm',
#  'ID_02131ad46.dcm',
#  'ID_0213b6fb9.dcm',
#  'ID_021460017.dcm',
#  'ID_021507ddb.dcm',
#  'ID_02167d826.dcm',
#  'ID_0217ac6d8.dcm',
#  'ID_0217f768e.dcm',
#  'ID_0218c4981.dcm',
#  'ID_0219f30ab.dcm',
#  'ID_021ac0e98.dcm',
#  'ID_021b91e3e.dcm',
#  'ID_021ce6fa7.dcm',
#  'ID_021e1a4ab.dcm',
#  'ID_021e4e148.dcm',
#  'ID_021f5d135.dcm',
#  'ID_0220b3bea.dcm',
#  'ID_0220c9820.dcm',
#  'ID_022396f43.dcm',
#  'ID_0223bc8cf.dcm',
#  'ID_0224bdd7d.dcm',
#  'ID_0225a8f80.dcm',
#  'ID_02284cf06.dcm',
#  'ID_0229dc878.dcm',
#  'ID_0229f0512.dcm',
#  'ID_022a621e3.dcm',
#  'ID_022c41d68.dcm',
#  'ID_022c638c7.dcm',
#  'ID_022dc16b0.dcm',
#  'ID_022dc716c.dcm',
#  'ID_022ded78a.dcm',
#  'ID_022e35f8b.dcm',
#  'ID_0232226e6.dcm',
#  'ID_0232ee978.dcm',
#  'ID_02395da43.dcm',
#  'ID_023b02213.dcm',
#  'ID_023b58870.dcm',
#  'ID_023bfa6e5.dcm',
#  'ID_023bfad6e.dcm',
#  'ID_023c67832.dcm',
#  'ID_023c7e2cf.dcm',
#  'ID_023d409b0.dcm',
#  'ID_023daa1d8.dcm',
#  'ID_023dffd1a.dcm',
#  'ID_02400e0e1.dcm',
#  'ID_024029feb.dcm',
#  'ID_02412ea8e.dcm',
#  'ID_0242c6e4f.dcm',
#  'ID_0242c9adb.dcm',
#  'ID_0242f20c2.dcm',
#  'ID_024385261.dcm',
#  'ID_02454ebe2.dcm',
#  'ID_02471b3e7.dcm',
#  'ID_024720efc.dcm',
#  'ID_0247b32ab.dcm',
#  'ID_0247b7e6f.dcm',
#  'ID_024812463.dcm',
#  'ID_02484d180.dcm',
#  'ID_0248ae5cc.dcm',
#  'ID_0248e359a.dcm',
#  'ID_0248fba88.dcm',
#  'ID_0249d796f.dcm',
#  'ID_024b476b2.dcm',
#  'ID_024bc074e.dcm',
#  'ID_024c4ee04.dcm',
#  'ID_024c7e591.dcm',
#  'ID_024cd0c5b.dcm',
#  'ID_024cf56ed.dcm',
#  'ID_024d32088.dcm',
#  'ID_024e2b0d8.dcm',
#  'ID_024ef2e4a.dcm',
#  'ID_024f328dd.dcm',
#  'ID_02513840e.dcm',
#  'ID_02533916a.dcm',
#  'ID_025386451.dcm',
#  'ID_02548dcb1.dcm',
#  'ID_0254e4a17.dcm',
#  'ID_0255a1198.dcm',
#  'ID_0255f0ead.dcm',
#  'ID_0255fc254.dcm',
#  'ID_0257be357.dcm',
#  'ID_0258192c7.dcm',
#  'ID_02592230d.dcm',
#  'ID_0259ea2ae.dcm',
#  'ID_025a38d09.dcm',
#  'ID_025b1b609.dcm',
#  'ID_025ca2cdd.dcm',
#  'ID_025e02360.dcm',
#  'ID_0260e82ba.dcm',
#  'ID_026177d53.dcm',
#  'ID_026249e7b.dcm',
#  'ID_02631e52a.dcm',
#  'ID_02639570d.dcm',
#  'ID_026446819.dcm',
#  'ID_02663cd1e.dcm',
#  'ID_0267b0070.dcm',
#  'ID_0267d6642.dcm',
#  'ID_0268333be.dcm',
#  'ID_026966fba.dcm',
#  'ID_026a9fb00.dcm',
#  'ID_026b12952.dcm',
#  'ID_026bcf6aa.dcm',
#  'ID_026c111d1.dcm',
#  'ID_026c3ed60.dcm',
#  'ID_026cd4842.dcm',
#  'ID_026d4f5eb.dcm',
#  'ID_026ec02aa.dcm',
#  'ID_026f5c072.dcm',
#  'ID_02711f770.dcm',
#  'ID_0271e1771.dcm',
#  'ID_0271f2ee6.dcm',
#  'ID_02726db10.dcm',
#  'ID_0272d9254.dcm',
#  'ID_0276a4578.dcm',
#  'ID_0276e7c99.dcm',
#  'ID_0278756b0.dcm',
#  'ID_0278ae6e7.dcm',
#  'ID_027cb0f41.dcm',
#  'ID_027dca76b.dcm',
#  'ID_027e1d578.dcm',
#  'ID_027e621ae.dcm',
#  'ID_027f32a47.dcm',
#  'ID_0280aa68d.dcm',
#  'ID_0281f3510.dcm',
#  'ID_02820f453.dcm',
#  'ID_0282c3b78.dcm',
#  'ID_0284b8b05.dcm',
#  'ID_0284d6631.dcm',
#  'ID_02872195c.dcm',
#  'ID_028889856.dcm',
#  'ID_028898832.dcm',
#  'ID_0288f68c5.dcm',
#  'ID_028a418b7.dcm',
#  'ID_028bb3f46.dcm',
#  'ID_028c44aa7.dcm',
#  'ID_028d77394.dcm',
#  'ID_028d7d9cb.dcm',
#  'ID_028d91c38.dcm',
#  'ID_028eb9a94.dcm',
#  'ID_028ebec94.dcm',
#  'ID_02903ef4a.dcm',
#  'ID_02905b666.dcm',
#  'ID_02907f79c.dcm',
#  'ID_02911e1e6.dcm',
#  'ID_0292e75cd.dcm',
#  'ID_02937ba6e.dcm',
#  'ID_0293e0349.dcm',
#  'ID_0295294f6.dcm',
#  'ID_0296447aa.dcm',
#  'ID_029694b4f.dcm',
#  'ID_0296ad8ac.dcm',
#  'ID_029775722.dcm',
#  'ID_029983560.dcm',
#  'ID_0299e9275.dcm',
#  'ID_029a670b4.dcm',
#  'ID_029b693d9.dcm',
#  'ID_029b94665.dcm',
#  'ID_029d9280e.dcm',
#  'ID_029e0abce.dcm',
#  'ID_029e4b639.dcm',
#  'ID_029f569cb.dcm',
#  'ID_029feab74.dcm',
#  'ID_02a09116b.dcm',
#  'ID_02a1bc0fb.dcm',
#  'ID_02a212a17.dcm',
#  'ID_02a224edf.dcm',
#  'ID_02a248572.dcm',
#  'ID_02a2c6588.dcm',
#  'ID_02a470b55.dcm',
#  'ID_02a587d42.dcm',
#  'ID_02a6e69e9.dcm',
#  'ID_02a6f2e3d.dcm',
#  'ID_02a72b642.dcm',
#  'ID_02a74d17a.dcm',
#  'ID_02a7d5ea3.dcm',
#  'ID_02a907bbd.dcm',
#  'ID_02ab0499c.dcm',
#  'ID_02acb679a.dcm',
#  'ID_02aef4194.dcm',
#  'ID_02af49b40.dcm',
#  'ID_02b029d0b.dcm',
#  'ID_02b0a753d.dcm',
#  'ID_02b0d4a32.dcm',
#  'ID_02b1336da.dcm',
#  'ID_02b134326.dcm',
#  'ID_02b13a134.dcm',
#  'ID_02b1f690e.dcm',
#  'ID_02b2f0f84.dcm',
#  'ID_02b307c46.dcm',
#  'ID_02b390084.dcm',
#  'ID_02b39be19.dcm',
#  'ID_02b3cf0db.dcm',
#  'ID_02b5adce7.dcm',
#  'ID_02b88f9e6.dcm',
#  'ID_02b9b1773.dcm',
#  'ID_02ba5a8e1.dcm',
#  'ID_02bab6890.dcm',
#  'ID_02babf852.dcm',
#  'ID_02bcfd3c4.dcm',
#  'ID_02bf87467.dcm',
#  'ID_02bf898c2.dcm',
#  'ID_02c0c6e60.dcm',
#  'ID_02c26fb39.dcm',
#  'ID_02c308006.dcm',
#  'ID_02c39a4ae.dcm',
#  'ID_02c726f59.dcm',
#  'ID_02c82fe3b.dcm',
#  'ID_02c9762ef.dcm',
#  'ID_02c98d8ee.dcm',
#  'ID_02cb9004a.dcm',
#  'ID_02cbb34f9.dcm',
#  'ID_02cce36ef.dcm',
#  'ID_02cd15ccd.dcm',
#  'ID_02ce3170a.dcm',
#  'ID_02ce923ae.dcm',
#  'ID_02cef5a44.dcm',
#  'ID_02cf09419.dcm',
#  'ID_02cf5272b.dcm',
#  'ID_02d0a103c.dcm',
#  'ID_02d25e0c3.dcm',
#  'ID_02d318e94.dcm',
#  'ID_02d3ad430.dcm',
#  'ID_02d7bf728.dcm',
#  'ID_02d7e1bb3.dcm',
#  'ID_02d95088d.dcm',
#  'ID_02da196db.dcm',
#  'ID_02da5c6c3.dcm',
#  'ID_02da8c2f4.dcm',
#  'ID_02db14b38.dcm',
#  'ID_02db747f9.dcm',
#  'ID_02dc01f8c.dcm',
#  'ID_02dfd248f.dcm',
#  'ID_02e0ee88c.dcm',
#  'ID_02e19ec4c.dcm',
#  'ID_02e2cc45e.dcm',
#  'ID_02e39a1de.dcm',
#  'ID_02e3d4d4f.dcm',
#  'ID_02e44a1ca.dcm',
#  'ID_02e4cca1d.dcm',
#  'ID_02e555e5e.dcm',
#  'ID_02e694ada.dcm',
#  'ID_02e6f4593.dcm',
#  'ID_02e728ef8.dcm',
#  'ID_02e753624.dcm',
#  'ID_02e75b940.dcm',
#  'ID_02e7ae2aa.dcm',
#  'ID_02e8da698.dcm',
#  'ID_02e9a6e4b.dcm',
#  'ID_02e9ba3b2.dcm',
#  'ID_02ea8d17b.dcm',
#  'ID_02eaacfd4.dcm',
#  'ID_02ecc6a13.dcm',
#  'ID_02ed02a4b.dcm',
#  'ID_02ed0ac21.dcm',
#  'ID_02eeb9dcb.dcm',
#  'ID_02eed31c9.dcm',
#  'ID_02ef9d760.dcm',
#  'ID_02f03a002.dcm',
#  'ID_02f0754bd.dcm',
#  'ID_02f302fb5.dcm',
#  'ID_02f3050e7.dcm',
#  'ID_02f322bca.dcm',
#  'ID_02f387a8f.dcm',
#  'ID_02f39da10.dcm',
#  'ID_02f7a40d4.dcm',
#  'ID_02f8b47b3.dcm',
#  'ID_02fa3d0fe.dcm',
#  'ID_02faaf17d.dcm',
#  'ID_02fabcc2d.dcm',
#  'ID_02fb77d44.dcm',
#  'ID_02fbe2f2f.dcm',
#  'ID_02fc26f1a.dcm',
#  'ID_02fc4bc06.dcm',
#  'ID_02fd00057.dcm',
#  'ID_02fd304a1.dcm',
#  'ID_0300ee498.dcm',
#  'ID_0301c5526.dcm',
#  'ID_03028f5d1.dcm',
#  'ID_03063f019.dcm',
#  'ID_03066fce4.dcm',
#  'ID_0307546b0.dcm',
#  'ID_03077fc18.dcm',
#  'ID_0308f0290.dcm',
#  'ID_0308f77c4.dcm',
#  'ID_030919dbe.dcm',
#  'ID_03094e955.dcm',
#  'ID_030952361.dcm',
#  'ID_030a36e4f.dcm',
#  'ID_030acbf50.dcm',
#  'ID_030c3305f.dcm',
#  'ID_0310637ce.dcm',
#  'ID_03123150d.dcm',
#  'ID_03136b445.dcm',
#  'ID_0313de9d8.dcm',
#  'ID_031453a54.dcm',
#  'ID_031549ae0.dcm',
#  'ID_0315b446e.dcm',
#  'ID_0316ab992.dcm',
#  'ID_03178a9f7.dcm',
#  'ID_0317e448f.dcm',
#  'ID_0318ef10c.dcm',
#  'ID_0319031fa.dcm',
#  'ID_031909542.dcm',
#  'ID_031afc162.dcm',
#  'ID_031c6c1c2.dcm',
#  'ID_031cadb52.dcm',
#  'ID_031cfdafd.dcm',
#  'ID_031d82fa5.dcm',
#  'ID_031dd3113.dcm',
#  'ID_031eb6855.dcm',
#  'ID_031f54f4e.dcm',
#  'ID_031fa3619.dcm',
#  'ID_03232f595.dcm',
#  'ID_032568a38.dcm',
#  'ID_032611f96.dcm',
#  'ID_032629807.dcm',
#  'ID_0326d4605.dcm',
#  'ID_032987bfa.dcm',
#  'ID_032beb55d.dcm',
#  'ID_032c134de.dcm',
#  'ID_032c30185.dcm',
#  'ID_032c7cbe7.dcm',
#  'ID_032e43aef.dcm',
#  'ID_032e7e7fa.dcm',
#  'ID_032f0c212.dcm',
#  'ID_032f516a5.dcm',
#  'ID_032f9bc7e.dcm',
#  'ID_0330296a5.dcm',
#  'ID_033253a32.dcm',
#  'ID_03346a153.dcm',
#  'ID_0334b565a.dcm',
#  'ID_03353f8ad.dcm',
#  'ID_033680140.dcm',
#  'ID_033878dbd.dcm',
#  'ID_03393da31.dcm',
#  'ID_0339cc1d5.dcm',
#  'ID_033a921ad.dcm',
#  'ID_033b47c71.dcm',
#  'ID_033e36c9e.dcm',
#  'ID_034015cad.dcm',
#  'ID_0341ef092.dcm',
#  'ID_0341f4e27.dcm',
#  'ID_034211e5c.dcm',
#  'ID_0342ff1cf.dcm',
#  'ID_0343c7183.dcm',
#  'ID_034478c12.dcm',
#  'ID_034505d03.dcm',
#  'ID_0346f9449.dcm',
#  'ID_034737b3d.dcm',
#  'ID_03474e46a.dcm',
#  'ID_034766fb7.dcm',
#  'ID_03479efe5.dcm',
#  'ID_0348008d4.dcm',
#  'ID_034a77c1e.dcm',
#  'ID_034a85b08.dcm',
#  'ID_034b72482.dcm',
#  'ID_034c9d078.dcm',
#  'ID_034d50426.dcm',
#  'ID_034fbe14b.dcm',
#  'ID_035043e6e.dcm',
#  'ID_03515d5a3.dcm',
#  'ID_0352f9257.dcm',
#  'ID_035315978.dcm',
#  'ID_0354aec88.dcm',
#  'ID_0355cee31.dcm',
#  'ID_0355eb4bf.dcm',
#  'ID_035612d99.dcm',
#  'ID_035660b67.dcm',
#  'ID_035708dd5.dcm',
#  'ID_0358055de.dcm',
#  'ID_03581e373.dcm',
#  'ID_03585c578.dcm',
#  'ID_03588e66a.dcm',
#  'ID_03591fcac.dcm',
#  'ID_035beec51.dcm',
#  'ID_035c6076d.dcm',
#  'ID_035c92fca.dcm',
#  'ID_035d2ae4f.dcm',
#  'ID_035dfc714.dcm',
#  'ID_035e46174.dcm',
#  'ID_035e74f70.dcm',
#  'ID_035f712c3.dcm',
#  'ID_0360f4fed.dcm',
#  'ID_036124e5c.dcm',
#  'ID_03629bcf0.dcm',
#  'ID_0362ec557.dcm',
#  'ID_0363b92ae.dcm',
#  ...]

# %%
classes = (pivot.columns.tolist()[1:])
classes
# Out:
# ['any',
#  'epidural',
#  'intraparenchymal',
#  'intraventricular',
#  'subarachnoid',
#  'subdural']

# %%
ids = []
labels = []

for path, pred in zip(sorted(test_files), preds):
    for i, label in enumerate(classes):
        ids.append(f"{path.split('.')[0]}_{label}")
        predicted_probability = '{0:1.10f}'.format(pred[i].item())
        labels.append(predicted_probability)

# %%
sub_df = pd.DataFrame({'ID': ids, 'Label': labels})
sub_df
# Out:
#                                    ID         Label
# 0                    ID_000012eaf_any  0.0496107265
# 1               ID_000012eaf_epidural  0.0014991296
# 2       ID_000012eaf_intraparenchymal  0.0125906980
# 3       ID_000012eaf_intraventricular  0.0062288442
# 4           ID_000012eaf_subarachnoid  0.0041651879
# ...                               ...           ...
# 471265          ID_ffffcbff8_epidural  0.0002638539
# 471266  ID_ffffcbff8_intraparenchymal  0.0010275993
# 471267  ID_ffffcbff8_intraventricular  0.0002821548
# 471268      ID_ffffcbff8_subarachnoid  0.0016106425
# 471269          ID_ffffcbff8_subdural  0.0044955746
#
# [471270 rows x 2 columns]

# %%
sub_df.to_csv('fastai-effb2-410-3channel-dicom-0.025delete-validgrouped-stage1.csv', index=False)

# %%
preds_tta, _ = learn.TTA(ds_type=DatasetType.Test)

# %%
preds_tta
# Out:
# tensor([[2.0501e-01, 2.7540e-03, 4.6725e-02, 5.7273e-02, 1.7230e-02, 6.4612e-02],
#         [3.5330e-02, 1.0541e-03, 5.9357e-03, 1.7477e-03, 8.1148e-03, 1.4788e-02],
#         [2.2686e-04, 5.2217e-06, 2.1988e-05, 2.3919e-06, 8.4630e-05, 2.5775e-04],
#         ...,
#         [4.2203e-04, 1.2639e-05, 7.7564e-06, 7.7404e-06, 6.4895e-05, 1.2684e-04],
#         [1.6098e-02, 1.3860e-04, 1.0548e-03, 7.3398e-04, 1.0356e-02, 7.1543e-03],
#         [2.8193e-02, 7.5107e-04, 5.0103e-03, 3.2394e-03, 5.6522e-03, 1.4341e-02]])

# %%
ids = []
labels_tta = []

for path, pred in zip(sorted(test_files), preds_tta):
    for i, label in enumerate(classes):
        ids.append(f"{path.split('.')[0]}_{label}")
        predicted_probability = '{0:1.10f}'.format(pred[i].item())
        labels_tta.append(predicted_probability)

# %%
sub_df_tta = pd.DataFrame({'ID': ids, 'Label': labels_tta})
sub_df_tta
# Out:
#                                    ID         Label
# 0                    ID_000012eaf_any  0.2050096989
# 1               ID_000012eaf_epidural  0.0027540459
# 2       ID_000012eaf_intraparenchymal  0.0467251465
# 3       ID_000012eaf_intraventricular  0.0572733246
# 4           ID_000012eaf_subarachnoid  0.0172295291
# ...                               ...           ...
# 471265          ID_ffffcbff8_epidural  0.0007510657
# 471266  ID_ffffcbff8_intraparenchymal  0.0050103101
# 471267  ID_ffffcbff8_intraventricular  0.0032393993
# 471268      ID_ffffcbff8_subarachnoid  0.0056521515
# 471269          ID_ffffcbff8_subdural  0.0143412380
#
# [471270 rows x 2 columns]

# %%
sub_df_tta.to_csv('fastai-effb2-410-3channel-dicom-0.025delete-validgrouped-tta-stage1.csv', index=False)

# %%
path

# %%
png = os.listdir('/mnt/fst/shaan/rsna-intracranial-hemorrhage-detection/png-rashid')
png

# %%
import matplotlib.image as mpimg
img = mpimg.imread('/mnt/fst/shaan/rsna-intracranial-hemorrhage-detection/png-rashid/'+png[0])
plt.imshow(img, cmap=cmap)
